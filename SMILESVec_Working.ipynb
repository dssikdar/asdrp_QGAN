# %% [markdown]
# <a href="https://colab.research.google.com/github/dssikdar/asdrp_QGAN/blob/main/SMILESVec_Working.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/hkmztrk/SMILESVecProteinRepresentation
# Out:
# Cloning into 'SMILESVecProteinRepresentation'...
# remote: Enumerating objects: 301, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 301 (delta 5), reused 16 (delta 5), pack-reused 285
# Receiving objects: 100% (301/301), 15.93 MiB | 12.49 MiB/s, done.
# Resolving deltas: 100% (161/161), done.

# %%
# !pip install sklearn

# %%
# !pip install chembl_webresource_client

# %%
# %cd SMILESVecProteinRepresentation/
# Out:
# /content/SMILESVecProteinRepresentation

# %%
# %cd source/
# Out:
# /content/SMILESVecProteinRepresentation/source

# %%
# !python getsmilesvec.py drug.l8.chembl23.canon.ws20.txt
# Out:
# Constructing SMILES vectors..
# Done.

# %%
# !wget https://cmpe.boun.edu.tr/~hakime.ozturk/source/embeddings/drug.l8.chembl23.canon.ws20.txt
# Out:
# --2021-12-14 04:55:25--  https://cmpe.boun.edu.tr/~hakime.ozturk/source/embeddings/drug.l8.chembl23.canon.ws20.txt
# Resolving cmpe.boun.edu.tr (cmpe.boun.edu.tr)... 79.123.177.135
# Connecting to cmpe.boun.edu.tr (cmpe.boun.edu.tr)|79.123.177.135|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1138335612 (1.1G) [text/plain]
# Saving to: ‘drug.l8.chembl23.canon.ws20.txt’
#
# drug.l8.chembl23.ca 100%[===================>]   1.06G  2.31MB/s    in 7m 11s
#
# 2021-12-14 05:02:38 (2.52 MB/s) - ‘drug.l8.chembl23.canon.ws20.txt’ saved [1138335612/1138335612]

# %%
with open('smiles.vec', 'rb') as f:
    s = pickle.load(f, encoding='bytes')

# %%
import pickle

# %%
s
# Out:
# [[0.17827299791449486,
#   0.4806515867576787,
#   -0.0378217111880842,
#   -0.19539410723863462,
#   -0.03667181661646617,
#   0.41489631812529343,
#   0.639587340974494,
#   -0.012580739187174722,
#   -0.12409336579424378,
#   0.14356137174916894,
#   0.05972639702285003,
#   -0.4087755550924492,
#   -0.1660392607170108,
#   0.19565534096603332,
#   -0.032377920554656735,
#   0.17553779076000578,
#   0.04121321258380225,
#   -0.31407676431301396,
#   0.25811731959938217,
#   -0.1974331598214217,
#   -0.0406801838574833,
#   -0.09712447328983169,
#   -0.020806737587248023,
#   -0.2206489441236236,
#   -0.23748399949583568,
#   0.6317996037633795,
#   -0.004878817273205833,
#   0.6844029450593027,
#   -0.011751262961249603,
#   -0.49031270753690287,
#   0.16075194823114494,
#   0.42906434745772887,
#   0.17887797419864096,
#   0.6432812098462722,
#   -0.02420715900677207,
#   -0.7252252954303434,
#   0.26332536712288857,
#   0.04624310415238142,
#   -0.027905346531617015,
# ...
