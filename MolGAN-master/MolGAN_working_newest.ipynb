# %%
# !git clone https://github.com/dssikdar/asdrp_QGAN/
# Out:
# Cloning into 'asdrp_QGAN'...
# remote: Enumerating objects: 219, done.
# remote: Counting objects: 100% (219/219), done.
# remote: Compressing objects: 100% (196/196), done.
# remote: Total 219 (delta 96), reused 27 (delta 10), pack-reused 0
# Receiving objects: 100% (219/219), 40.74 MiB | 6.18 MiB/s, done.
# Resolving deltas: 100% (96/96), done.

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=a54050436c7a21d645112cb063ae4cd9a98d86f2dbec86b298a6bb2ac6e89336
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
import wget

# %%
wget.download('http://molcyclegan.ardigen.com/250k_rndm_zinc_drugs_clean_3_canonized.csv')
wget.download('http://molcyclegan.ardigen.com/X_JTVAE_250k_rndm_zinc.csv')
# Out:
# 'X_JTVAE_250k_rndm_zinc.csv'

# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import torch.optim as optim

# %%
data = pd.read_csv('X_JTVAE_250k_rndm_zinc.csv')

# %%
smiles = data['SMILES'].values
np.savetxt(r'smiles.txt', smiles, fmt='%s')

# %%
class Discriminator(nn.Module):
    def __init__(self, data_shape):
        super(Discriminator, self).__init__()
        self.data_shape = data_shape

        self.model = nn.Sequential(
            nn.Linear(int(np.prod(self.data_shape)), 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
        )

    def forward(self, mol):
        validity = self.model(mol)
        return validity

    def save(self, path):
        save_dict = {
            'model': self.model.state_dict(),
            'data_shape': self.data_shape,
        }
        torch.save(save_dict, path)
        return

    @staticmethod
    def load(path):
        save_dict = torch.load(path)
        D = Discriminator(save_dict['data_shape'])
        D.model.load_state_dict(save_dict["model"])

        return D

# %%
import torch.nn as nn
import numpy as np
import torch


class Generator(nn.Module):
    def __init__(self, data_shape, latent_dim=None):
        super(Generator, self).__init__()
        self.data_shape = data_shape

        # latent dim of the generator is one of the hyperparams.
        # by default it is set to the prod of data_shapes
        self.latent_dim = int(np.prod(self.data_shape)) if latent_dim is None else latent_dim

        def block(in_feat, out_feat, normalize=True):
            layers = [nn.Linear(in_feat, out_feat)]
            if normalize:
                layers.append(nn.BatchNorm1d(out_feat, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        self.model = nn.Sequential(
            *block(self.latent_dim, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, int(np.prod(self.data_shape))),
            # nn.Tanh() # expecting latent vectors to be not normalized
        )

    def forward(self, z):
        out = self.model(z)
        return out

    def save(self, path):
        save_dict = {
            'latent_dim': self.latent_dim,
            'model': self.model.state_dict(),
            'data_shape': self.data_shape,
        }
        torch.save(save_dict, path)

        return

    @staticmethod
    def load(path):
        save_dict = torch.load(path)
        G = Generator(save_dict['data_shape'], latent_dim=save_dict['latent_dim'])
        G.model.load_state_dict(save_dict["model"])

        return G

# %%
class Sampler(object):
    """
    Sampling the mols the generator.
    All scripts should use this class for sampling.
    """

    def __init__(self, generator: Generator):
        self.set_generator(generator)

    def set_generator(self, generator):
        self.G = generator

    def sample(self, n):
        # Sample noise as generator input
        z = torch.cuda.FloatTensor(np.random.uniform(-1, 1, (n, self.G.latent_dim)))
        #z = torch.FloatTensor(np.random.uniform(-1, 1, (n, self.G.latent_dim)))
        # Generate a batch of mols
        return self.G(z)

# %%
from torch.utils import data
import json
import numpy as np


class LatentMolsDataset(data.Dataset):
    def __init__(self, latent_space_mols):
        self.data = latent_space_mols

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        return self.data[index]

# %%
import pickle
import os
import torch
import torch.autograd as autograd
import numpy as np
import json
import time
import sys


class TrainModelRunner:
    # Loss weight for gradient penalty
    lambda_gp = 10

    def __init__(self, input_data_path, output_model_folder, decode_mols_save_path='', n_epochs=2000, starting_epoch=1,
                 batch_size=2500, lr=0.0002, b1=0.5, b2=0.999,  n_critic=5,
                 save_interval=1000, sample_after_training=30000, message=""):
        self.message = message

        # init params
        self.input_data_path = input_data_path
        self.output_model_folder = output_model_folder
        self.n_epochs = n_epochs
        self.starting_epoch = starting_epoch
        self.batch_size = batch_size
        self.lr = lr
        self.b1 = b1
        self.b2 = b2
        self.n_critic = n_critic
        self.save_interval = save_interval
        self.sample_after_training = sample_after_training
        self.decode_mols_save_path = decode_mols_save_path

        # initialize dataloader
        smiles_lat = pd.read_csv(input_data_path)
        latent_space_mols = smiles_lat.drop('SMILES', axis=1).values
        latent_space_mols = latent_space_mols.reshape(latent_space_mols.shape[0], 56)

        self.dataloader = torch.utils.data.DataLoader(LatentMolsDataset(latent_space_mols), shuffle=True,
                                                      batch_size=self.batch_size, drop_last=True)

        # load discriminator
        discriminator_name = 'discriminator.txt' if self.starting_epoch == 1 else str(
            self.starting_epoch) + '_discriminator.txt'
        discriminator_path = os.path.join(output_model_folder, discriminator_name)
        #self.D = Discriminator.load(discriminator_path)
        self.D = Discriminator(latent_space_mols[0].shape)
        # load generator
        generator_name = 'generator.txt' if self.starting_epoch == 1 else str(
            self.starting_epoch) + '_generator.txt'
        generator_path = os.path.join(output_model_folder, generator_name)
        #self.G = Generator.load(generator_path)
        self.G = Generator(latent_space_mols[0].shape)
        # initialize sampler
        self.Sampler = Sampler(self.G)

        # initialize optimizer
        self.optimizer_G = torch.optim.Adam(self.G.parameters(), lr=self.lr, betas=(self.b1, self.b2))
        self.optimizer_D = torch.optim.Adam(self.D.parameters(), lr=self.lr, betas=(self.b1, self.b2))

        # Tensor
        cuda = True if torch.cuda.is_available() else False
        if cuda:
            self.G.cuda()
            self.D.cuda()
        self.Tensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor

    def run(self):

        print("Run began.")
        print("Message: %s" % self.message)
        sys.stdout.flush()

        batches_done = 0
        disc_loss_log = []
        g_loss_log = []

        for epoch in range(self.starting_epoch, self.n_epochs + self.starting_epoch):
            disc_loss_per_batch = []
            g_loss_log_per_batch = []
            for i, real_mols in enumerate(self.dataloader):

                # Configure input
                real_mols = real_mols.type(self.Tensor)
                # real_mols = np.squeeze(real_mols, axis=1)

                # ---------------------
                #  Train Discriminator
                # ---------------------

                self.optimizer_D.zero_grad()

                # Generate a batch of mols from noise
                fake_mols = self.Sampler.sample(real_mols.shape[0])

                # Real mols
                real_validity = self.D(real_mols)
                # Fake mols
                fake_validity = self.D(fake_mols)
                # Gradient penalty
                gradient_penalty = self.compute_gradient_penalty(real_mols.data, fake_mols.data)
                # Adversarial loss
                d_loss = -torch.mean(real_validity) + torch.mean(fake_validity) + self.lambda_gp * gradient_penalty
                disc_loss_per_batch.append(d_loss.item())

                d_loss.backward()
                self.optimizer_D.step()
                self.optimizer_G.zero_grad()

                # Train the generator every n_critic steps
                if i % self.n_critic == 0:
                    # -----------------
                    #  Train Generator
                    # -----------------

                    # Generate a batch of mols
                    fake_mols = self.Sampler.sample(real_mols.shape[0])
                    # Loss measures generator's ability to fool the discriminator
                    # Train on fake images
                    fake_validity = self.D(fake_mols)
                    g_loss = -torch.mean(fake_validity)
                    g_loss_log_per_batch.append(g_loss.item())

                    g_loss.backward()
                    self.optimizer_G.step()

                    batches_done += self.n_critic

                # If last batch in the set
                if i == len(self.dataloader) - 1:
                    if epoch % self.save_interval == 0:
                        generator_save_path = os.path.join(self.output_model_folder,
                                                           str(epoch) + '_generator.txt')
                        discriminator_save_path = os.path.join(self.output_model_folder,
                                                               str(epoch) + '_discriminator.txt')
                        self.G.save(generator_save_path)
                        self.D.save(discriminator_save_path)

                    disc_loss_log.append([time.time(), epoch, np.mean(disc_loss_per_batch)])
                    g_loss_log.append([time.time(), epoch, np.mean(g_loss_log_per_batch)])

                    # Print and log
                    print(
                        "[Epoch %d/%d]  [Disc loss: %f] [Gen loss: %f] "
                        % (epoch, self.n_epochs + self.starting_epoch, disc_loss_log[-1][2], g_loss_log[-1][2])
                    )
                    sys.stdout.flush()

        # log the losses
        with open(os.path.join(self.output_model_folder, 'disc_loss.json'), 'w') as json_file:
            json.dump(disc_loss_log, json_file)
        with open(os.path.join(self.output_model_folder, 'gen_loss.json'), 'w') as json_file:
            json.dump(g_loss_log, json_file)

        # Sampling after training
        if self.sample_after_training > 0:
            print("Training finished. Generating sample of latent vectors")
            # sampling mode
            torch.no_grad()
            self.G.eval()

            S = Sampler(generator=self.G)
            latent = S.sample(self.sample_after_training)
            latent = latent.detach().cpu().numpy().tolist()

            sampled_mols_save_path = os.path.join(self.output_model_folder, 'sampled')
            np.save(sampled_mols_save_path+f'_epoch{epoch}', latent)

            # decoding sampled mols

        return 0

    def compute_gradient_penalty(self, real_samples, fake_samples):
        """Calculates the gradient penalty loss for WGAN GP"""
        # Random weight term for interpolation between real and fake samples
        alpha = self.Tensor(np.random.random((real_samples.size(0), 1)))

        # Get random interpolation between real and fake samples
        interpolates = (alpha * real_samples + ((1 - alpha) * fake_samples)).requires_grad_(True)
        d_interpolates = self.D(interpolates)
        fake = self.Tensor(real_samples.shape[0], 1).fill_(1.0)

        # Get gradient w.r.t. interpolates
        gradients = autograd.grad(
            outputs=d_interpolates,
            inputs=interpolates,
            grad_outputs=fake,
            create_graph=True,
            retain_graph=True,
            only_inputs=True,
        )[0]
        gradients = gradients.view(gradients.size(0), -1)
        gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean()

        return gradient_penalty

# %%
trainer = TrainModelRunner('X_JTVAE_250k_rndm_zinc.csv', output_model_folder='asdrp_QGAN/MolGAN-master/sussyoutput', starting_epoch=200,
                           save_interval=100, message='Starting training', batch_size=2000)

# %%
trainer.run()
# Out:
# Run began.
# Message: Starting training
# [Epoch 200/2200]  [Disc loss: -6.147428] [Gen loss: -0.772320]
# [Epoch 201/2200]  [Disc loss: -11.277042] [Gen loss: -0.600219]
# [Epoch 202/2200]  [Disc loss: -9.544904] [Gen loss: -0.734304]
# [Epoch 203/2200]  [Disc loss: -9.059465] [Gen loss: -0.666370]
# [Epoch 204/2200]  [Disc loss: -8.377227] [Gen loss: -0.814009]
# [Epoch 205/2200]  [Disc loss: -7.747880] [Gen loss: -1.014137]
# [Epoch 206/2200]  [Disc loss: -7.186549] [Gen loss: -0.921502]
# [Epoch 207/2200]  [Disc loss: -6.730028] [Gen loss: -0.854973]
# [Epoch 208/2200]  [Disc loss: -6.565425] [Gen loss: -0.742636]
# [Epoch 209/2200]  [Disc loss: -6.468088] [Gen loss: -0.506219]
# [Epoch 210/2200]  [Disc loss: -6.420172] [Gen loss: -0.623610]
# [Epoch 211/2200]  [Disc loss: -6.334639] [Gen loss: -0.640086]
# [Epoch 212/2200]  [Disc loss: -6.042214] [Gen loss: -0.907074]
# [Epoch 213/2200]  [Disc loss: -5.801292] [Gen loss: -1.164438]
# [Epoch 214/2200]  [Disc loss: -5.593796] [Gen loss: -0.930459]
# [Epoch 215/2200]  [Disc loss: -5.487094] [Gen loss: -0.802126]
# [Epoch 216/2200]  [Disc loss: -5.295337] [Gen loss: -0.675241]
# [Epoch 217/2200]  [Disc loss: -5.319605] [Gen loss: -0.796562]
# [Epoch 218/2200]  [Disc loss: -5.329968] [Gen loss: -0.886041]
# [Epoch 219/2200]  [Disc loss: -5.057513] [Gen loss: -0.814775]
# [Epoch 220/2200]  [Disc loss: -5.137658] [Gen loss: -0.882273]
# [Epoch 221/2200]  [Disc loss: -4.879934] [Gen loss: -0.885347]
# [Epoch 222/2200]  [Disc loss: -4.576929] [Gen loss: -1.140567]
# [Epoch 223/2200]  [Disc loss: -4.356355] [Gen loss: -0.979414]
# [Epoch 224/2200]  [Disc loss: -4.216683] [Gen loss: -1.022808]
# [Epoch 225/2200]  [Disc loss: -4.013152] [Gen loss: -0.484124]
# [Epoch 226/2200]  [Disc loss: -3.979245] [Gen loss: -0.600091]
# [Epoch 227/2200]  [Disc loss: -3.816992] [Gen loss: -0.350625]
# [Epoch 228/2200]  [Disc loss: -3.851315] [Gen loss: -0.397489]
# [Epoch 229/2200]  [Disc loss: -3.639797] [Gen loss: -0.573539]
# [Epoch 230/2200]  [Disc loss: -3.535181] [Gen loss: -0.374006]
# [Epoch 231/2200]  [Disc loss: -3.430467] [Gen loss: -0.070289]
# [Epoch 232/2200]  [Disc loss: -3.425361] [Gen loss: -0.069670]
# [Epoch 233/2200]  [Disc loss: -3.400313] [Gen loss: 0.701178]
# [Epoch 234/2200]  [Disc loss: -3.418992] [Gen loss: 0.705012]
# [Epoch 235/2200]  [Disc loss: -3.475550] [Gen loss: 0.329844]
# [Epoch 236/2200]  [Disc loss: -3.624029] [Gen loss: 0.048141]
# [Epoch 237/2200]  [Disc loss: -3.470997] [Gen loss: 0.024520]
# [Epoch 238/2200]  [Disc loss: -3.385266] [Gen loss: 0.362394]
# [Epoch 239/2200]  [Disc loss: -3.394324] [Gen loss: 0.140656]
# [Epoch 240/2200]  [Disc loss: -3.222475] [Gen loss: 0.364314]
# [Epoch 241/2200]  [Disc loss: -3.045735] [Gen loss: -0.238419]
# [Epoch 242/2200]  [Disc loss: -3.091803] [Gen loss: 0.251882]
# [Epoch 243/2200]  [Disc loss: -3.093379] [Gen loss: 0.354783]
# [Epoch 244/2200]  [Disc loss: -3.196079] [Gen loss: 0.131311]
# [Epoch 245/2200]  [Disc loss: -3.200509] [Gen loss: 0.155748]
# [Epoch 246/2200]  [Disc loss: -3.020196] [Gen loss: 0.121062]
# [Epoch 247/2200]  [Disc loss: -2.950749] [Gen loss: 0.207725]
# [Epoch 248/2200]  [Disc loss: -3.022321] [Gen loss: -0.321523]
# [Epoch 249/2200]  [Disc loss: -2.782552] [Gen loss: -0.045549]
# [Epoch 250/2200]  [Disc loss: -2.761349] [Gen loss: -0.438117]
# [Epoch 251/2200]  [Disc loss: -2.646926] [Gen loss: -0.243011]
# [Epoch 252/2200]  [Disc loss: -2.611019] [Gen loss: -0.787741]
# [Epoch 253/2200]  [Disc loss: -2.328175] [Gen loss: -0.215690]
# [Epoch 254/2200]  [Disc loss: -2.333296] [Gen loss: 0.166569]
# [Epoch 255/2200]  [Disc loss: -2.380032] [Gen loss: -0.315779]
# [Epoch 256/2200]  [Disc loss: -2.291318] [Gen loss: -0.069806]
# [Epoch 257/2200]  [Disc loss: -2.103128] [Gen loss: 0.057911]
# [Epoch 258/2200]  [Disc loss: -2.114248] [Gen loss: -0.223060]
# [Epoch 259/2200]  [Disc loss: -2.131630] [Gen loss: -0.087727]
# [Epoch 260/2200]  [Disc loss: -2.131806] [Gen loss: 0.348388]
# [Epoch 261/2200]  [Disc loss: -2.034728] [Gen loss: -0.167767]
# [Epoch 262/2200]  [Disc loss: -2.144178] [Gen loss: -0.563168]
# [Epoch 263/2200]  [Disc loss: -2.100054] [Gen loss: -0.643602]
# [Epoch 264/2200]  [Disc loss: -2.024887] [Gen loss: -0.789817]
# [Epoch 265/2200]  [Disc loss: -2.019115] [Gen loss: -0.678130]
# [Epoch 266/2200]  [Disc loss: -2.140196] [Gen loss: -1.586289]
# [Epoch 267/2200]  [Disc loss: -2.126443] [Gen loss: -1.462277]
# [Epoch 268/2200]  [Disc loss: -2.072247] [Gen loss: -1.889941]
# [Epoch 269/2200]  [Disc loss: -1.985084] [Gen loss: -1.681997]
# [Epoch 270/2200]  [Disc loss: -2.046418] [Gen loss: -2.083850]
# [Epoch 271/2200]  [Disc loss: -2.002416] [Gen loss: -2.202570]
# [Epoch 272/2200]  [Disc loss: -2.014001] [Gen loss: -2.428322]
# [Epoch 273/2200]  [Disc loss: -1.963261] [Gen loss: -2.580042]
# [Epoch 274/2200]  [Disc loss: -1.920809] [Gen loss: -3.186949]
# [Epoch 275/2200]  [Disc loss: -1.939575] [Gen loss: -3.298457]
# [Epoch 276/2200]  [Disc loss: -1.904487] [Gen loss: -3.832400]
# [Epoch 277/2200]  [Disc loss: -1.758243] [Gen loss: -3.783086]
# [Epoch 278/2200]  [Disc loss: -1.776729] [Gen loss: -4.143993]
# [Epoch 279/2200]  [Disc loss: -1.824904] [Gen loss: -4.056180]
# [Epoch 280/2200]  [Disc loss: -1.804895] [Gen loss: -4.155562]
# [Epoch 281/2200]  [Disc loss: -1.719526] [Gen loss: -4.390873]
# [Epoch 282/2200]  [Disc loss: -1.698832] [Gen loss: -4.510317]
# [Epoch 283/2200]  [Disc loss: -1.726818] [Gen loss: -4.690166]
# [Epoch 284/2200]  [Disc loss: -1.656531] [Gen loss: -4.902456]
# [Epoch 285/2200]  [Disc loss: -1.588927] [Gen loss: -5.167848]
# [Epoch 286/2200]  [Disc loss: -1.562347] [Gen loss: -5.471774]
# [Epoch 287/2200]  [Disc loss: -1.550158] [Gen loss: -5.175435]
# [Epoch 288/2200]  [Disc loss: -1.506747] [Gen loss: -5.427459]
# [Epoch 289/2200]  [Disc loss: -1.491892] [Gen loss: -5.901055]
# [Epoch 290/2200]  [Disc loss: -1.465212] [Gen loss: -6.242329]
# [Epoch 291/2200]  [Disc loss: -1.433933] [Gen loss: -6.058423]
# [Epoch 292/2200]  [Disc loss: -1.446468] [Gen loss: -6.093133]
# [Epoch 293/2200]  [Disc loss: -1.433451] [Gen loss: -6.006294]
# [Epoch 294/2200]  [Disc loss: -1.460497] [Gen loss: -6.351086]
# [Epoch 295/2200]  [Disc loss: -1.386939] [Gen loss: -6.506216]
# [Epoch 296/2200]  [Disc loss: -1.338684] [Gen loss: -6.429898]
# [Epoch 297/2200]  [Disc loss: -1.369599] [Gen loss: -6.472023]
# [Epoch 298/2200]  [Disc loss: -1.315908] [Gen loss: -6.557269]
# [Epoch 299/2200]  [Disc loss: -1.314700] [Gen loss: -6.362188]
# [Epoch 300/2200]  [Disc loss: -1.312959] [Gen loss: -6.284750]
# [Epoch 301/2200]  [Disc loss: -1.287596] [Gen loss: -6.403525]
# [Epoch 302/2200]  [Disc loss: -1.312620] [Gen loss: -6.695986]
# [Epoch 303/2200]  [Disc loss: -1.361061] [Gen loss: -6.915991]
# [Epoch 304/2200]  [Disc loss: -1.332194] [Gen loss: -6.769660]
# [Epoch 305/2200]  [Disc loss: -1.305501] [Gen loss: -6.633972]
# [Epoch 306/2200]  [Disc loss: -1.259253] [Gen loss: -6.043677]
# [Epoch 307/2200]  [Disc loss: -1.295525] [Gen loss: -6.302669]
# [Epoch 308/2200]  [Disc loss: -1.266564] [Gen loss: -6.178815]
# [Epoch 309/2200]  [Disc loss: -1.284907] [Gen loss: -5.790800]
# [Epoch 310/2200]  [Disc loss: -1.252748] [Gen loss: -5.747532]
# [Epoch 311/2200]  [Disc loss: -1.199702] [Gen loss: -5.460228]
# [Epoch 312/2200]  [Disc loss: -1.236877] [Gen loss: -5.733155]
# [Epoch 313/2200]  [Disc loss: -1.228400] [Gen loss: -5.488440]
# [Epoch 314/2200]  [Disc loss: -1.183537] [Gen loss: -5.460728]
# [Epoch 315/2200]  [Disc loss: -1.155688] [Gen loss: -5.077117]
# [Epoch 316/2200]  [Disc loss: -1.160841] [Gen loss: -4.937046]
# [Epoch 317/2200]  [Disc loss: -1.163041] [Gen loss: -4.924233]
# [Epoch 318/2200]  [Disc loss: -1.184437] [Gen loss: -5.184406]
# [Epoch 319/2200]  [Disc loss: -1.140293] [Gen loss: -5.050203]
# [Epoch 320/2200]  [Disc loss: -1.127831] [Gen loss: -4.858789]
# [Epoch 321/2200]  [Disc loss: -1.100066] [Gen loss: -4.817544]
# [Epoch 322/2200]  [Disc loss: -1.096404] [Gen loss: -4.433476]
# [Epoch 323/2200]  [Disc loss: -1.082597] [Gen loss: -4.954098]
# [Epoch 324/2200]  [Disc loss: -1.058897] [Gen loss: -4.559926]
# [Epoch 325/2200]  [Disc loss: -1.063496] [Gen loss: -4.624019]
# [Epoch 326/2200]  [Disc loss: -1.043662] [Gen loss: -4.264456]
# [Epoch 327/2200]  [Disc loss: -1.020457] [Gen loss: -4.352074]
# [Epoch 328/2200]  [Disc loss: -1.012895] [Gen loss: -4.499089]
# [Epoch 329/2200]  [Disc loss: -0.992714] [Gen loss: -4.422692]
# [Epoch 330/2200]  [Disc loss: -0.974404] [Gen loss: -4.431430]
# [Epoch 331/2200]  [Disc loss: -0.977363] [Gen loss: -4.185032]
# [Epoch 332/2200]  [Disc loss: -0.953465] [Gen loss: -4.239973]
# [Epoch 333/2200]  [Disc loss: -0.929193] [Gen loss: -4.337566]
# [Epoch 334/2200]  [Disc loss: -0.931281] [Gen loss: -4.055040]
# [Epoch 335/2200]  [Disc loss: -0.949678] [Gen loss: -4.238618]
# [Epoch 336/2200]  [Disc loss: -0.912521] [Gen loss: -4.264744]
# [Epoch 337/2200]  [Disc loss: -0.914455] [Gen loss: -4.376841]
# [Epoch 338/2200]  [Disc loss: -0.933380] [Gen loss: -4.029614]
# [Epoch 339/2200]  [Disc loss: -0.900501] [Gen loss: -4.200794]
# [Epoch 340/2200]  [Disc loss: -0.902648] [Gen loss: -3.966029]
# [Epoch 341/2200]  [Disc loss: -0.883455] [Gen loss: -3.949009]
# [Epoch 342/2200]  [Disc loss: -0.888406] [Gen loss: -4.170408]
# [Epoch 343/2200]  [Disc loss: -0.869987] [Gen loss: -4.082331]
# [Epoch 344/2200]  [Disc loss: -0.888741] [Gen loss: -4.192958]
# [Epoch 345/2200]  [Disc loss: -0.882193] [Gen loss: -3.670610]
# [Epoch 346/2200]  [Disc loss: -0.881682] [Gen loss: -4.148175]
# [Epoch 347/2200]  [Disc loss: -0.852817] [Gen loss: -4.349088]
# [Epoch 348/2200]  [Disc loss: -0.869094] [Gen loss: -4.102886]
# [Epoch 349/2200]  [Disc loss: -0.846176] [Gen loss: -3.985672]
# [Epoch 350/2200]  [Disc loss: -0.864801] [Gen loss: -3.968295]
# [Epoch 351/2200]  [Disc loss: -0.852481] [Gen loss: -4.122330]
# [Epoch 352/2200]  [Disc loss: -0.846953] [Gen loss: -3.704174]
# [Epoch 353/2200]  [Disc loss: -0.843150] [Gen loss: -4.058035]
# [Epoch 354/2200]  [Disc loss: -0.831487] [Gen loss: -3.883045]
# [Epoch 355/2200]  [Disc loss: -0.850405] [Gen loss: -3.848205]
# [Epoch 356/2200]  [Disc loss: -0.825943] [Gen loss: -3.872343]
# [Epoch 357/2200]  [Disc loss: -0.836328] [Gen loss: -3.812800]
# [Epoch 358/2200]  [Disc loss: -0.823531] [Gen loss: -4.017036]
# [Epoch 359/2200]  [Disc loss: -0.807799] [Gen loss: -3.655935]
# [Epoch 360/2200]  [Disc loss: -0.832014] [Gen loss: -3.781375]
# [Epoch 361/2200]  [Disc loss: -0.825787] [Gen loss: -3.619844]
# [Epoch 362/2200]  [Disc loss: -0.822479] [Gen loss: -3.780085]
# [Epoch 363/2200]  [Disc loss: -0.824626] [Gen loss: -3.622272]
# [Epoch 364/2200]  [Disc loss: -0.817707] [Gen loss: -3.917584]
# [Epoch 365/2200]  [Disc loss: -0.818725] [Gen loss: -3.723362]
# [Epoch 366/2200]  [Disc loss: -0.830712] [Gen loss: -3.876155]
# [Epoch 367/2200]  [Disc loss: -0.821982] [Gen loss: -3.587525]
# [Epoch 368/2200]  [Disc loss: -0.829977] [Gen loss: -3.911301]
# [Epoch 369/2200]  [Disc loss: -0.828885] [Gen loss: -3.932046]
# [Epoch 370/2200]  [Disc loss: -0.832771] [Gen loss: -3.788788]
# [Epoch 371/2200]  [Disc loss: -0.837717] [Gen loss: -3.831966]
# [Epoch 372/2200]  [Disc loss: -0.813338] [Gen loss: -3.702133]
# [Epoch 373/2200]  [Disc loss: -0.819788] [Gen loss: -4.066414]
# [Epoch 374/2200]  [Disc loss: -0.837808] [Gen loss: -4.227406]
# [Epoch 375/2200]  [Disc loss: -0.825039] [Gen loss: -3.857659]
# [Epoch 376/2200]  [Disc loss: -0.843768] [Gen loss: -4.361745]
# [Epoch 377/2200]  [Disc loss: -0.826185] [Gen loss: -3.821449]
# [Epoch 378/2200]  [Disc loss: -0.832445] [Gen loss: -4.071953]
# [Epoch 379/2200]  [Disc loss: -0.840023] [Gen loss: -4.056028]
# [Epoch 380/2200]  [Disc loss: -0.834375] [Gen loss: -4.006774]
# [Epoch 381/2200]  [Disc loss: -0.844610] [Gen loss: -4.148179]
# [Epoch 382/2200]  [Disc loss: -0.834729] [Gen loss: -4.209478]
# [Epoch 383/2200]  [Disc loss: -0.837511] [Gen loss: -4.203743]
# [Epoch 384/2200]  [Disc loss: -0.831934] [Gen loss: -4.136189]
# [Epoch 385/2200]  [Disc loss: -0.836803] [Gen loss: -4.347661]
# [Epoch 386/2200]  [Disc loss: -0.846161] [Gen loss: -4.470575]
# [Epoch 387/2200]  [Disc loss: -0.835318] [Gen loss: -4.042012]
# [Epoch 388/2200]  [Disc loss: -0.841045] [Gen loss: -4.431694]
# [Epoch 389/2200]  [Disc loss: -0.817804] [Gen loss: -4.289160]
# [Epoch 390/2200]  [Disc loss: -0.841993] [Gen loss: -4.521344]
# [Epoch 391/2200]  [Disc loss: -0.839277] [Gen loss: -4.697519]
# [Epoch 392/2200]  [Disc loss: -0.838573] [Gen loss: -4.569836]
# [Epoch 393/2200]  [Disc loss: -0.833329] [Gen loss: -4.553112]
# [Epoch 394/2200]  [Disc loss: -0.841198] [Gen loss: -4.724033]
# [Epoch 395/2200]  [Disc loss: -0.834764] [Gen loss: -4.695467]
# [Epoch 396/2200]  [Disc loss: -0.824538] [Gen loss: -4.760902]
# [Epoch 397/2200]  [Disc loss: -0.831864] [Gen loss: -4.556063]
# [Epoch 398/2200]  [Disc loss: -0.825297] [Gen loss: -4.833251]
# [Epoch 399/2200]  [Disc loss: -0.832289] [Gen loss: -4.711805]
# [Epoch 400/2200]  [Disc loss: -0.830549] [Gen loss: -4.564934]
# [Epoch 401/2200]  [Disc loss: -0.823669] [Gen loss: -4.599571]
# [Epoch 402/2200]  [Disc loss: -0.820796] [Gen loss: -4.931499]
# [Epoch 403/2200]  [Disc loss: -0.834568] [Gen loss: -4.936627]
# [Epoch 404/2200]  [Disc loss: -0.832353] [Gen loss: -4.988613]
# [Epoch 405/2200]  [Disc loss: -0.823974] [Gen loss: -4.871589]
# [Epoch 406/2200]  [Disc loss: -0.812597] [Gen loss: -4.581201]
# [Epoch 407/2200]  [Disc loss: -0.829988] [Gen loss: -4.629719]
# [Epoch 408/2200]  [Disc loss: -0.817031] [Gen loss: -4.859451]
# [Epoch 409/2200]  [Disc loss: -0.813797] [Gen loss: -4.840468]
# [Epoch 410/2200]  [Disc loss: -0.819593] [Gen loss: -4.743550]
# [Epoch 411/2200]  [Disc loss: -0.810141] [Gen loss: -4.644119]
# [Epoch 412/2200]  [Disc loss: -0.812908] [Gen loss: -4.768376]
# [Epoch 413/2200]  [Disc loss: -0.808275] [Gen loss: -4.435774]
# [Epoch 414/2200]  [Disc loss: -0.802341] [Gen loss: -4.469859]
# [Epoch 415/2200]  [Disc loss: -0.808765] [Gen loss: -4.717882]
# [Epoch 416/2200]  [Disc loss: -0.801883] [Gen loss: -4.552880]
# [Epoch 417/2200]  [Disc loss: -0.788211] [Gen loss: -4.521027]
# [Epoch 418/2200]  [Disc loss: -0.801075] [Gen loss: -4.568958]
# [Epoch 419/2200]  [Disc loss: -0.802620] [Gen loss: -4.592024]
# [Epoch 420/2200]  [Disc loss: -0.795511] [Gen loss: -4.680019]
# [Epoch 421/2200]  [Disc loss: -0.798596] [Gen loss: -4.529059]
# [Epoch 422/2200]  [Disc loss: -0.787971] [Gen loss: -4.321301]
# [Epoch 423/2200]  [Disc loss: -0.790464] [Gen loss: -4.441909]
# [Epoch 424/2200]  [Disc loss: -0.789146] [Gen loss: -4.382417]
# [Epoch 425/2200]  [Disc loss: -0.790418] [Gen loss: -4.333595]
# [Epoch 426/2200]  [Disc loss: -0.789735] [Gen loss: -4.267923]
# [Epoch 427/2200]  [Disc loss: -0.786622] [Gen loss: -4.331286]
# [Epoch 428/2200]  [Disc loss: -0.781786] [Gen loss: -4.183734]
# [Epoch 429/2200]  [Disc loss: -0.784532] [Gen loss: -4.122946]
# [Epoch 430/2200]  [Disc loss: -0.792753] [Gen loss: -4.057721]
# [Epoch 431/2200]  [Disc loss: -0.774219] [Gen loss: -4.151322]
# [Epoch 432/2200]  [Disc loss: -0.767588] [Gen loss: -3.835109]
# [Epoch 433/2200]  [Disc loss: -0.776103] [Gen loss: -4.043406]
# [Epoch 434/2200]  [Disc loss: -0.778504] [Gen loss: -3.965744]
# [Epoch 435/2200]  [Disc loss: -0.780220] [Gen loss: -3.850380]
# [Epoch 436/2200]  [Disc loss: -0.773850] [Gen loss: -4.159889]
# [Epoch 437/2200]  [Disc loss: -0.772839] [Gen loss: -3.794001]
# [Epoch 438/2200]  [Disc loss: -0.768519] [Gen loss: -3.943642]
# [Epoch 439/2200]  [Disc loss: -0.778997] [Gen loss: -4.079923]
# [Epoch 440/2200]  [Disc loss: -0.766480] [Gen loss: -3.846316]
# [Epoch 441/2200]  [Disc loss: -0.759657] [Gen loss: -3.695762]
# [Epoch 442/2200]  [Disc loss: -0.770675] [Gen loss: -3.792923]
# [Epoch 443/2200]  [Disc loss: -0.770727] [Gen loss: -3.902121]
# [Epoch 444/2200]  [Disc loss: -0.772569] [Gen loss: -3.717903]
# [Epoch 445/2200]  [Disc loss: -0.774015] [Gen loss: -3.860241]
# [Epoch 446/2200]  [Disc loss: -0.762202] [Gen loss: -3.394706]
# [Epoch 447/2200]  [Disc loss: -0.759424] [Gen loss: -3.552986]
# [Epoch 448/2200]  [Disc loss: -0.767003] [Gen loss: -3.610422]
# [Epoch 449/2200]  [Disc loss: -0.770466] [Gen loss: -3.588644]
# [Epoch 450/2200]  [Disc loss: -0.757060] [Gen loss: -3.557269]
# [Epoch 451/2200]  [Disc loss: -0.759356] [Gen loss: -3.404242]
# [Epoch 452/2200]  [Disc loss: -0.762039] [Gen loss: -3.272680]
# [Epoch 453/2200]  [Disc loss: -0.744691] [Gen loss: -3.401654]
# [Epoch 454/2200]  [Disc loss: -0.762891] [Gen loss: -3.579485]
# [Epoch 455/2200]  [Disc loss: -0.756889] [Gen loss: -3.210595]
# [Epoch 456/2200]  [Disc loss: -0.758219] [Gen loss: -3.299169]
# [Epoch 457/2200]  [Disc loss: -0.750285] [Gen loss: -3.151851]
# [Epoch 458/2200]  [Disc loss: -0.748001] [Gen loss: -3.188777]
# [Epoch 459/2200]  [Disc loss: -0.751777] [Gen loss: -3.317483]
# [Epoch 460/2200]  [Disc loss: -0.755196] [Gen loss: -3.382222]
# [Epoch 461/2200]  [Disc loss: -0.747714] [Gen loss: -3.135235]
# [Epoch 462/2200]  [Disc loss: -0.753952] [Gen loss: -3.122990]
# [Epoch 463/2200]  [Disc loss: -0.745773] [Gen loss: -2.967631]
# [Epoch 464/2200]  [Disc loss: -0.744466] [Gen loss: -2.944849]
# [Epoch 465/2200]  [Disc loss: -0.757286] [Gen loss: -3.293909]
# [Epoch 466/2200]  [Disc loss: -0.744726] [Gen loss: -2.948423]
# [Epoch 467/2200]  [Disc loss: -0.752960] [Gen loss: -2.872205]
# [Epoch 468/2200]  [Disc loss: -0.748291] [Gen loss: -2.991667]
# [Epoch 469/2200]  [Disc loss: -0.754884] [Gen loss: -3.059848]
# [Epoch 470/2200]  [Disc loss: -0.750452] [Gen loss: -2.879160]
# [Epoch 471/2200]  [Disc loss: -0.742685] [Gen loss: -2.707533]
# [Epoch 472/2200]  [Disc loss: -0.745462] [Gen loss: -2.812288]
# [Epoch 473/2200]  [Disc loss: -0.745744] [Gen loss: -2.980375]
# [Epoch 474/2200]  [Disc loss: -0.746018] [Gen loss: -2.845190]
# [Epoch 475/2200]  [Disc loss: -0.741211] [Gen loss: -2.975747]
# [Epoch 476/2200]  [Disc loss: -0.743015] [Gen loss: -2.865420]
# [Epoch 477/2200]  [Disc loss: -0.737852] [Gen loss: -2.853286]
# [Epoch 478/2200]  [Disc loss: -0.742519] [Gen loss: -2.737905]
# [Epoch 479/2200]  [Disc loss: -0.739336] [Gen loss: -2.812782]
# [Epoch 480/2200]  [Disc loss: -0.739516] [Gen loss: -2.882150]
# [Epoch 481/2200]  [Disc loss: -0.736709] [Gen loss: -2.708556]
# [Epoch 482/2200]  [Disc loss: -0.742596] [Gen loss: -2.803299]
# [Epoch 483/2200]  [Disc loss: -0.735463] [Gen loss: -2.564674]
# [Epoch 484/2200]  [Disc loss: -0.738157] [Gen loss: -2.832676]
# [Epoch 485/2200]  [Disc loss: -0.741542] [Gen loss: -2.657160]
# [Epoch 486/2200]  [Disc loss: -0.735656] [Gen loss: -2.743909]
# [Epoch 487/2200]  [Disc loss: -0.741121] [Gen loss: -2.542864]
# [Epoch 488/2200]  [Disc loss: -0.733835] [Gen loss: -2.686837]
# [Epoch 489/2200]  [Disc loss: -0.729233] [Gen loss: -2.736732]
# [Epoch 490/2200]  [Disc loss: -0.734074] [Gen loss: -2.696559]
# [Epoch 491/2200]  [Disc loss: -0.736855] [Gen loss: -2.407149]
# [Epoch 492/2200]  [Disc loss: -0.731617] [Gen loss: -2.706826]
# [Epoch 493/2200]  [Disc loss: -0.732250] [Gen loss: -2.507862]
# [Epoch 494/2200]  [Disc loss: -0.728822] [Gen loss: -2.364270]
# [Epoch 495/2200]  [Disc loss: -0.738241] [Gen loss: -2.422699]
# [Epoch 496/2200]  [Disc loss: -0.730952] [Gen loss: -2.480016]
# [Epoch 497/2200]  [Disc loss: -0.735010] [Gen loss: -2.347166]
# [Epoch 498/2200]  [Disc loss: -0.721478] [Gen loss: -2.392349]
# [Epoch 499/2200]  [Disc loss: -0.729099] [Gen loss: -2.379457]
# [Epoch 500/2200]  [Disc loss: -0.724852] [Gen loss: -2.267362]
# [Epoch 501/2200]  [Disc loss: -0.727719] [Gen loss: -2.355346]
# [Epoch 502/2200]  [Disc loss: -0.726065] [Gen loss: -2.288514]
# [Epoch 503/2200]  [Disc loss: -0.720146] [Gen loss: -2.248991]
# [Epoch 504/2200]  [Disc loss: -0.726312] [Gen loss: -2.345707]
# [Epoch 505/2200]  [Disc loss: -0.725306] [Gen loss: -2.271982]
# [Epoch 506/2200]  [Disc loss: -0.725435] [Gen loss: -2.256810]
# [Epoch 507/2200]  [Disc loss: -0.719099] [Gen loss: -2.254744]
# [Epoch 508/2200]  [Disc loss: -0.727071] [Gen loss: -2.293573]
# [Epoch 509/2200]  [Disc loss: -0.719576] [Gen loss: -2.204371]
# [Epoch 510/2200]  [Disc loss: -0.719981] [Gen loss: -2.067650]
# [Epoch 511/2200]  [Disc loss: -0.720803] [Gen loss: -2.189586]
# [Epoch 512/2200]  [Disc loss: -0.720787] [Gen loss: -2.282567]
# [Epoch 513/2200]  [Disc loss: -0.716572] [Gen loss: -2.054321]
# [Epoch 514/2200]  [Disc loss: -0.719720] [Gen loss: -2.064179]
# [Epoch 515/2200]  [Disc loss: -0.714868] [Gen loss: -2.151298]
# [Epoch 516/2200]  [Disc loss: -0.709631] [Gen loss: -2.017424]
# [Epoch 517/2200]  [Disc loss: -0.719031] [Gen loss: -2.081464]
# [Epoch 518/2200]  [Disc loss: -0.713735] [Gen loss: -1.986719]
# [Epoch 519/2200]  [Disc loss: -0.717529] [Gen loss: -2.079906]
# [Epoch 520/2200]  [Disc loss: -0.716972] [Gen loss: -2.121982]
# [Epoch 521/2200]  [Disc loss: -0.708276] [Gen loss: -1.895825]
# [Epoch 522/2200]  [Disc loss: -0.711344] [Gen loss: -1.824331]
# [Epoch 523/2200]  [Disc loss: -0.714772] [Gen loss: -1.893190]
# [Epoch 524/2200]  [Disc loss: -0.712173] [Gen loss: -1.670113]
# [Epoch 525/2200]  [Disc loss: -0.710415] [Gen loss: -1.824522]
# [Epoch 526/2200]  [Disc loss: -0.712094] [Gen loss: -1.775444]
# [Epoch 527/2200]  [Disc loss: -0.707748] [Gen loss: -1.627238]
# [Epoch 528/2200]  [Disc loss: -0.709168] [Gen loss: -1.887403]
# [Epoch 529/2200]  [Disc loss: -0.709276] [Gen loss: -1.676816]
# [Epoch 530/2200]  [Disc loss: -0.701092] [Gen loss: -1.821013]
# [Epoch 531/2200]  [Disc loss: -0.709156] [Gen loss: -1.768991]
# [Epoch 532/2200]  [Disc loss: -0.705401] [Gen loss: -1.739315]
# [Epoch 533/2200]  [Disc loss: -0.702962] [Gen loss: -1.587431]
# [Epoch 534/2200]  [Disc loss: -0.702217] [Gen loss: -1.712010]
# [Epoch 535/2200]  [Disc loss: -0.707415] [Gen loss: -1.726192]
# [Epoch 536/2200]  [Disc loss: -0.698782] [Gen loss: -1.576997]
# [Epoch 537/2200]  [Disc loss: -0.703705] [Gen loss: -1.663788]
# [Epoch 538/2200]  [Disc loss: -0.699455] [Gen loss: -1.503594]
# [Epoch 539/2200]  [Disc loss: -0.699096] [Gen loss: -1.501056]
# [Epoch 540/2200]  [Disc loss: -0.702916] [Gen loss: -1.524084]
# [Epoch 541/2200]  [Disc loss: -0.697343] [Gen loss: -1.464434]
# [Epoch 542/2200]  [Disc loss: -0.696664] [Gen loss: -1.611189]
# [Epoch 543/2200]  [Disc loss: -0.697904] [Gen loss: -1.525981]
# [Epoch 544/2200]  [Disc loss: -0.691870] [Gen loss: -1.551245]
# [Epoch 545/2200]  [Disc loss: -0.694172] [Gen loss: -1.507793]
# [Epoch 546/2200]  [Disc loss: -0.695084] [Gen loss: -1.451125]
# [Epoch 547/2200]  [Disc loss: -0.698959] [Gen loss: -1.333992]
# [Epoch 548/2200]  [Disc loss: -0.694273] [Gen loss: -1.410658]
# [Epoch 549/2200]  [Disc loss: -0.695478] [Gen loss: -1.219271]
# [Epoch 550/2200]  [Disc loss: -0.688224] [Gen loss: -1.281936]
# [Epoch 551/2200]  [Disc loss: -0.692777] [Gen loss: -1.442537]
# [Epoch 552/2200]  [Disc loss: -0.696137] [Gen loss: -1.258720]
# [Epoch 553/2200]  [Disc loss: -0.690004] [Gen loss: -1.312507]
# [Epoch 554/2200]  [Disc loss: -0.688562] [Gen loss: -1.302879]
# [Epoch 555/2200]  [Disc loss: -0.687811] [Gen loss: -1.297521]
# [Epoch 556/2200]  [Disc loss: -0.686882] [Gen loss: -1.422070]
# [Epoch 557/2200]  [Disc loss: -0.680971] [Gen loss: -1.261128]
# [Epoch 558/2200]  [Disc loss: -0.685556] [Gen loss: -1.172338]
# [Epoch 559/2200]  [Disc loss: -0.693278] [Gen loss: -1.215845]
# [Epoch 560/2200]  [Disc loss: -0.683389] [Gen loss: -1.337640]
# [Epoch 561/2200]  [Disc loss: -0.685056] [Gen loss: -1.128408]
# [Epoch 562/2200]  [Disc loss: -0.680638] [Gen loss: -1.218063]
# [Epoch 563/2200]  [Disc loss: -0.683443] [Gen loss: -1.273493]
# [Epoch 564/2200]  [Disc loss: -0.682527] [Gen loss: -1.054314]
# [Epoch 565/2200]  [Disc loss: -0.678485] [Gen loss: -1.089268]
# [Epoch 566/2200]  [Disc loss: -0.680755] [Gen loss: -1.116985]
# [Epoch 567/2200]  [Disc loss: -0.681431] [Gen loss: -1.165347]
# [Epoch 568/2200]  [Disc loss: -0.676329] [Gen loss: -1.249259]
# [Epoch 569/2200]  [Disc loss: -0.676934] [Gen loss: -1.082410]
# [Epoch 570/2200]  [Disc loss: -0.678940] [Gen loss: -0.993753]
# [Epoch 571/2200]  [Disc loss: -0.680128] [Gen loss: -1.132799]
# [Epoch 572/2200]  [Disc loss: -0.678931] [Gen loss: -1.109311]
# [Epoch 573/2200]  [Disc loss: -0.675285] [Gen loss: -1.010979]
# [Epoch 574/2200]  [Disc loss: -0.675476] [Gen loss: -0.817785]
# [Epoch 575/2200]  [Disc loss: -0.674804] [Gen loss: -0.943606]
# [Epoch 576/2200]  [Disc loss: -0.675154] [Gen loss: -0.945538]
# [Epoch 577/2200]  [Disc loss: -0.674681] [Gen loss: -1.032916]
# [Epoch 578/2200]  [Disc loss: -0.673280] [Gen loss: -1.025372]
# [Epoch 579/2200]  [Disc loss: -0.672214] [Gen loss: -0.945552]
# [Epoch 580/2200]  [Disc loss: -0.665568] [Gen loss: -1.163046]
# [Epoch 581/2200]  [Disc loss: -0.668358] [Gen loss: -1.007348]
# [Epoch 582/2200]  [Disc loss: -0.669088] [Gen loss: -0.967690]
# [Epoch 583/2200]  [Disc loss: -0.671980] [Gen loss: -1.039886]
# [Epoch 584/2200]  [Disc loss: -0.666546] [Gen loss: -0.910400]
# [Epoch 585/2200]  [Disc loss: -0.671042] [Gen loss: -0.867876]
# [Epoch 586/2200]  [Disc loss: -0.659587] [Gen loss: -0.772511]
# [Epoch 587/2200]  [Disc loss: -0.666428] [Gen loss: -0.870920]
# [Epoch 588/2200]  [Disc loss: -0.664250] [Gen loss: -0.870667]
# [Epoch 589/2200]  [Disc loss: -0.665657] [Gen loss: -0.853046]
# [Epoch 590/2200]  [Disc loss: -0.659721] [Gen loss: -0.899955]
# [Epoch 591/2200]  [Disc loss: -0.668466] [Gen loss: -0.925376]
# [Epoch 592/2200]  [Disc loss: -0.662600] [Gen loss: -0.760248]
# [Epoch 593/2200]  [Disc loss: -0.662058] [Gen loss: -0.893728]
# [Epoch 594/2200]  [Disc loss: -0.660408] [Gen loss: -0.813955]
# [Epoch 595/2200]  [Disc loss: -0.658356] [Gen loss: -0.667482]
# [Epoch 596/2200]  [Disc loss: -0.661407] [Gen loss: -0.711504]
# [Epoch 597/2200]  [Disc loss: -0.661766] [Gen loss: -0.778824]
# [Epoch 598/2200]  [Disc loss: -0.658412] [Gen loss: -0.909816]
# [Epoch 599/2200]  [Disc loss: -0.656162] [Gen loss: -0.871357]
# [Epoch 600/2200]  [Disc loss: -0.658884] [Gen loss: -0.684784]
# [Epoch 601/2200]  [Disc loss: -0.651616] [Gen loss: -0.770246]
# [Epoch 602/2200]  [Disc loss: -0.653992] [Gen loss: -0.705692]
# [Epoch 603/2200]  [Disc loss: -0.653974] [Gen loss: -0.689217]
# [Epoch 604/2200]  [Disc loss: -0.655373] [Gen loss: -0.782217]
# [Epoch 605/2200]  [Disc loss: -0.652448] [Gen loss: -0.711396]
# [Epoch 606/2200]  [Disc loss: -0.657121] [Gen loss: -0.775234]
# [Epoch 607/2200]  [Disc loss: -0.650486] [Gen loss: -0.629806]
# [Epoch 608/2200]  [Disc loss: -0.655187] [Gen loss: -0.663235]
# [Epoch 609/2200]  [Disc loss: -0.656818] [Gen loss: -0.565129]
# [Epoch 610/2200]  [Disc loss: -0.650322] [Gen loss: -0.606230]
# [Epoch 611/2200]  [Disc loss: -0.651450] [Gen loss: -0.552080]
# [Epoch 612/2200]  [Disc loss: -0.649531] [Gen loss: -0.728395]
# [Epoch 613/2200]  [Disc loss: -0.651990] [Gen loss: -0.677538]
# [Epoch 614/2200]  [Disc loss: -0.651305] [Gen loss: -0.659768]
# [Epoch 615/2200]  [Disc loss: -0.647835] [Gen loss: -0.680492]
# [Epoch 616/2200]  [Disc loss: -0.647952] [Gen loss: -0.623676]
# [Epoch 617/2200]  [Disc loss: -0.648466] [Gen loss: -0.584376]
# [Epoch 618/2200]  [Disc loss: -0.652173] [Gen loss: -0.688815]
# [Epoch 619/2200]  [Disc loss: -0.653258] [Gen loss: -0.472685]
# [Epoch 620/2200]  [Disc loss: -0.651793] [Gen loss: -0.570615]
# [Epoch 621/2200]  [Disc loss: -0.645943] [Gen loss: -0.541431]
# [Epoch 622/2200]  [Disc loss: -0.651477] [Gen loss: -0.563241]
# [Epoch 623/2200]  [Disc loss: -0.644007] [Gen loss: -0.567507]
# [Epoch 624/2200]  [Disc loss: -0.652529] [Gen loss: -0.628469]
# [Epoch 625/2200]  [Disc loss: -0.649301] [Gen loss: -0.452493]
# [Epoch 626/2200]  [Disc loss: -0.646369] [Gen loss: -0.585272]
# [Epoch 627/2200]  [Disc loss: -0.649818] [Gen loss: -0.681358]
# [Epoch 628/2200]  [Disc loss: -0.638658] [Gen loss: -0.481270]
# [Epoch 629/2200]  [Disc loss: -0.647844] [Gen loss: -0.699497]
# [Epoch 630/2200]  [Disc loss: -0.644540] [Gen loss: -0.668210]
# [Epoch 631/2200]  [Disc loss: -0.644420] [Gen loss: -0.590306]
# [Epoch 632/2200]  [Disc loss: -0.637936] [Gen loss: -0.531813]
# [Epoch 633/2200]  [Disc loss: -0.641281] [Gen loss: -0.509067]
# [Epoch 634/2200]  [Disc loss: -0.646978] [Gen loss: -0.560747]
# [Epoch 635/2200]  [Disc loss: -0.638893] [Gen loss: -0.419133]
# [Epoch 636/2200]  [Disc loss: -0.640058] [Gen loss: -0.512139]
# [Epoch 637/2200]  [Disc loss: -0.644723] [Gen loss: -0.560778]
# [Epoch 638/2200]  [Disc loss: -0.645280] [Gen loss: -0.370563]
# [Epoch 639/2200]  [Disc loss: -0.639616] [Gen loss: -0.296772]
# [Epoch 640/2200]  [Disc loss: -0.642167] [Gen loss: -0.599637]
# [Epoch 641/2200]  [Disc loss: -0.643445] [Gen loss: -0.361720]
# [Epoch 642/2200]  [Disc loss: -0.640555] [Gen loss: -0.382797]
# [Epoch 643/2200]  [Disc loss: -0.638040] [Gen loss: -0.196665]
# [Epoch 644/2200]  [Disc loss: -0.643687] [Gen loss: -0.553070]
# [Epoch 645/2200]  [Disc loss: -0.635784] [Gen loss: -0.421622]
# [Epoch 646/2200]  [Disc loss: -0.635349] [Gen loss: -0.371598]
# [Epoch 647/2200]  [Disc loss: -0.639699] [Gen loss: -0.405445]
# [Epoch 648/2200]  [Disc loss: -0.637344] [Gen loss: -0.398344]
# [Epoch 649/2200]  [Disc loss: -0.636592] [Gen loss: -0.503734]
# [Epoch 650/2200]  [Disc loss: -0.639134] [Gen loss: -0.399566]
# [Epoch 651/2200]  [Disc loss: -0.640170] [Gen loss: -0.404731]
# [Epoch 652/2200]  [Disc loss: -0.635826] [Gen loss: -0.345514]
# [Epoch 653/2200]  [Disc loss: -0.632421] [Gen loss: -0.240913]
# [Epoch 654/2200]  [Disc loss: -0.630169] [Gen loss: -0.212705]
# [Epoch 655/2200]  [Disc loss: -0.639510] [Gen loss: -0.298655]
# [Epoch 656/2200]  [Disc loss: -0.637784] [Gen loss: -0.266298]
# [Epoch 657/2200]  [Disc loss: -0.633553] [Gen loss: -0.274636]
# [Epoch 658/2200]  [Disc loss: -0.636695] [Gen loss: -0.174237]
# [Epoch 659/2200]  [Disc loss: -0.635449] [Gen loss: -0.117274]
# [Epoch 660/2200]  [Disc loss: -0.632831] [Gen loss: -0.283159]
# [Epoch 661/2200]  [Disc loss: -0.629998] [Gen loss: -0.241628]
# [Epoch 662/2200]  [Disc loss: -0.634374] [Gen loss: -0.166683]
# [Epoch 663/2200]  [Disc loss: -0.632329] [Gen loss: -0.171034]
# [Epoch 664/2200]  [Disc loss: -0.628433] [Gen loss: -0.179407]
# [Epoch 665/2200]  [Disc loss: -0.630852] [Gen loss: -0.094272]
# [Epoch 666/2200]  [Disc loss: -0.627960] [Gen loss: -0.193295]
# [Epoch 667/2200]  [Disc loss: -0.634131] [Gen loss: -0.048276]
# [Epoch 668/2200]  [Disc loss: -0.631835] [Gen loss: -0.032587]
# [Epoch 669/2200]  [Disc loss: -0.632348] [Gen loss: -0.105999]
# [Epoch 670/2200]  [Disc loss: -0.627105] [Gen loss: -0.052294]
# [Epoch 671/2200]  [Disc loss: -0.624656] [Gen loss: -0.099867]
# [Epoch 672/2200]  [Disc loss: -0.634853] [Gen loss: 0.008064]
# [Epoch 673/2200]  [Disc loss: -0.623797] [Gen loss: -0.170696]
# [Epoch 674/2200]  [Disc loss: -0.629380] [Gen loss: -0.130385]
# [Epoch 675/2200]  [Disc loss: -0.629457] [Gen loss: -0.013697]
# [Epoch 676/2200]  [Disc loss: -0.626662] [Gen loss: 0.034192]
# [Epoch 677/2200]  [Disc loss: -0.622129] [Gen loss: -0.061447]
# [Epoch 678/2200]  [Disc loss: -0.627565] [Gen loss: 0.131750]
# [Epoch 679/2200]  [Disc loss: -0.623383] [Gen loss: 0.024129]
# [Epoch 680/2200]  [Disc loss: -0.625809] [Gen loss: -0.118243]
# [Epoch 681/2200]  [Disc loss: -0.623563] [Gen loss: 0.071598]
# [Epoch 682/2200]  [Disc loss: -0.621608] [Gen loss: 0.074888]
# [Epoch 683/2200]  [Disc loss: -0.622115] [Gen loss: 0.059737]
# [Epoch 684/2200]  [Disc loss: -0.623748] [Gen loss: 0.088769]
# [Epoch 685/2200]  [Disc loss: -0.619360] [Gen loss: 0.097683]
# [Epoch 686/2200]  [Disc loss: -0.625703] [Gen loss: 0.121843]
# [Epoch 687/2200]  [Disc loss: -0.620535] [Gen loss: 0.134279]
# [Epoch 688/2200]  [Disc loss: -0.625071] [Gen loss: 0.140996]
# [Epoch 689/2200]  [Disc loss: -0.631243] [Gen loss: 0.257305]
# [Epoch 690/2200]  [Disc loss: -0.620669] [Gen loss: 0.088974]
# [Epoch 691/2200]  [Disc loss: -0.620014] [Gen loss: 0.101050]
# [Epoch 692/2200]  [Disc loss: -0.626671] [Gen loss: 0.162306]
# [Epoch 693/2200]  [Disc loss: -0.626313] [Gen loss: 0.165577]
# [Epoch 694/2200]  [Disc loss: -0.623587] [Gen loss: 0.183112]
# [Epoch 695/2200]  [Disc loss: -0.617530] [Gen loss: 0.278361]
# [Epoch 696/2200]  [Disc loss: -0.623069] [Gen loss: 0.371888]
# [Epoch 697/2200]  [Disc loss: -0.620925] [Gen loss: 0.316893]
# [Epoch 698/2200]  [Disc loss: -0.622133] [Gen loss: 0.124650]
# [Epoch 699/2200]  [Disc loss: -0.619845] [Gen loss: 0.159872]
# [Epoch 700/2200]  [Disc loss: -0.616176] [Gen loss: 0.355326]
# [Epoch 701/2200]  [Disc loss: -0.620828] [Gen loss: 0.253185]
# [Epoch 702/2200]  [Disc loss: -0.620236] [Gen loss: 0.308719]
# [Epoch 703/2200]  [Disc loss: -0.620214] [Gen loss: 0.162041]
# [Epoch 704/2200]  [Disc loss: -0.614119] [Gen loss: 0.225908]
# [Epoch 705/2200]  [Disc loss: -0.617644] [Gen loss: 0.138137]
# [Epoch 706/2200]  [Disc loss: -0.620578] [Gen loss: 0.320300]
# [Epoch 707/2200]  [Disc loss: -0.618687] [Gen loss: 0.248304]
# [Epoch 708/2200]  [Disc loss: -0.618398] [Gen loss: 0.469853]
# [Epoch 709/2200]  [Disc loss: -0.617212] [Gen loss: 0.481071]
# [Epoch 710/2200]  [Disc loss: -0.618340] [Gen loss: 0.344303]
# [Epoch 711/2200]  [Disc loss: -0.616819] [Gen loss: 0.440500]
# [Epoch 712/2200]  [Disc loss: -0.620809] [Gen loss: 0.535597]
# [Epoch 713/2200]  [Disc loss: -0.616764] [Gen loss: 0.432500]
# [Epoch 714/2200]  [Disc loss: -0.617277] [Gen loss: 0.396209]
# [Epoch 715/2200]  [Disc loss: -0.618729] [Gen loss: 0.380465]
# [Epoch 716/2200]  [Disc loss: -0.619760] [Gen loss: 0.455404]
# [Epoch 717/2200]  [Disc loss: -0.613657] [Gen loss: 0.330695]
# [Epoch 718/2200]  [Disc loss: -0.616109] [Gen loss: 0.607316]
# [Epoch 719/2200]  [Disc loss: -0.614561] [Gen loss: 0.463988]
# [Epoch 720/2200]  [Disc loss: -0.618174] [Gen loss: 0.475559]
# [Epoch 721/2200]  [Disc loss: -0.616848] [Gen loss: 0.348537]
# [Epoch 722/2200]  [Disc loss: -0.619868] [Gen loss: 0.308565]
# [Epoch 723/2200]  [Disc loss: -0.615743] [Gen loss: 0.535448]
# [Epoch 724/2200]  [Disc loss: -0.617748] [Gen loss: 0.434923]
# [Epoch 725/2200]  [Disc loss: -0.617834] [Gen loss: 0.577825]
# [Epoch 726/2200]  [Disc loss: -0.615460] [Gen loss: 0.506712]
# [Epoch 727/2200]  [Disc loss: -0.616884] [Gen loss: 0.528583]
# [Epoch 728/2200]  [Disc loss: -0.614979] [Gen loss: 0.684031]
# [Epoch 729/2200]  [Disc loss: -0.618200] [Gen loss: 0.672839]
# [Epoch 730/2200]  [Disc loss: -0.619691] [Gen loss: 0.743111]
# [Epoch 731/2200]  [Disc loss: -0.615808] [Gen loss: 0.379182]
# [Epoch 732/2200]  [Disc loss: -0.611860] [Gen loss: 0.640373]
# [Epoch 733/2200]  [Disc loss: -0.617644] [Gen loss: 0.578860]
# [Epoch 734/2200]  [Disc loss: -0.618688] [Gen loss: 0.702133]
# [Epoch 735/2200]  [Disc loss: -0.614762] [Gen loss: 0.668355]
# [Epoch 736/2200]  [Disc loss: -0.622308] [Gen loss: 0.710052]
# [Epoch 737/2200]  [Disc loss: -0.613222] [Gen loss: 0.577108]
# [Epoch 738/2200]  [Disc loss: -0.616450] [Gen loss: 0.637524]
# [Epoch 739/2200]  [Disc loss: -0.616404] [Gen loss: 0.777356]
# [Epoch 740/2200]  [Disc loss: -0.608953] [Gen loss: 0.658193]
# [Epoch 741/2200]  [Disc loss: -0.610404] [Gen loss: 0.803012]
# [Epoch 742/2200]  [Disc loss: -0.616464] [Gen loss: 0.631536]
# [Epoch 743/2200]  [Disc loss: -0.616152] [Gen loss: 0.693493]
# [Epoch 744/2200]  [Disc loss: -0.614791] [Gen loss: 0.739732]
# [Epoch 745/2200]  [Disc loss: -0.611632] [Gen loss: 0.725750]
# [Epoch 746/2200]  [Disc loss: -0.613387] [Gen loss: 0.883200]
# [Epoch 747/2200]  [Disc loss: -0.618638] [Gen loss: 0.820076]
# [Epoch 748/2200]  [Disc loss: -0.613889] [Gen loss: 0.649476]
# [Epoch 749/2200]  [Disc loss: -0.618898] [Gen loss: 0.791540]
# [Epoch 750/2200]  [Disc loss: -0.609572] [Gen loss: 0.723228]
# [Epoch 751/2200]  [Disc loss: -0.613573] [Gen loss: 0.734731]
# [Epoch 752/2200]  [Disc loss: -0.614008] [Gen loss: 0.661663]
# [Epoch 753/2200]  [Disc loss: -0.618369] [Gen loss: 0.673896]
# [Epoch 754/2200]  [Disc loss: -0.614633] [Gen loss: 0.698746]
# [Epoch 755/2200]  [Disc loss: -0.610645] [Gen loss: 0.728058]
# [Epoch 756/2200]  [Disc loss: -0.612465] [Gen loss: 0.644054]
# [Epoch 757/2200]  [Disc loss: -0.606967] [Gen loss: 0.660094]
# [Epoch 758/2200]  [Disc loss: -0.609427] [Gen loss: 0.780804]
# [Epoch 759/2200]  [Disc loss: -0.614129] [Gen loss: 0.510223]
# [Epoch 760/2200]  [Disc loss: -0.609885] [Gen loss: 0.786861]
# [Epoch 761/2200]  [Disc loss: -0.610182] [Gen loss: 0.737967]
# [Epoch 762/2200]  [Disc loss: -0.613411] [Gen loss: 0.750107]
# [Epoch 763/2200]  [Disc loss: -0.609450] [Gen loss: 0.709653]
# [Epoch 764/2200]  [Disc loss: -0.610646] [Gen loss: 0.930782]
# [Epoch 765/2200]  [Disc loss: -0.608067] [Gen loss: 0.735090]
# [Epoch 766/2200]  [Disc loss: -0.611752] [Gen loss: 0.697958]
# [Epoch 767/2200]  [Disc loss: -0.608972] [Gen loss: 0.825981]
# [Epoch 768/2200]  [Disc loss: -0.612451] [Gen loss: 0.701119]
# [Epoch 769/2200]  [Disc loss: -0.610356] [Gen loss: 0.880834]
# [Epoch 770/2200]  [Disc loss: -0.610076] [Gen loss: 0.860896]
# [Epoch 771/2200]  [Disc loss: -0.606156] [Gen loss: 0.840661]
# [Epoch 772/2200]  [Disc loss: -0.614391] [Gen loss: 0.949332]
# [Epoch 773/2200]  [Disc loss: -0.608674] [Gen loss: 0.771518]
# [Epoch 774/2200]  [Disc loss: -0.607495] [Gen loss: 0.805441]
# [Epoch 775/2200]  [Disc loss: -0.606225] [Gen loss: 0.851202]
# [Epoch 776/2200]  [Disc loss: -0.607015] [Gen loss: 0.817927]
# [Epoch 777/2200]  [Disc loss: -0.607039] [Gen loss: 0.808215]
# [Epoch 778/2200]  [Disc loss: -0.607334] [Gen loss: 0.831943]
# [Epoch 779/2200]  [Disc loss: -0.609556] [Gen loss: 0.669006]
# [Epoch 780/2200]  [Disc loss: -0.609304] [Gen loss: 0.951370]
# [Epoch 781/2200]  [Disc loss: -0.612432] [Gen loss: 0.953352]
# [Epoch 782/2200]  [Disc loss: -0.604153] [Gen loss: 0.781078]
# [Epoch 783/2200]  [Disc loss: -0.606620] [Gen loss: 0.765669]
# [Epoch 784/2200]  [Disc loss: -0.605367] [Gen loss: 0.785220]
# [Epoch 785/2200]  [Disc loss: -0.603835] [Gen loss: 0.829723]
# [Epoch 786/2200]  [Disc loss: -0.605580] [Gen loss: 0.718773]
# [Epoch 787/2200]  [Disc loss: -0.609206] [Gen loss: 0.853556]
# [Epoch 788/2200]  [Disc loss: -0.602916] [Gen loss: 0.852145]
# [Epoch 789/2200]  [Disc loss: -0.601945] [Gen loss: 0.910044]
# [Epoch 790/2200]  [Disc loss: -0.605031] [Gen loss: 0.926776]
# [Epoch 791/2200]  [Disc loss: -0.603834] [Gen loss: 0.848821]
# [Epoch 792/2200]  [Disc loss: -0.605289] [Gen loss: 0.816805]
# [Epoch 793/2200]  [Disc loss: -0.605043] [Gen loss: 0.796721]
# [Epoch 794/2200]  [Disc loss: -0.602831] [Gen loss: 1.022348]
# [Epoch 795/2200]  [Disc loss: -0.602254] [Gen loss: 0.838411]
# [Epoch 796/2200]  [Disc loss: -0.604511] [Gen loss: 0.835090]
# [Epoch 797/2200]  [Disc loss: -0.605948] [Gen loss: 0.995415]
# [Epoch 798/2200]  [Disc loss: -0.606158] [Gen loss: 0.972940]
# [Epoch 799/2200]  [Disc loss: -0.599726] [Gen loss: 1.177024]
# [Epoch 800/2200]  [Disc loss: -0.601443] [Gen loss: 0.990004]
# [Epoch 801/2200]  [Disc loss: -0.601676] [Gen loss: 0.867775]
# [Epoch 802/2200]  [Disc loss: -0.601948] [Gen loss: 0.902871]
# [Epoch 803/2200]  [Disc loss: -0.601595] [Gen loss: 0.843171]
# [Epoch 804/2200]  [Disc loss: -0.599649] [Gen loss: 0.937790]
# [Epoch 805/2200]  [Disc loss: -0.597692] [Gen loss: 0.910531]
# [Epoch 806/2200]  [Disc loss: -0.595905] [Gen loss: 0.740794]
# [Epoch 807/2200]  [Disc loss: -0.603081] [Gen loss: 0.921710]
# [Epoch 808/2200]  [Disc loss: -0.601721] [Gen loss: 0.831452]
# [Epoch 809/2200]  [Disc loss: -0.601709] [Gen loss: 0.943359]
# [Epoch 810/2200]  [Disc loss: -0.600450] [Gen loss: 0.997382]
# [Epoch 811/2200]  [Disc loss: -0.597019] [Gen loss: 0.717540]
# [Epoch 812/2200]  [Disc loss: -0.600550] [Gen loss: 0.910827]
# [Epoch 813/2200]  [Disc loss: -0.597791] [Gen loss: 0.779068]
# [Epoch 814/2200]  [Disc loss: -0.595011] [Gen loss: 0.952484]
# [Epoch 815/2200]  [Disc loss: -0.601644] [Gen loss: 0.913769]
# [Epoch 816/2200]  [Disc loss: -0.593319] [Gen loss: 0.901415]
# [Epoch 817/2200]  [Disc loss: -0.601638] [Gen loss: 0.816589]
# [Epoch 818/2200]  [Disc loss: -0.599816] [Gen loss: 0.994817]
# [Epoch 819/2200]  [Disc loss: -0.595503] [Gen loss: 0.925340]
# [Epoch 820/2200]  [Disc loss: -0.592102] [Gen loss: 1.007038]
# [Epoch 821/2200]  [Disc loss: -0.595169] [Gen loss: 0.947520]
# [Epoch 822/2200]  [Disc loss: -0.594157] [Gen loss: 0.984887]
# [Epoch 823/2200]  [Disc loss: -0.597513] [Gen loss: 1.024603]
# [Epoch 824/2200]  [Disc loss: -0.590312] [Gen loss: 0.988026]
# [Epoch 825/2200]  [Disc loss: -0.599543] [Gen loss: 0.902379]
# [Epoch 826/2200]  [Disc loss: -0.592611] [Gen loss: 1.072299]
# [Epoch 827/2200]  [Disc loss: -0.600675] [Gen loss: 0.864125]
# [Epoch 828/2200]  [Disc loss: -0.599504] [Gen loss: 1.013856]
# [Epoch 829/2200]  [Disc loss: -0.599222] [Gen loss: 1.116807]
# [Epoch 830/2200]  [Disc loss: -0.595012] [Gen loss: 1.073136]
# [Epoch 831/2200]  [Disc loss: -0.595094] [Gen loss: 0.960065]
# [Epoch 832/2200]  [Disc loss: -0.594568] [Gen loss: 1.159320]
# [Epoch 833/2200]  [Disc loss: -0.592827] [Gen loss: 1.069318]
# [Epoch 834/2200]  [Disc loss: -0.590163] [Gen loss: 0.913156]
# [Epoch 835/2200]  [Disc loss: -0.593526] [Gen loss: 1.102903]
# [Epoch 836/2200]  [Disc loss: -0.594856] [Gen loss: 1.069285]
# [Epoch 837/2200]  [Disc loss: -0.591573] [Gen loss: 1.160119]
# [Epoch 838/2200]  [Disc loss: -0.593049] [Gen loss: 1.113995]
# [Epoch 839/2200]  [Disc loss: -0.593263] [Gen loss: 1.074828]
# [Epoch 840/2200]  [Disc loss: -0.584939] [Gen loss: 1.031487]
# [Epoch 841/2200]  [Disc loss: -0.590551] [Gen loss: 0.959411]
# [Epoch 842/2200]  [Disc loss: -0.593781] [Gen loss: 0.951053]
# [Epoch 843/2200]  [Disc loss: -0.591881] [Gen loss: 1.045318]
# [Epoch 844/2200]  [Disc loss: -0.596182] [Gen loss: 1.135240]
# [Epoch 845/2200]  [Disc loss: -0.589197] [Gen loss: 1.100867]
# [Epoch 846/2200]  [Disc loss: -0.593098] [Gen loss: 1.157630]
# [Epoch 847/2200]  [Disc loss: -0.589376] [Gen loss: 1.064370]
# [Epoch 848/2200]  [Disc loss: -0.588881] [Gen loss: 1.003525]
# [Epoch 849/2200]  [Disc loss: -0.592508] [Gen loss: 1.060893]
# [Epoch 850/2200]  [Disc loss: -0.587217] [Gen loss: 0.903567]
# [Epoch 851/2200]  [Disc loss: -0.587635] [Gen loss: 0.932847]
# [Epoch 852/2200]  [Disc loss: -0.592455] [Gen loss: 1.040072]
# [Epoch 853/2200]  [Disc loss: -0.584583] [Gen loss: 1.034876]
# [Epoch 854/2200]  [Disc loss: -0.585220] [Gen loss: 0.903489]
# [Epoch 855/2200]  [Disc loss: -0.597010] [Gen loss: 1.120656]
# [Epoch 856/2200]  [Disc loss: -0.582834] [Gen loss: 0.990688]
# [Epoch 857/2200]  [Disc loss: -0.586804] [Gen loss: 0.979244]
# [Epoch 858/2200]  [Disc loss: -0.587446] [Gen loss: 1.196515]
# [Epoch 859/2200]  [Disc loss: -0.585367] [Gen loss: 1.116998]
# [Epoch 860/2200]  [Disc loss: -0.586432] [Gen loss: 1.117266]
# [Epoch 861/2200]  [Disc loss: -0.587809] [Gen loss: 1.165135]
# [Epoch 862/2200]  [Disc loss: -0.589401] [Gen loss: 1.062037]
# [Epoch 863/2200]  [Disc loss: -0.580505] [Gen loss: 0.945588]
# [Epoch 864/2200]  [Disc loss: -0.583260] [Gen loss: 0.973983]
# [Epoch 865/2200]  [Disc loss: -0.586183] [Gen loss: 1.101133]
# [Epoch 866/2200]  [Disc loss: -0.584390] [Gen loss: 0.918775]
# [Epoch 867/2200]  [Disc loss: -0.589932] [Gen loss: 1.061571]
# [Epoch 868/2200]  [Disc loss: -0.593038] [Gen loss: 1.175637]
# [Epoch 869/2200]  [Disc loss: -0.584821] [Gen loss: 1.062477]
# [Epoch 870/2200]  [Disc loss: -0.583186] [Gen loss: 0.953015]
# [Epoch 871/2200]  [Disc loss: -0.584531] [Gen loss: 0.971916]
# [Epoch 872/2200]  [Disc loss: -0.584030] [Gen loss: 0.961384]
# [Epoch 873/2200]  [Disc loss: -0.582528] [Gen loss: 1.174516]
# [Epoch 874/2200]  [Disc loss: -0.580711] [Gen loss: 1.078546]
# [Epoch 875/2200]  [Disc loss: -0.581491] [Gen loss: 0.919086]
# [Epoch 876/2200]  [Disc loss: -0.583528] [Gen loss: 1.034853]
# [Epoch 877/2200]  [Disc loss: -0.585921] [Gen loss: 1.072783]
# [Epoch 878/2200]  [Disc loss: -0.581208] [Gen loss: 1.104778]
# [Epoch 879/2200]  [Disc loss: -0.580277] [Gen loss: 1.071393]
# [Epoch 880/2200]  [Disc loss: -0.589302] [Gen loss: 1.117686]
# [Epoch 881/2200]  [Disc loss: -0.584359] [Gen loss: 1.097692]
# [Epoch 882/2200]  [Disc loss: -0.581762] [Gen loss: 0.982490]
# [Epoch 883/2200]  [Disc loss: -0.580832] [Gen loss: 1.078328]
# [Epoch 884/2200]  [Disc loss: -0.580652] [Gen loss: 1.024575]
# [Epoch 885/2200]  [Disc loss: -0.583215] [Gen loss: 1.059832]
# [Epoch 886/2200]  [Disc loss: -0.585700] [Gen loss: 0.951168]
# [Epoch 887/2200]  [Disc loss: -0.581976] [Gen loss: 1.014318]
# [Epoch 888/2200]  [Disc loss: -0.582195] [Gen loss: 1.127043]
# [Epoch 889/2200]  [Disc loss: -0.578878] [Gen loss: 1.106238]
# [Epoch 890/2200]  [Disc loss: -0.582837] [Gen loss: 1.074146]
# [Epoch 891/2200]  [Disc loss: -0.582008] [Gen loss: 1.090879]
# [Epoch 892/2200]  [Disc loss: -0.576263] [Gen loss: 1.006024]
# [Epoch 893/2200]  [Disc loss: -0.577257] [Gen loss: 0.970086]
# [Epoch 894/2200]  [Disc loss: -0.578077] [Gen loss: 1.170271]
# [Epoch 895/2200]  [Disc loss: -0.577256] [Gen loss: 1.184580]
# [Epoch 896/2200]  [Disc loss: -0.577480] [Gen loss: 1.168413]
# [Epoch 897/2200]  [Disc loss: -0.578769] [Gen loss: 1.062333]
# [Epoch 898/2200]  [Disc loss: -0.577460] [Gen loss: 1.008648]
# [Epoch 899/2200]  [Disc loss: -0.584979] [Gen loss: 1.155461]
# [Epoch 900/2200]  [Disc loss: -0.580343] [Gen loss: 1.251120]
# [Epoch 901/2200]  [Disc loss: -0.574597] [Gen loss: 1.281279]
# [Epoch 902/2200]  [Disc loss: -0.578992] [Gen loss: 0.987243]
# [Epoch 903/2200]  [Disc loss: -0.579861] [Gen loss: 1.066826]
# [Epoch 904/2200]  [Disc loss: -0.582809] [Gen loss: 1.144309]
# [Epoch 905/2200]  [Disc loss: -0.576099] [Gen loss: 1.130231]
# [Epoch 906/2200]  [Disc loss: -0.575719] [Gen loss: 1.168094]
# [Epoch 907/2200]  [Disc loss: -0.575478] [Gen loss: 1.021825]
# [Epoch 908/2200]  [Disc loss: -0.577995] [Gen loss: 1.100484]
# [Epoch 909/2200]  [Disc loss: -0.577902] [Gen loss: 1.028198]
# [Epoch 910/2200]  [Disc loss: -0.575555] [Gen loss: 0.886022]
# [Epoch 911/2200]  [Disc loss: -0.577950] [Gen loss: 1.088978]
# [Epoch 912/2200]  [Disc loss: -0.578294] [Gen loss: 1.036124]
# [Epoch 913/2200]  [Disc loss: -0.578578] [Gen loss: 1.182231]
# [Epoch 914/2200]  [Disc loss: -0.578364] [Gen loss: 0.915816]
# [Epoch 915/2200]  [Disc loss: -0.579205] [Gen loss: 1.040204]
# [Epoch 916/2200]  [Disc loss: -0.571849] [Gen loss: 1.068282]
# [Epoch 917/2200]  [Disc loss: -0.579247] [Gen loss: 1.112064]
# [Epoch 918/2200]  [Disc loss: -0.570223] [Gen loss: 1.029842]
# [Epoch 919/2200]  [Disc loss: -0.573411] [Gen loss: 1.049620]
# [Epoch 920/2200]  [Disc loss: -0.575887] [Gen loss: 1.076203]
# [Epoch 921/2200]  [Disc loss: -0.575260] [Gen loss: 0.921183]
# [Epoch 922/2200]  [Disc loss: -0.571731] [Gen loss: 1.039970]
# [Epoch 923/2200]  [Disc loss: -0.572723] [Gen loss: 0.880372]
# [Epoch 924/2200]  [Disc loss: -0.577393] [Gen loss: 1.091127]
# [Epoch 925/2200]  [Disc loss: -0.572510] [Gen loss: 0.990054]
# [Epoch 926/2200]  [Disc loss: -0.575208] [Gen loss: 1.175213]
# [Epoch 927/2200]  [Disc loss: -0.570767] [Gen loss: 1.088401]
# [Epoch 928/2200]  [Disc loss: -0.572568] [Gen loss: 0.876557]
# [Epoch 929/2200]  [Disc loss: -0.576664] [Gen loss: 0.996087]
# [Epoch 930/2200]  [Disc loss: -0.572175] [Gen loss: 1.066891]
# [Epoch 931/2200]  [Disc loss: -0.571081] [Gen loss: 1.100163]
# [Epoch 932/2200]  [Disc loss: -0.580161] [Gen loss: 0.929138]
# [Epoch 933/2200]  [Disc loss: -0.573067] [Gen loss: 1.071490]
# [Epoch 934/2200]  [Disc loss: -0.572429] [Gen loss: 0.872010]
# [Epoch 935/2200]  [Disc loss: -0.572152] [Gen loss: 0.935882]
# [Epoch 936/2200]  [Disc loss: -0.576264] [Gen loss: 1.036185]
# [Epoch 937/2200]  [Disc loss: -0.571081] [Gen loss: 0.851025]
# [Epoch 938/2200]  [Disc loss: -0.571110] [Gen loss: 0.912195]
# [Epoch 939/2200]  [Disc loss: -0.572516] [Gen loss: 1.077328]
# [Epoch 940/2200]  [Disc loss: -0.571065] [Gen loss: 0.860153]
# [Epoch 941/2200]  [Disc loss: -0.571795] [Gen loss: 0.963695]
# [Epoch 942/2200]  [Disc loss: -0.571661] [Gen loss: 0.955765]
# [Epoch 943/2200]  [Disc loss: -0.567856] [Gen loss: 0.985807]
# [Epoch 944/2200]  [Disc loss: -0.573574] [Gen loss: 0.873052]
# [Epoch 945/2200]  [Disc loss: -0.569785] [Gen loss: 0.966995]
# [Epoch 946/2200]  [Disc loss: -0.570237] [Gen loss: 0.932255]
# [Epoch 947/2200]  [Disc loss: -0.576161] [Gen loss: 1.048100]
# [Epoch 948/2200]  [Disc loss: -0.568650] [Gen loss: 0.837737]
# [Epoch 949/2200]  [Disc loss: -0.571897] [Gen loss: 0.987571]
# [Epoch 950/2200]  [Disc loss: -0.575000] [Gen loss: 0.781766]
# [Epoch 951/2200]  [Disc loss: -0.569548] [Gen loss: 0.887316]
# [Epoch 952/2200]  [Disc loss: -0.568991] [Gen loss: 0.931547]
# ...
# [Epoch 1951/2200]  [Disc loss: -0.427802] [Gen loss: 0.521751]
# [Epoch 1952/2200]  [Disc loss: -0.422735] [Gen loss: 0.520792]
# [Epoch 1953/2200]  [Disc loss: -0.421517] [Gen loss: 0.657298]
# [Epoch 1954/2200]  [Disc loss: -0.428334] [Gen loss: 0.633505]
# [Epoch 1955/2200]  [Disc loss: -0.424391] [Gen loss: 0.555600]
# [Epoch 1956/2200]  [Disc loss: -0.426910] [Gen loss: 0.618383]
# [Epoch 1957/2200]  [Disc loss: -0.424357] [Gen loss: 0.487702]
# [Epoch 1958/2200]  [Disc loss: -0.420563] [Gen loss: 0.559789]
# [Epoch 1959/2200]  [Disc loss: -0.421330] [Gen loss: 0.596537]
# [Epoch 1960/2200]  [Disc loss: -0.423819] [Gen loss: 0.613121]
# [Epoch 1961/2200]  [Disc loss: -0.428041] [Gen loss: 0.492579]
# [Epoch 1962/2200]  [Disc loss: -0.420293] [Gen loss: 0.530138]
# [Epoch 1963/2200]  [Disc loss: -0.424148] [Gen loss: 0.683791]
# [Epoch 1964/2200]  [Disc loss: -0.420273] [Gen loss: 0.675523]
# [Epoch 1965/2200]  [Disc loss: -0.422309] [Gen loss: 0.546680]
# [Epoch 1966/2200]  [Disc loss: -0.424580] [Gen loss: 0.510942]
# [Epoch 1967/2200]  [Disc loss: -0.423007] [Gen loss: 0.446326]
# [Epoch 1968/2200]  [Disc loss: -0.428289] [Gen loss: 0.513724]
# [Epoch 1969/2200]  [Disc loss: -0.416784] [Gen loss: 0.405802]
# [Epoch 1970/2200]  [Disc loss: -0.423701] [Gen loss: 0.439022]
# [Epoch 1971/2200]  [Disc loss: -0.422423] [Gen loss: 0.617804]
# [Epoch 1972/2200]  [Disc loss: -0.425680] [Gen loss: 0.260580]
# [Epoch 1973/2200]  [Disc loss: -0.421816] [Gen loss: 0.502896]
# [Epoch 1974/2200]  [Disc loss: -0.423649] [Gen loss: 0.360857]
# [Epoch 1975/2200]  [Disc loss: -0.424572] [Gen loss: 0.377568]
# [Epoch 1976/2200]  [Disc loss: -0.420935] [Gen loss: 0.444656]
# [Epoch 1977/2200]  [Disc loss: -0.425532] [Gen loss: 0.503454]
# [Epoch 1978/2200]  [Disc loss: -0.421045] [Gen loss: 0.599217]
# [Epoch 1979/2200]  [Disc loss: -0.424795] [Gen loss: 0.497286]
# [Epoch 1980/2200]  [Disc loss: -0.421517] [Gen loss: 0.559359]
# [Epoch 1981/2200]  [Disc loss: -0.428177] [Gen loss: 0.729861]
# [Epoch 1982/2200]  [Disc loss: -0.418742] [Gen loss: 0.463219]
# [Epoch 1983/2200]  [Disc loss: -0.422097] [Gen loss: 0.502435]
# [Epoch 1984/2200]  [Disc loss: -0.418530] [Gen loss: 0.591696]
# [Epoch 1985/2200]  [Disc loss: -0.423844] [Gen loss: 0.552679]
# [Epoch 1986/2200]  [Disc loss: -0.419022] [Gen loss: 0.471569]
# [Epoch 1987/2200]  [Disc loss: -0.423012] [Gen loss: 0.552217]
# [Epoch 1988/2200]  [Disc loss: -0.416097] [Gen loss: 0.419526]
# [Epoch 1989/2200]  [Disc loss: -0.418370] [Gen loss: 0.436192]
# [Epoch 1990/2200]  [Disc loss: -0.422518] [Gen loss: 0.730547]
# [Epoch 1991/2200]  [Disc loss: -0.426041] [Gen loss: 0.465763]
# [Epoch 1992/2200]  [Disc loss: -0.422937] [Gen loss: 0.718757]
# [Epoch 1993/2200]  [Disc loss: -0.426667] [Gen loss: 0.482155]
# [Epoch 1994/2200]  [Disc loss: -0.425256] [Gen loss: 0.593023]
# [Epoch 1995/2200]  [Disc loss: -0.421769] [Gen loss: 0.540657]
# [Epoch 1996/2200]  [Disc loss: -0.423835] [Gen loss: 0.458339]
# [Epoch 1997/2200]  [Disc loss: -0.425514] [Gen loss: 0.611621]
# [Epoch 1998/2200]  [Disc loss: -0.417617] [Gen loss: 0.411932]
# [Epoch 1999/2200]  [Disc loss: -0.422252] [Gen loss: 0.548840]
# [Epoch 2000/2200]  [Disc loss: -0.420447] [Gen loss: 0.560916]
# [Epoch 2001/2200]  [Disc loss: -0.416456] [Gen loss: 0.371163]
# [Epoch 2002/2200]  [Disc loss: -0.416498] [Gen loss: 0.515089]
# [Epoch 2003/2200]  [Disc loss: -0.425006] [Gen loss: 0.489289]
# [Epoch 2004/2200]  [Disc loss: -0.418881] [Gen loss: 0.416430]
# [Epoch 2005/2200]  [Disc loss: -0.418509] [Gen loss: 0.406305]
# [Epoch 2006/2200]  [Disc loss: -0.418939] [Gen loss: 0.353698]
# [Epoch 2007/2200]  [Disc loss: -0.423148] [Gen loss: 0.403264]
# [Epoch 2008/2200]  [Disc loss: -0.420471] [Gen loss: 0.581846]
# [Epoch 2009/2200]  [Disc loss: -0.421751] [Gen loss: 0.335532]
# [Epoch 2010/2200]  [Disc loss: -0.421811] [Gen loss: 0.328317]
# [Epoch 2011/2200]  [Disc loss: -0.416517] [Gen loss: 0.396059]
# [Epoch 2012/2200]  [Disc loss: -0.421793] [Gen loss: 0.533329]
# [Epoch 2013/2200]  [Disc loss: -0.425264] [Gen loss: 0.255551]
# [Epoch 2014/2200]  [Disc loss: -0.415079] [Gen loss: 0.601165]
# [Epoch 2015/2200]  [Disc loss: -0.421626] [Gen loss: 0.488695]
# [Epoch 2016/2200]  [Disc loss: -0.418482] [Gen loss: 0.559323]
# [Epoch 2017/2200]  [Disc loss: -0.421966] [Gen loss: 0.538084]
# [Epoch 2018/2200]  [Disc loss: -0.421631] [Gen loss: 0.379874]
# [Epoch 2019/2200]  [Disc loss: -0.420335] [Gen loss: 0.472681]
# [Epoch 2020/2200]  [Disc loss: -0.416642] [Gen loss: 0.294716]
# [Epoch 2021/2200]  [Disc loss: -0.420012] [Gen loss: 0.630061]
# [Epoch 2022/2200]  [Disc loss: -0.418588] [Gen loss: 0.472402]
# [Epoch 2023/2200]  [Disc loss: -0.421478] [Gen loss: 0.385303]
# [Epoch 2024/2200]  [Disc loss: -0.417851] [Gen loss: 0.558757]
# [Epoch 2025/2200]  [Disc loss: -0.419771] [Gen loss: 0.476233]
# [Epoch 2026/2200]  [Disc loss: -0.417362] [Gen loss: 0.566066]
# [Epoch 2027/2200]  [Disc loss: -0.423502] [Gen loss: 0.286065]
# [Epoch 2028/2200]  [Disc loss: -0.416002] [Gen loss: 0.585903]
# [Epoch 2029/2200]  [Disc loss: -0.420239] [Gen loss: 0.324448]
# [Epoch 2030/2200]  [Disc loss: -0.418471] [Gen loss: 0.341880]
# [Epoch 2031/2200]  [Disc loss: -0.425911] [Gen loss: 0.483833]
# [Epoch 2032/2200]  [Disc loss: -0.414627] [Gen loss: 0.424628]
# [Epoch 2033/2200]  [Disc loss: -0.423662] [Gen loss: 0.417249]
# [Epoch 2034/2200]  [Disc loss: -0.417010] [Gen loss: 0.255397]
# [Epoch 2035/2200]  [Disc loss: -0.421988] [Gen loss: 0.335022]
# [Epoch 2036/2200]  [Disc loss: -0.416661] [Gen loss: 0.464889]
# [Epoch 2037/2200]  [Disc loss: -0.416673] [Gen loss: 0.391358]
# [Epoch 2038/2200]  [Disc loss: -0.417558] [Gen loss: 0.262717]
# [Epoch 2039/2200]  [Disc loss: -0.417628] [Gen loss: 0.460675]
# [Epoch 2040/2200]  [Disc loss: -0.413683] [Gen loss: 0.366542]
# [Epoch 2041/2200]  [Disc loss: -0.419011] [Gen loss: 0.341988]
# [Epoch 2042/2200]  [Disc loss: -0.417012] [Gen loss: 0.434965]
# [Epoch 2043/2200]  [Disc loss: -0.414693] [Gen loss: 0.447447]
# [Epoch 2044/2200]  [Disc loss: -0.417443] [Gen loss: 0.331195]
# [Epoch 2045/2200]  [Disc loss: -0.416601] [Gen loss: 0.427978]
# [Epoch 2046/2200]  [Disc loss: -0.416360] [Gen loss: 0.532825]
# [Epoch 2047/2200]  [Disc loss: -0.416299] [Gen loss: 0.414105]
# [Epoch 2048/2200]  [Disc loss: -0.417009] [Gen loss: 0.364449]
# [Epoch 2049/2200]  [Disc loss: -0.414916] [Gen loss: 0.377907]
# [Epoch 2050/2200]  [Disc loss: -0.413191] [Gen loss: 0.441724]
# [Epoch 2051/2200]  [Disc loss: -0.422650] [Gen loss: 0.435559]
# [Epoch 2052/2200]  [Disc loss: -0.414689] [Gen loss: 0.266669]
# [Epoch 2053/2200]  [Disc loss: -0.418553] [Gen loss: 0.457594]
# [Epoch 2054/2200]  [Disc loss: -0.414838] [Gen loss: 0.385628]
# [Epoch 2055/2200]  [Disc loss: -0.415236] [Gen loss: 0.476701]
# [Epoch 2056/2200]  [Disc loss: -0.415175] [Gen loss: 0.419088]
# [Epoch 2057/2200]  [Disc loss: -0.419992] [Gen loss: 0.335082]
# [Epoch 2058/2200]  [Disc loss: -0.422909] [Gen loss: 0.358446]
# [Epoch 2059/2200]  [Disc loss: -0.419448] [Gen loss: 0.549415]
# [Epoch 2060/2200]  [Disc loss: -0.412331] [Gen loss: 0.319731]
# [Epoch 2061/2200]  [Disc loss: -0.418037] [Gen loss: 0.499303]
# [Epoch 2062/2200]  [Disc loss: -0.409958] [Gen loss: 0.367932]
# [Epoch 2063/2200]  [Disc loss: -0.412641] [Gen loss: 0.423125]
# [Epoch 2064/2200]  [Disc loss: -0.409988] [Gen loss: 0.409685]
# [Epoch 2065/2200]  [Disc loss: -0.418153] [Gen loss: 0.296795]
# [Epoch 2066/2200]  [Disc loss: -0.416815] [Gen loss: 0.469393]
# [Epoch 2067/2200]  [Disc loss: -0.410878] [Gen loss: 0.389278]
# [Epoch 2068/2200]  [Disc loss: -0.411663] [Gen loss: 0.436070]
# [Epoch 2069/2200]  [Disc loss: -0.415231] [Gen loss: 0.354074]
# [Epoch 2070/2200]  [Disc loss: -0.411914] [Gen loss: 0.243512]
# [Epoch 2071/2200]  [Disc loss: -0.414376] [Gen loss: 0.319385]
# [Epoch 2072/2200]  [Disc loss: -0.421572] [Gen loss: 0.692597]
# [Epoch 2073/2200]  [Disc loss: -0.414706] [Gen loss: 0.417060]
# [Epoch 2074/2200]  [Disc loss: -0.416165] [Gen loss: 0.521702]
# [Epoch 2075/2200]  [Disc loss: -0.409977] [Gen loss: 0.454624]
# [Epoch 2076/2200]  [Disc loss: -0.414490] [Gen loss: 0.333491]
# [Epoch 2077/2200]  [Disc loss: -0.414963] [Gen loss: 0.565504]
# [Epoch 2078/2200]  [Disc loss: -0.412783] [Gen loss: 0.445788]
# [Epoch 2079/2200]  [Disc loss: -0.412343] [Gen loss: 0.391029]
# [Epoch 2080/2200]  [Disc loss: -0.410321] [Gen loss: 0.448792]
# [Epoch 2081/2200]  [Disc loss: -0.417263] [Gen loss: 0.466895]
# [Epoch 2082/2200]  [Disc loss: -0.415856] [Gen loss: 0.658613]
# [Epoch 2083/2200]  [Disc loss: -0.415524] [Gen loss: 0.388928]
# [Epoch 2084/2200]  [Disc loss: -0.411438] [Gen loss: 0.504576]
# [Epoch 2085/2200]  [Disc loss: -0.408218] [Gen loss: 0.383287]
# [Epoch 2086/2200]  [Disc loss: -0.417596] [Gen loss: 0.537673]
# [Epoch 2087/2200]  [Disc loss: -0.412704] [Gen loss: 0.554910]
# [Epoch 2088/2200]  [Disc loss: -0.419326] [Gen loss: 0.422741]
# [Epoch 2089/2200]  [Disc loss: -0.416033] [Gen loss: 0.276058]
# [Epoch 2090/2200]  [Disc loss: -0.411842] [Gen loss: 0.399930]
# [Epoch 2091/2200]  [Disc loss: -0.411838] [Gen loss: 0.312963]
# [Epoch 2092/2200]  [Disc loss: -0.407019] [Gen loss: 0.436720]
# [Epoch 2093/2200]  [Disc loss: -0.409600] [Gen loss: 0.093424]
# [Epoch 2094/2200]  [Disc loss: -0.413730] [Gen loss: 0.364619]
# [Epoch 2095/2200]  [Disc loss: -0.409290] [Gen loss: 0.253847]
# [Epoch 2096/2200]  [Disc loss: -0.413649] [Gen loss: 0.440703]
# [Epoch 2097/2200]  [Disc loss: -0.406401] [Gen loss: 0.552024]
# [Epoch 2098/2200]  [Disc loss: -0.414323] [Gen loss: 0.299784]
# [Epoch 2099/2200]  [Disc loss: -0.407883] [Gen loss: 0.564636]
# [Epoch 2100/2200]  [Disc loss: -0.410862] [Gen loss: 0.367691]
# [Epoch 2101/2200]  [Disc loss: -0.408483] [Gen loss: 0.415350]
# [Epoch 2102/2200]  [Disc loss: -0.407694] [Gen loss: 0.405729]
# [Epoch 2103/2200]  [Disc loss: -0.410037] [Gen loss: 0.303586]
# [Epoch 2104/2200]  [Disc loss: -0.409100] [Gen loss: 0.304044]
# [Epoch 2105/2200]  [Disc loss: -0.406475] [Gen loss: 0.419819]
# [Epoch 2106/2200]  [Disc loss: -0.415267] [Gen loss: 0.335671]
# [Epoch 2107/2200]  [Disc loss: -0.412945] [Gen loss: 0.348348]
# [Epoch 2108/2200]  [Disc loss: -0.413326] [Gen loss: 0.297927]
# [Epoch 2109/2200]  [Disc loss: -0.408215] [Gen loss: 0.278831]
# [Epoch 2110/2200]  [Disc loss: -0.409630] [Gen loss: 0.481615]
# [Epoch 2111/2200]  [Disc loss: -0.412911] [Gen loss: 0.308954]
# [Epoch 2112/2200]  [Disc loss: -0.409568] [Gen loss: 0.288297]
# [Epoch 2113/2200]  [Disc loss: -0.407091] [Gen loss: 0.458918]
# [Epoch 2114/2200]  [Disc loss: -0.409756] [Gen loss: 0.332638]
# [Epoch 2115/2200]  [Disc loss: -0.404916] [Gen loss: 0.376037]
# [Epoch 2116/2200]  [Disc loss: -0.408621] [Gen loss: 0.406201]
# [Epoch 2117/2200]  [Disc loss: -0.403201] [Gen loss: 0.487230]
# [Epoch 2118/2200]  [Disc loss: -0.417917] [Gen loss: 0.427196]
# [Epoch 2119/2200]  [Disc loss: -0.405879] [Gen loss: 0.403904]
# [Epoch 2120/2200]  [Disc loss: -0.408194] [Gen loss: 0.409213]
# [Epoch 2121/2200]  [Disc loss: -0.414578] [Gen loss: 0.387131]
# [Epoch 2122/2200]  [Disc loss: -0.407582] [Gen loss: 0.611056]
# [Epoch 2123/2200]  [Disc loss: -0.414559] [Gen loss: 0.390757]
# [Epoch 2124/2200]  [Disc loss: -0.404681] [Gen loss: 0.518918]
# [Epoch 2125/2200]  [Disc loss: -0.404678] [Gen loss: 0.362888]
# [Epoch 2126/2200]  [Disc loss: -0.409613] [Gen loss: 0.362565]
# [Epoch 2127/2200]  [Disc loss: -0.404957] [Gen loss: 0.267004]
# [Epoch 2128/2200]  [Disc loss: -0.407794] [Gen loss: 0.574327]
# [Epoch 2129/2200]  [Disc loss: -0.405989] [Gen loss: 0.330954]
# [Epoch 2130/2200]  [Disc loss: -0.406312] [Gen loss: 0.506048]
# [Epoch 2131/2200]  [Disc loss: -0.408142] [Gen loss: 0.502486]
# [Epoch 2132/2200]  [Disc loss: -0.405204] [Gen loss: 0.467297]
# [Epoch 2133/2200]  [Disc loss: -0.405614] [Gen loss: 0.400823]
# [Epoch 2134/2200]  [Disc loss: -0.407450] [Gen loss: 0.434511]
# [Epoch 2135/2200]  [Disc loss: -0.403637] [Gen loss: 0.524032]
# [Epoch 2136/2200]  [Disc loss: -0.410210] [Gen loss: 0.329394]
# [Epoch 2137/2200]  [Disc loss: -0.406433] [Gen loss: 0.594572]
# [Epoch 2138/2200]  [Disc loss: -0.404636] [Gen loss: 0.387221]
# [Epoch 2139/2200]  [Disc loss: -0.400968] [Gen loss: 0.276292]
# [Epoch 2140/2200]  [Disc loss: -0.408860] [Gen loss: 0.298319]
# [Epoch 2141/2200]  [Disc loss: -0.406357] [Gen loss: 0.423977]
# [Epoch 2142/2200]  [Disc loss: -0.400327] [Gen loss: 0.468986]
# [Epoch 2143/2200]  [Disc loss: -0.410906] [Gen loss: 0.423253]
# [Epoch 2144/2200]  [Disc loss: -0.407552] [Gen loss: 0.433133]
# [Epoch 2145/2200]  [Disc loss: -0.405616] [Gen loss: 0.550044]
# [Epoch 2146/2200]  [Disc loss: -0.404920] [Gen loss: 0.406863]
# [Epoch 2147/2200]  [Disc loss: -0.406263] [Gen loss: 0.436409]
# [Epoch 2148/2200]  [Disc loss: -0.406453] [Gen loss: 0.633035]
# [Epoch 2149/2200]  [Disc loss: -0.406620] [Gen loss: 0.320468]
# [Epoch 2150/2200]  [Disc loss: -0.404374] [Gen loss: 0.397064]
# [Epoch 2151/2200]  [Disc loss: -0.407233] [Gen loss: 0.501306]
# [Epoch 2152/2200]  [Disc loss: -0.409203] [Gen loss: 0.266416]
# [Epoch 2153/2200]  [Disc loss: -0.409356] [Gen loss: 0.420073]
# [Epoch 2154/2200]  [Disc loss: -0.401853] [Gen loss: 0.671043]
# [Epoch 2155/2200]  [Disc loss: -0.408259] [Gen loss: 0.345539]
# [Epoch 2156/2200]  [Disc loss: -0.402876] [Gen loss: 0.480114]
# [Epoch 2157/2200]  [Disc loss: -0.408665] [Gen loss: 0.554215]
# [Epoch 2158/2200]  [Disc loss: -0.408489] [Gen loss: 0.524384]
# [Epoch 2159/2200]  [Disc loss: -0.397381] [Gen loss: 0.420231]
# [Epoch 2160/2200]  [Disc loss: -0.410475] [Gen loss: 0.676375]
# [Epoch 2161/2200]  [Disc loss: -0.406419] [Gen loss: 0.380445]
# [Epoch 2162/2200]  [Disc loss: -0.403429] [Gen loss: 0.639435]
# [Epoch 2163/2200]  [Disc loss: -0.405495] [Gen loss: 0.362470]
# [Epoch 2164/2200]  [Disc loss: -0.403661] [Gen loss: 0.441850]
# [Epoch 2165/2200]  [Disc loss: -0.402943] [Gen loss: 0.469729]
# [Epoch 2166/2200]  [Disc loss: -0.408216] [Gen loss: 0.450701]
# [Epoch 2167/2200]  [Disc loss: -0.404229] [Gen loss: 0.535777]
# [Epoch 2168/2200]  [Disc loss: -0.406356] [Gen loss: 0.467672]
# [Epoch 2169/2200]  [Disc loss: -0.402011] [Gen loss: 0.487056]
# [Epoch 2170/2200]  [Disc loss: -0.404372] [Gen loss: 0.443640]
# [Epoch 2171/2200]  [Disc loss: -0.407986] [Gen loss: 0.413658]
# [Epoch 2172/2200]  [Disc loss: -0.403956] [Gen loss: 0.516956]
# [Epoch 2173/2200]  [Disc loss: -0.402100] [Gen loss: 0.499188]
# [Epoch 2174/2200]  [Disc loss: -0.401930] [Gen loss: 0.177964]
# [Epoch 2175/2200]  [Disc loss: -0.406751] [Gen loss: 0.334546]
# [Epoch 2176/2200]  [Disc loss: -0.411832] [Gen loss: 0.358625]
# [Epoch 2177/2200]  [Disc loss: -0.405170] [Gen loss: 0.361202]
# [Epoch 2178/2200]  [Disc loss: -0.397960] [Gen loss: 0.621899]
# [Epoch 2179/2200]  [Disc loss: -0.403901] [Gen loss: 0.389221]
# [Epoch 2180/2200]  [Disc loss: -0.403926] [Gen loss: 0.317911]
# [Epoch 2181/2200]  [Disc loss: -0.398842] [Gen loss: 0.287673]
# [Epoch 2182/2200]  [Disc loss: -0.399852] [Gen loss: 0.508183]
# [Epoch 2183/2200]  [Disc loss: -0.402816] [Gen loss: 0.417993]
# [Epoch 2184/2200]  [Disc loss: -0.404189] [Gen loss: 0.244708]
# [Epoch 2185/2200]  [Disc loss: -0.398700] [Gen loss: 0.240707]
# [Epoch 2186/2200]  [Disc loss: -0.403227] [Gen loss: 0.429149]
# [Epoch 2187/2200]  [Disc loss: -0.406433] [Gen loss: 0.407732]
# [Epoch 2188/2200]  [Disc loss: -0.401105] [Gen loss: 0.518832]
# [Epoch 2189/2200]  [Disc loss: -0.401959] [Gen loss: 0.531632]
# [Epoch 2190/2200]  [Disc loss: -0.402398] [Gen loss: 0.523894]
# [Epoch 2191/2200]  [Disc loss: -0.400017] [Gen loss: 0.394077]
# [Epoch 2192/2200]  [Disc loss: -0.404566] [Gen loss: 0.311754]
# [Epoch 2193/2200]  [Disc loss: -0.400200] [Gen loss: 0.503997]
# [Epoch 2194/2200]  [Disc loss: -0.401015] [Gen loss: 0.252137]
# [Epoch 2195/2200]  [Disc loss: -0.401370] [Gen loss: 0.409275]
# [Epoch 2196/2200]  [Disc loss: -0.400312] [Gen loss: 0.376665]
# [Epoch 2197/2200]  [Disc loss: -0.402368] [Gen loss: 0.383163]
# [Epoch 2198/2200]  [Disc loss: -0.402065] [Gen loss: 0.466981]
# [Epoch 2199/2200]  [Disc loss: -0.405396] [Gen loss: 0.331888]
# Training finished. Generating sample of latent vectors
# 0

# %%
torch.no_grad()
trainer.G.eval()
# Out:
# Generator(
#   (model): Sequential(
#     (0): Linear(in_features=56, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1024, bias=True)
#     (9): BatchNorm1d(1024, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Linear(in_features=1024, out_features=56, bias=True)
#   )
# )

# %%
S = Sampler(generator=trainer.G)
latent = S.sample(10) #10 samples
latent = latent.detach().cpu().numpy().tolist()

# %%
sampled_mols_save_path = os.path.join(trainer.output_model_folder, 'sampled')
np.save(sampled_mols_save_path+f'_epoch{200}', latent)

# %%
x = np.load('asdrp_QGAN/MolGAN-master/sussyoutput/sampled_epoch2199.npy')
# Out:
#          0         1         2   ...        53        54        55
# 0  2.108176  1.893925 -3.531663  ...  0.603406 -0.124114  0.258185
# 1 -1.601339  0.174058  0.083210  ...  0.100140  0.129457  0.518875
# 2  0.207651 -1.724208  0.729644  ... -0.040108 -0.255305  0.497587
# 3 -0.220726  3.110145 -0.886518  ...  1.137102  0.158870 -0.378291
# 4 -1.302804  0.541726  0.775340  ... -0.239455  0.112124  0.485329
# 5  0.850899 -0.367891  0.053300  ...  0.429844  0.645901  0.092834
# 6  1.882317 -0.348617  0.015124  ...  0.306750  0.507072  0.400872
# 7 -1.883415 -0.861364 -1.387948  ...  0.400174 -0.282275 -0.191831
# 8  1.124615 -0.632122  0.027952  ... -0.404833 -0.371575  0.181702
# 9 -0.771928 -0.214135 -0.031244  ...  0.365756  0.092322  0.334798
#
# [10 rows x 56 columns]

# %%
pd.DataFrame(x).head(10).data_shape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-d681c22cdf78> in <module>()
# ----> 1 pd.DataFrame(x).head(10).data_shape()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data_shape'

# %%
count = 0
for a in range(1,31):
    for b in range(1, 31):
        for c in rnage(1, 31):
            if a*b*c == 30: count += 1

# %%
count
