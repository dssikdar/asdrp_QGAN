# %%
import wget

# %%
#url = 'http://www.futurecrew.com/skaven/song_files/mp3/razorback.mp3'
#filename = wget.download(url)
#filename

# %%
wget.download('http://molcyclegan.ardigen.com/250k_rndm_zinc_drugs_clean_3_canonized.csv')
wget.download('http://molcyclegan.ardigen.com/X_JTVAE_250k_rndm_zinc.csv')
# Out:
# 'X_JTVAE_250k_rndm_zinc.csv'

# %%
# %conda install -c pytorch pytorch torchvision
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import torch.optim as optim

# %%
data = pd.read_csv('X_JTVAE_250k_rndm_zinc.csv')

# %%
smiles = data['SMILES'].values
np.savetxt(r'smiles.txt', smiles, fmt='%s')

# %%
class Discriminator(nn.Module):
    def __init__(self, data_shape):
        super(Discriminator, self).__init__()
        self.data_shape = data_shape

        self.model = nn.Sequential(
            nn.Linear(int(np.prod(self.data_shape)), 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
        )

    def forward(self, mol):
        validity = self.model(mol)
        return validity

    def save(self, path):
        save_dict = {
            'model': self.model.state_dict(),
            'data_shape': self.data_shape,
        }
        torch.save(save_dict, path)
        return

    @staticmethod
    def load(path):
        save_dict = torch.load(path)
        D = Discriminator(save_dict['data_shape'])
        D.model.load_state_dict(save_dict["model"])

        return D

# %%
import torch.nn as nn
import numpy as np
import torch


class Generator(nn.Module):
    def __init__(self, data_shape, latent_dim=None):
        super(Generator, self).__init__()
        self.data_shape = data_shape

        # latent dim of the generator is one of the hyperparams.
        # by default it is set to the prod of data_shapes
        self.latent_dim = int(np.prod(self.data_shape)) if latent_dim is None else latent_dim

        def block(in_feat, out_feat, normalize=True):
            layers = [nn.Linear(in_feat, out_feat)]
            if normalize:
                layers.append(nn.BatchNorm1d(out_feat, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        self.model = nn.Sequential(
            *block(self.latent_dim, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, int(np.prod(self.data_shape))),
            # nn.Tanh() # expecting latent vectors to be not normalized
        )

    def forward(self, z):
        out = self.model(z)
        return out

    def save(self, path):
        save_dict = {
            'latent_dim': self.latent_dim,
            'model': self.model.state_dict(),
            'data_shape': self.data_shape,
        }
        torch.save(save_dict, path)

        return

    @staticmethod
    def load(path):
        save_dict = torch.load(path)
        G = Generator(save_dict['data_shape'], latent_dim=save_dict['latent_dim'])
        G.model.load_state_dict(save_dict["model"])

        return G

# %%
class Sampler(object):
    """
    Sampling the mols the generator.
    All scripts should use this class for sampling.
    """

    def __init__(self, generator: Generator):
        self.set_generator(generator)

    def set_generator(self, generator):
        self.G = generator

    def sample(self, n):
        # Sample noise as generator input
        z = torch.cuda.FloatTensor(np.random.uniform(-1, 1, (n, self.G.latent_dim)))
        # Generate a batch of mols
        return self.G(z)

# %%
from torch.utils import data
import json
import numpy as np


class LatentMolsDataset(data.Dataset):
    def __init__(self, latent_space_mols):
        self.data = latent_space_mols

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        return self.data[index]

# %%
import pickle
import os
import torch
import torch.autograd as autograd
import numpy as np
import json
import time
import sys


class TrainModelRunner:
    # Loss weight for gradient penalty
    lambda_gp = 10

    def __init__(self, input_data_path, output_model_folder, decode_mols_save_path='', n_epochs=2000, starting_epoch=1,
                 batch_size=2500, lr=0.0002, b1=0.5, b2=0.999,  n_critic=5,
                 save_interval=1000, sample_after_training=30000, message=""):
        self.message = message

        # init params
        self.input_data_path = input_data_path
        self.output_model_folder = output_model_folder
        self.n_epochs = n_epochs
        self.starting_epoch = starting_epoch
        self.batch_size = batch_size
        self.lr = lr
        self.b1 = b1
        self.b2 = b2
        self.n_critic = n_critic
        self.save_interval = save_interval
        self.sample_after_training = sample_after_training
        self.decode_mols_save_path = decode_mols_save_path

        # initialize dataloader
        smiles_lat = pd.read_csv(input_data_path)
        latent_space_mols = smiles_lat.drop('SMILES', axis=1).values
        latent_space_mols = latent_space_mols.reshape(latent_space_mols.shape[0], 56)

        self.dataloader = torch.utils.data.DataLoader(LatentMolsDataset(latent_space_mols), shuffle=True,
                                                      batch_size=self.batch_size, drop_last=True)

        # load discriminator
        discriminator_name = 'discriminator.txt' if self.starting_epoch == 1 else str(
            self.starting_epoch) + '_discriminator.txt'
        discriminator_path = os.path.join(output_model_folder, discriminator_name)
        #self.D = Discriminator.load(discriminator_path)
        self.D = Discriminator(latent_space_mols[0].shape)
        # load generator
        generator_name = 'generator.txt' if self.starting_epoch == 1 else str(
            self.starting_epoch) + '_generator.txt'
        generator_path = os.path.join(output_model_folder, generator_name)
        #self.G = Generator.load(generator_path)
        self.G = Generator(latent_space_mols[0].shape)
        # initialize sampler
        self.Sampler = Sampler(self.G)

        # initialize optimizer
        self.optimizer_G = torch.optim.Adam(self.G.parameters(), lr=self.lr, betas=(self.b1, self.b2))
        self.optimizer_D = torch.optim.Adam(self.D.parameters(), lr=self.lr, betas=(self.b1, self.b2))

        # Tensor
        cuda = True if torch.cuda.is_available() else False
        if cuda:
            self.G.cuda()
            self.D.cuda()
        self.Tensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor

    def run(self):

        print("Run began.")
        print("Message: %s" % self.message)
        sys.stdout.flush()

        batches_done = 0
        disc_loss_log = []
        g_loss_log = []

        for epoch in range(self.starting_epoch, self.n_epochs + self.starting_epoch):
            disc_loss_per_batch = []
            g_loss_log_per_batch = []
            for i, real_mols in enumerate(self.dataloader):

                # Configure input
                real_mols = real_mols.type(self.Tensor)
                # real_mols = np.squeeze(real_mols, axis=1)

                # ---------------------
                #  Train Discriminator
                # ---------------------

                self.optimizer_D.zero_grad()

                # Generate a batch of mols from noise
                fake_mols = self.Sampler.sample(real_mols.shape[0])

                # Real mols
                real_validity = self.D(real_mols)
                # Fake mols
                fake_validity = self.D(fake_mols)
                # Gradient penalty
                gradient_penalty = self.compute_gradient_penalty(real_mols.data, fake_mols.data)
                # Adversarial loss
                d_loss = -torch.mean(real_validity) + torch.mean(fake_validity) + self.lambda_gp * gradient_penalty
                disc_loss_per_batch.append(d_loss.item())

                d_loss.backward()
                self.optimizer_D.step()
                self.optimizer_G.zero_grad()

                # Train the generator every n_critic steps
                if i % self.n_critic == 0:
                    # -----------------
                    #  Train Generator
                    # -----------------

                    # Generate a batch of mols
                    fake_mols = self.Sampler.sample(real_mols.shape[0])
                    # Loss measures generator's ability to fool the discriminator
                    # Train on fake images
                    fake_validity = self.D(fake_mols)
                    g_loss = -torch.mean(fake_validity)
                    g_loss_log_per_batch.append(g_loss.item())

                    g_loss.backward()
                    self.optimizer_G.step()

                    batches_done += self.n_critic

                # If last batch in the set
                if i == len(self.dataloader) - 1:
                    if epoch % self.save_interval == 0:
                        generator_save_path = os.path.join(self.output_model_folder,
                                                           str(epoch) + '_generator.txt')
                        discriminator_save_path = os.path.join(self.output_model_folder,
                                                               str(epoch) + '_discriminator.txt')
                        self.G.save(generator_save_path)
                        self.D.save(discriminator_save_path)

                    disc_loss_log.append([time.time(), epoch, np.mean(disc_loss_per_batch)])
                    g_loss_log.append([time.time(), epoch, np.mean(g_loss_log_per_batch)])

                    # Print and log
                    print(
                        "[Epoch %d/%d]  [Disc loss: %f] [Gen loss: %f] "
                        % (epoch, self.n_epochs + self.starting_epoch, disc_loss_log[-1][2], g_loss_log[-1][2])
                    )
                    sys.stdout.flush()

        # log the losses
        with open(os.path.join(self.output_model_folder, 'disc_loss.json'), 'w') as json_file:
            json.dump(disc_loss_log, json_file)
        with open(os.path.join(self.output_model_folder, 'gen_loss.json'), 'w') as json_file:
            json.dump(g_loss_log, json_file)

        # Sampling after training
        if self.sample_after_training > 0:
            print("Training finished. Generating sample of latent vectors")
            # sampling mode
            torch.no_grad()
            self.G.eval()

            S = Sampler(generator=self.G)
            latent = S.sample(self.sample_after_training)
            latent = latent.detach().cpu().numpy().tolist()

            sampled_mols_save_path = os.path.join(self.output_model_folder, 'sampled')
            np.save(sampled_mols_save_path+f'_epoch{epoch}', latent)

            # decoding sampled mols

        return 0

    def compute_gradient_penalty(self, real_samples, fake_samples):
        """Calculates the gradient penalty loss for WGAN GP"""
        # Random weight term for interpolation between real and fake samples
        alpha = self.Tensor(np.random.random((real_samples.size(0), 1)))

        # Get random interpolation between real and fake samples
        interpolates = (alpha * real_samples + ((1 - alpha) * fake_samples)).requires_grad_(True)
        d_interpolates = self.D(interpolates)
        fake = self.Tensor(real_samples.shape[0], 1).fill_(1.0)

        # Get gradient w.r.t. interpolates
        gradients = autograd.grad(
            outputs=d_interpolates,
            inputs=interpolates,
            grad_outputs=fake,
            create_graph=True,
            retain_graph=True,
            only_inputs=True,
        )[0]
        gradients = gradients.view(gradients.size(0), -1)
        gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean()

        return gradient_penalty

# %%
trainer = TrainModelRunner('X_JTVAE_250k_rndm_zinc.csv', output_model_folder='content', starting_epoch=200,
                           save_interval=100, message='Starting training', batch_size=2500)

# %%
trainer.run()
# Out:
# Run began.
# Message: Starting training
# [Epoch 200/2200]  [Disc loss: -4.918017] [Gen loss: -0.419686]
# [Epoch 201/2200]  [Disc loss: -10.800661] [Gen loss: -1.444345]
# [Epoch 202/2200]  [Disc loss: -9.768504] [Gen loss: -0.499753]
# [Epoch 203/2200]  [Disc loss: -8.670980] [Gen loss: -0.277073]
# [Epoch 204/2200]  [Disc loss: -8.569320] [Gen loss: -0.447810]
# [Epoch 205/2200]  [Disc loss: -7.927479] [Gen loss: -0.464426]
# [Epoch 206/2200]  [Disc loss: -7.679630] [Gen loss: -0.648365]
# [Epoch 207/2200]  [Disc loss: -7.189933] [Gen loss: -0.734310]
# [Epoch 208/2200]  [Disc loss: -6.711613] [Gen loss: -0.595327]
# [Epoch 209/2200]  [Disc loss: -6.476677] [Gen loss: -0.740527]
# [Epoch 210/2200]  [Disc loss: -6.196911] [Gen loss: -0.783275]
# [Epoch 211/2200]  [Disc loss: -5.884022] [Gen loss: -0.933188]
# [Epoch 212/2200]  [Disc loss: -5.683596] [Gen loss: -0.894367]
# [Epoch 213/2200]  [Disc loss: -5.482324] [Gen loss: -0.748679]
# [Epoch 214/2200]  [Disc loss: -5.200372] [Gen loss: -0.846595]
# [Epoch 215/2200]  [Disc loss: -5.020348] [Gen loss: -0.650156]
# [Epoch 216/2200]  [Disc loss: -4.977599] [Gen loss: -0.604281]
# [Epoch 217/2200]  [Disc loss: -5.017876] [Gen loss: -0.434629]
# [Epoch 218/2200]  [Disc loss: -4.925477] [Gen loss: -0.559727]
# [Epoch 219/2200]  [Disc loss: -4.804678] [Gen loss: -0.713608]
# [Epoch 220/2200]  [Disc loss: -4.843441] [Gen loss: -0.704100]
# [Epoch 221/2200]  [Disc loss: -4.868673] [Gen loss: -0.789855]
# [Epoch 222/2200]  [Disc loss: -4.770540] [Gen loss: -0.848619]
# [Epoch 223/2200]  [Disc loss: -4.847179] [Gen loss: -0.873669]
# [Epoch 224/2200]  [Disc loss: -4.680343] [Gen loss: -0.950484]
# [Epoch 225/2200]  [Disc loss: -4.401661] [Gen loss: -0.905644]
# [Epoch 226/2200]  [Disc loss: -4.420688] [Gen loss: -0.851964]
# [Epoch 227/2200]  [Disc loss: -4.195569] [Gen loss: -1.135876]
# [Epoch 228/2200]  [Disc loss: -4.193282] [Gen loss: -1.175912]
# [Epoch 229/2200]  [Disc loss: -3.751670] [Gen loss: -1.184839]
# [Epoch 230/2200]  [Disc loss: -3.778834] [Gen loss: -1.281548]
# [Epoch 231/2200]  [Disc loss: -3.579427] [Gen loss: -1.212221]
# [Epoch 232/2200]  [Disc loss: -3.536387] [Gen loss: -0.922613]
# [Epoch 233/2200]  [Disc loss: -3.306350] [Gen loss: -0.618447]
# [Epoch 234/2200]  [Disc loss: -3.222109] [Gen loss: -0.941863]
# [Epoch 235/2200]  [Disc loss: -3.278618] [Gen loss: -0.704225]
# [Epoch 236/2200]  [Disc loss: -2.979405] [Gen loss: -0.705909]
# [Epoch 237/2200]  [Disc loss: -3.011624] [Gen loss: -0.374301]
# [Epoch 238/2200]  [Disc loss: -3.070741] [Gen loss: -0.222392]
# [Epoch 239/2200]  [Disc loss: -3.107968] [Gen loss: -0.237571]
# [Epoch 240/2200]  [Disc loss: -3.109314] [Gen loss: -0.020241]
# [Epoch 241/2200]  [Disc loss: -3.117795] [Gen loss: -0.368826]
# [Epoch 242/2200]  [Disc loss: -3.081336] [Gen loss: -0.532993]
# [Epoch 243/2200]  [Disc loss: -2.898444] [Gen loss: -0.193837]
# [Epoch 244/2200]  [Disc loss: -3.014608] [Gen loss: -0.186544]
# [Epoch 245/2200]  [Disc loss: -3.105700] [Gen loss: -0.148037]
# [Epoch 246/2200]  [Disc loss: -3.043419] [Gen loss: -0.549859]
# [Epoch 247/2200]  [Disc loss: -2.942948] [Gen loss: 0.137036]
# [Epoch 248/2200]  [Disc loss: -2.970412] [Gen loss: -0.074047]
# [Epoch 249/2200]  [Disc loss: -2.914012] [Gen loss: -0.390002]
# [Epoch 250/2200]  [Disc loss: -2.928861] [Gen loss: 0.022212]
# [Epoch 251/2200]  [Disc loss: -2.833983] [Gen loss: -0.122360]
# [Epoch 252/2200]  [Disc loss: -2.978315] [Gen loss: -0.179404]
# [Epoch 253/2200]  [Disc loss: -2.873524] [Gen loss: -0.431185]
# [Epoch 254/2200]  [Disc loss: -2.800988] [Gen loss: -0.044623]
# [Epoch 255/2200]  [Disc loss: -2.703057] [Gen loss: -0.621071]
# [Epoch 256/2200]  [Disc loss: -2.751915] [Gen loss: -0.590884]
# [Epoch 257/2200]  [Disc loss: -2.647664] [Gen loss: -0.890103]
# [Epoch 258/2200]  [Disc loss: -2.680132] [Gen loss: -0.717028]
# [Epoch 259/2200]  [Disc loss: -2.618702] [Gen loss: -0.465839]
# [Epoch 260/2200]  [Disc loss: -2.553512] [Gen loss: -0.763368]
# [Epoch 261/2200]  [Disc loss: -2.618171] [Gen loss: -1.101474]
# [Epoch 262/2200]  [Disc loss: -2.549244] [Gen loss: -0.869773]
# [Epoch 263/2200]  [Disc loss: -2.566045] [Gen loss: -1.163869]
# [Epoch 264/2200]  [Disc loss: -2.484152] [Gen loss: -0.913467]
# [Epoch 265/2200]  [Disc loss: -2.389977] [Gen loss: -0.959178]
# [Epoch 266/2200]  [Disc loss: -2.445614] [Gen loss: -1.240292]
# [Epoch 267/2200]  [Disc loss: -2.375619] [Gen loss: -1.351147]
# [Epoch 268/2200]  [Disc loss: -2.410406] [Gen loss: -1.444870]
# [Epoch 269/2200]  [Disc loss: -2.346895] [Gen loss: -1.397315]
# [Epoch 270/2200]  [Disc loss: -2.225459] [Gen loss: -1.661180]
# [Epoch 271/2200]  [Disc loss: -2.164383] [Gen loss: -1.845031]
# [Epoch 272/2200]  [Disc loss: -2.124899] [Gen loss: -1.881823]
# [Epoch 273/2200]  [Disc loss: -2.058620] [Gen loss: -1.861294]
# [Epoch 274/2200]  [Disc loss: -2.029356] [Gen loss: -1.593228]
# [Epoch 275/2200]  [Disc loss: -2.008377] [Gen loss: -1.602705]
# [Epoch 276/2200]  [Disc loss: -2.005484] [Gen loss: -2.140271]
# [Epoch 277/2200]  [Disc loss: -1.992894] [Gen loss: -2.219236]
# [Epoch 278/2200]  [Disc loss: -1.964706] [Gen loss: -2.178820]
# [Epoch 279/2200]  [Disc loss: -1.882975] [Gen loss: -2.004811]
# [Epoch 280/2200]  [Disc loss: -1.815637] [Gen loss: -2.389267]
# [Epoch 281/2200]  [Disc loss: -1.737495] [Gen loss: -2.017412]
# [Epoch 282/2200]  [Disc loss: -1.733550] [Gen loss: -1.950080]
# [Epoch 283/2200]  [Disc loss: -1.713096] [Gen loss: -2.066824]
# [Epoch 284/2200]  [Disc loss: -1.799705] [Gen loss: -2.251493]
# [Epoch 285/2200]  [Disc loss: -1.853946] [Gen loss: -3.116236]
# [Epoch 286/2200]  [Disc loss: -1.784185] [Gen loss: -2.840687]
# [Epoch 287/2200]  [Disc loss: -1.765250] [Gen loss: -3.205481]
# [Epoch 288/2200]  [Disc loss: -1.712533] [Gen loss: -3.590711]
# [Epoch 289/2200]  [Disc loss: -1.737935] [Gen loss: -3.593361]
# [Epoch 290/2200]  [Disc loss: -1.699249] [Gen loss: -3.900907]
# [Epoch 291/2200]  [Disc loss: -1.672250] [Gen loss: -4.105552]
# [Epoch 292/2200]  [Disc loss: -1.583941] [Gen loss: -4.169905]
# [Epoch 293/2200]  [Disc loss: -1.534149] [Gen loss: -4.345237]
# [Epoch 294/2200]  [Disc loss: -1.627288] [Gen loss: -4.403223]
# [Epoch 295/2200]  [Disc loss: -1.623047] [Gen loss: -4.791027]
# [Epoch 296/2200]  [Disc loss: -1.601239] [Gen loss: -5.052703]
# [Epoch 297/2200]  [Disc loss: -1.509768] [Gen loss: -5.154490]
# [Epoch 298/2200]  [Disc loss: -1.450355] [Gen loss: -5.136924]
# [Epoch 299/2200]  [Disc loss: -1.463266] [Gen loss: -5.194979]
# [Epoch 300/2200]  [Disc loss: -1.486124] [Gen loss: -5.468221]
# [Epoch 301/2200]  [Disc loss: -1.470438] [Gen loss: -5.738208]
# [Epoch 302/2200]  [Disc loss: -1.419405] [Gen loss: -5.824730]
# [Epoch 303/2200]  [Disc loss: -1.421947] [Gen loss: -5.874311]
# [Epoch 304/2200]  [Disc loss: -1.432442] [Gen loss: -5.943535]
# [Epoch 305/2200]  [Disc loss: -1.459590] [Gen loss: -5.805574]
# [Epoch 306/2200]  [Disc loss: -1.503182] [Gen loss: -5.860185]
# [Epoch 307/2200]  [Disc loss: -1.494762] [Gen loss: -5.884780]
# [Epoch 308/2200]  [Disc loss: -1.387254] [Gen loss: -5.982429]
# [Epoch 309/2200]  [Disc loss: -1.414285] [Gen loss: -5.963368]
# [Epoch 310/2200]  [Disc loss: -1.438511] [Gen loss: -5.971455]
# [Epoch 311/2200]  [Disc loss: -1.388935] [Gen loss: -5.677075]
# [Epoch 312/2200]  [Disc loss: -1.396351] [Gen loss: -5.655285]
# [Epoch 313/2200]  [Disc loss: -1.382100] [Gen loss: -5.798697]
# [Epoch 314/2200]  [Disc loss: -1.363119] [Gen loss: -5.869480]
# [Epoch 315/2200]  [Disc loss: -1.372731] [Gen loss: -5.800757]
# [Epoch 316/2200]  [Disc loss: -1.350032] [Gen loss: -5.558320]
# [Epoch 317/2200]  [Disc loss: -1.327149] [Gen loss: -5.535704]
# [Epoch 318/2200]  [Disc loss: -1.353527] [Gen loss: -5.462984]
# [Epoch 319/2200]  [Disc loss: -1.337293] [Gen loss: -5.441341]
# [Epoch 320/2200]  [Disc loss: -1.265055] [Gen loss: -5.358879]
# [Epoch 321/2200]  [Disc loss: -1.297362] [Gen loss: -5.580453]
# [Epoch 322/2200]  [Disc loss: -1.340043] [Gen loss: -5.717913]
# [Epoch 323/2200]  [Disc loss: -1.270812] [Gen loss: -5.679271]
# [Epoch 324/2200]  [Disc loss: -1.277938] [Gen loss: -5.820198]
# [Epoch 325/2200]  [Disc loss: -1.261737] [Gen loss: -5.793058]
# [Epoch 326/2200]  [Disc loss: -1.253826] [Gen loss: -5.874670]
# [Epoch 327/2200]  [Disc loss: -1.285503] [Gen loss: -6.114434]
# [Epoch 328/2200]  [Disc loss: -1.229156] [Gen loss: -6.026992]
# [Epoch 329/2200]  [Disc loss: -1.173935] [Gen loss: -5.727431]
# [Epoch 330/2200]  [Disc loss: -1.219337] [Gen loss: -5.975587]
# [Epoch 331/2200]  [Disc loss: -1.203248] [Gen loss: -5.729454]
# [Epoch 332/2200]  [Disc loss: -1.209566] [Gen loss: -5.655477]
# [Epoch 333/2200]  [Disc loss: -1.195251] [Gen loss: -5.452358]
# [Epoch 334/2200]  [Disc loss: -1.156187] [Gen loss: -5.121678]
# [Epoch 335/2200]  [Disc loss: -1.149792] [Gen loss: -5.031679]
# [Epoch 336/2200]  [Disc loss: -1.148945] [Gen loss: -5.009090]
# [Epoch 337/2200]  [Disc loss: -1.097907] [Gen loss: -5.045149]
# [Epoch 338/2200]  [Disc loss: -1.100305] [Gen loss: -5.103206]
# [Epoch 339/2200]  [Disc loss: -1.080007] [Gen loss: -4.957438]
# [Epoch 340/2200]  [Disc loss: -1.078788] [Gen loss: -5.065842]
# [Epoch 341/2200]  [Disc loss: -1.058429] [Gen loss: -4.997929]
# [Epoch 342/2200]  [Disc loss: -1.039819] [Gen loss: -5.012943]
# [Epoch 343/2200]  [Disc loss: -1.038722] [Gen loss: -4.974489]
# [Epoch 344/2200]  [Disc loss: -1.026014] [Gen loss: -5.083472]
# [Epoch 345/2200]  [Disc loss: -1.012969] [Gen loss: -4.863897]
# [Epoch 346/2200]  [Disc loss: -1.013029] [Gen loss: -4.810648]
# [Epoch 347/2200]  [Disc loss: -0.975013] [Gen loss: -4.871234]
# [Epoch 348/2200]  [Disc loss: -0.971368] [Gen loss: -4.985945]
# [Epoch 349/2200]  [Disc loss: -0.973310] [Gen loss: -5.037743]
# [Epoch 350/2200]  [Disc loss: -0.972598] [Gen loss: -5.002247]
# [Epoch 351/2200]  [Disc loss: -0.946709] [Gen loss: -5.067622]
# [Epoch 352/2200]  [Disc loss: -0.946567] [Gen loss: -4.740485]
# [Epoch 353/2200]  [Disc loss: -0.911566] [Gen loss: -4.727101]
# [Epoch 354/2200]  [Disc loss: -0.931653] [Gen loss: -4.151184]
# [Epoch 355/2200]  [Disc loss: -0.930566] [Gen loss: -4.662828]
# [Epoch 356/2200]  [Disc loss: -0.877169] [Gen loss: -4.251271]
# [Epoch 357/2200]  [Disc loss: -0.871246] [Gen loss: -4.087278]
# [Epoch 358/2200]  [Disc loss: -0.904252] [Gen loss: -4.186006]
# [Epoch 359/2200]  [Disc loss: -0.870973] [Gen loss: -4.380806]
# [Epoch 360/2200]  [Disc loss: -0.891535] [Gen loss: -4.155376]
# [Epoch 361/2200]  [Disc loss: -0.863196] [Gen loss: -3.988393]
# [Epoch 362/2200]  [Disc loss: -0.877342] [Gen loss: -4.191373]
# [Epoch 363/2200]  [Disc loss: -0.876940] [Gen loss: -3.828330]
# [Epoch 364/2200]  [Disc loss: -0.858197] [Gen loss: -3.510954]
# [Epoch 365/2200]  [Disc loss: -0.870249] [Gen loss: -3.759133]
# [Epoch 366/2200]  [Disc loss: -0.856655] [Gen loss: -3.666107]
# [Epoch 367/2200]  [Disc loss: -0.833323] [Gen loss: -3.394253]
# [Epoch 368/2200]  [Disc loss: -0.852312] [Gen loss: -3.519377]
# [Epoch 369/2200]  [Disc loss: -0.848523] [Gen loss: -3.863521]
# [Epoch 370/2200]  [Disc loss: -0.856918] [Gen loss: -3.565242]
# [Epoch 371/2200]  [Disc loss: -0.841358] [Gen loss: -3.615461]
# [Epoch 372/2200]  [Disc loss: -0.833221] [Gen loss: -3.945852]
# [Epoch 373/2200]  [Disc loss: -0.840153] [Gen loss: -3.369434]
# [Epoch 374/2200]  [Disc loss: -0.853219] [Gen loss: -3.921371]
# [Epoch 375/2200]  [Disc loss: -0.830523] [Gen loss: -3.272159]
# [Epoch 376/2200]  [Disc loss: -0.833069] [Gen loss: -3.247288]
# [Epoch 377/2200]  [Disc loss: -0.844445] [Gen loss: -3.272717]
# [Epoch 378/2200]  [Disc loss: -0.826330] [Gen loss: -3.317647]
# [Epoch 379/2200]  [Disc loss: -0.817433] [Gen loss: -3.424052]
# [Epoch 380/2200]  [Disc loss: -0.838496] [Gen loss: -3.556717]
# [Epoch 381/2200]  [Disc loss: -0.822365] [Gen loss: -3.664674]
# [Epoch 382/2200]  [Disc loss: -0.836904] [Gen loss: -3.474821]
# [Epoch 383/2200]  [Disc loss: -0.825189] [Gen loss: -3.678750]
# [Epoch 384/2200]  [Disc loss: -0.848754] [Gen loss: -3.422538]
# [Epoch 385/2200]  [Disc loss: -0.826442] [Gen loss: -3.276993]
# [Epoch 386/2200]  [Disc loss: -0.825502] [Gen loss: -3.378655]
# [Epoch 387/2200]  [Disc loss: -0.828280] [Gen loss: -3.684629]
# [Epoch 388/2200]  [Disc loss: -0.833202] [Gen loss: -3.286391]
# [Epoch 389/2200]  [Disc loss: -0.837550] [Gen loss: -3.086445]
# [Epoch 390/2200]  [Disc loss: -0.823906] [Gen loss: -3.323550]
# [Epoch 391/2200]  [Disc loss: -0.823820] [Gen loss: -3.266752]
# [Epoch 392/2200]  [Disc loss: -0.814991] [Gen loss: -3.286346]
# [Epoch 393/2200]  [Disc loss: -0.831441] [Gen loss: -3.107309]
# [Epoch 394/2200]  [Disc loss: -0.820581] [Gen loss: -3.367381]
# [Epoch 395/2200]  [Disc loss: -0.827319] [Gen loss: -3.303193]
# [Epoch 396/2200]  [Disc loss: -0.821262] [Gen loss: -3.175099]
# [Epoch 397/2200]  [Disc loss: -0.818976] [Gen loss: -2.973004]
# [Epoch 398/2200]  [Disc loss: -0.820570] [Gen loss: -3.439957]
# [Epoch 399/2200]  [Disc loss: -0.807068] [Gen loss: -3.270411]
# [Epoch 400/2200]  [Disc loss: -0.814669] [Gen loss: -3.371259]
# [Epoch 401/2200]  [Disc loss: -0.819500] [Gen loss: -3.056725]
# [Epoch 402/2200]  [Disc loss: -0.815046] [Gen loss: -3.199352]
# [Epoch 403/2200]  [Disc loss: -0.821630] [Gen loss: -3.319365]
# [Epoch 404/2200]  [Disc loss: -0.816428] [Gen loss: -3.366906]
# [Epoch 405/2200]  [Disc loss: -0.813833] [Gen loss: -3.522244]
# [Epoch 406/2200]  [Disc loss: -0.794386] [Gen loss: -3.386794]
# [Epoch 407/2200]  [Disc loss: -0.805165] [Gen loss: -3.338822]
# [Epoch 408/2200]  [Disc loss: -0.809949] [Gen loss: -3.526813]
# [Epoch 409/2200]  [Disc loss: -0.813289] [Gen loss: -3.569659]
# [Epoch 410/2200]  [Disc loss: -0.813541] [Gen loss: -3.379088]
# [Epoch 411/2200]  [Disc loss: -0.815177] [Gen loss: -3.295477]
# [Epoch 412/2200]  [Disc loss: -0.808953] [Gen loss: -3.286705]
# [Epoch 413/2200]  [Disc loss: -0.801055] [Gen loss: -3.229427]
# [Epoch 414/2200]  [Disc loss: -0.815638] [Gen loss: -3.583147]
# [Epoch 415/2200]  [Disc loss: -0.792535] [Gen loss: -3.273635]
# [Epoch 416/2200]  [Disc loss: -0.817217] [Gen loss: -3.550929]
# [Epoch 417/2200]  [Disc loss: -0.815717] [Gen loss: -3.544945]
# [Epoch 418/2200]  [Disc loss: -0.801055] [Gen loss: -3.236863]
# [Epoch 419/2200]  [Disc loss: -0.811901] [Gen loss: -3.442088]
# [Epoch 420/2200]  [Disc loss: -0.805442] [Gen loss: -3.545923]
# [Epoch 421/2200]  [Disc loss: -0.828632] [Gen loss: -3.480497]
# [Epoch 422/2200]  [Disc loss: -0.823563] [Gen loss: -3.757934]
# [Epoch 423/2200]  [Disc loss: -0.800878] [Gen loss: -3.256240]
# [Epoch 424/2200]  [Disc loss: -0.805159] [Gen loss: -3.365123]
# [Epoch 425/2200]  [Disc loss: -0.829232] [Gen loss: -3.453868]
# [Epoch 426/2200]  [Disc loss: -0.808765] [Gen loss: -3.505778]
# [Epoch 427/2200]  [Disc loss: -0.810896] [Gen loss: -3.510377]
# [Epoch 428/2200]  [Disc loss: -0.816686] [Gen loss: -3.417722]
# [Epoch 429/2200]  [Disc loss: -0.817447] [Gen loss: -3.463584]
# [Epoch 430/2200]  [Disc loss: -0.809173] [Gen loss: -3.179536]
# [Epoch 431/2200]  [Disc loss: -0.803804] [Gen loss: -3.423386]
# [Epoch 432/2200]  [Disc loss: -0.824857] [Gen loss: -3.498883]
# [Epoch 433/2200]  [Disc loss: -0.817836] [Gen loss: -3.512383]
# [Epoch 434/2200]  [Disc loss: -0.802056] [Gen loss: -3.454937]
# [Epoch 435/2200]  [Disc loss: -0.808994] [Gen loss: -3.575119]
# [Epoch 436/2200]  [Disc loss: -0.811594] [Gen loss: -3.622628]
# [Epoch 437/2200]  [Disc loss: -0.810915] [Gen loss: -3.441529]
# [Epoch 438/2200]  [Disc loss: -0.813547] [Gen loss: -3.779636]
# [Epoch 439/2200]  [Disc loss: -0.817786] [Gen loss: -3.888875]
# [Epoch 440/2200]  [Disc loss: -0.808259] [Gen loss: -3.572147]
# [Epoch 441/2200]  [Disc loss: -0.803444] [Gen loss: -3.854853]
# [Epoch 442/2200]  [Disc loss: -0.793359] [Gen loss: -3.489422]
# [Epoch 443/2200]  [Disc loss: -0.800075] [Gen loss: -3.868086]
# [Epoch 444/2200]  [Disc loss: -0.807977] [Gen loss: -3.838788]
# [Epoch 445/2200]  [Disc loss: -0.807832] [Gen loss: -3.819190]
# [Epoch 446/2200]  [Disc loss: -0.790495] [Gen loss: -3.627389]
# [Epoch 447/2200]  [Disc loss: -0.798705] [Gen loss: -3.705624]
# [Epoch 448/2200]  [Disc loss: -0.797999] [Gen loss: -3.713361]
# [Epoch 449/2200]  [Disc loss: -0.782163] [Gen loss: -3.961116]
# [Epoch 450/2200]  [Disc loss: -0.780055] [Gen loss: -3.373186]
# [Epoch 451/2200]  [Disc loss: -0.788059] [Gen loss: -3.625791]
# [Epoch 452/2200]  [Disc loss: -0.790006] [Gen loss: -3.541325]
# [Epoch 453/2200]  [Disc loss: -0.791063] [Gen loss: -3.642824]
# [Epoch 454/2200]  [Disc loss: -0.780252] [Gen loss: -3.581318]
# [Epoch 455/2200]  [Disc loss: -0.781551] [Gen loss: -3.526167]
# [Epoch 456/2200]  [Disc loss: -0.786265] [Gen loss: -3.331405]
# [Epoch 457/2200]  [Disc loss: -0.782414] [Gen loss: -3.414472]
# [Epoch 458/2200]  [Disc loss: -0.771228] [Gen loss: -3.328647]
# [Epoch 459/2200]  [Disc loss: -0.779893] [Gen loss: -3.389699]
# [Epoch 460/2200]  [Disc loss: -0.777095] [Gen loss: -3.367792]
# [Epoch 461/2200]  [Disc loss: -0.779676] [Gen loss: -3.352312]
# [Epoch 462/2200]  [Disc loss: -0.780758] [Gen loss: -3.252027]
# [Epoch 463/2200]  [Disc loss: -0.768057] [Gen loss: -3.259046]
# [Epoch 464/2200]  [Disc loss: -0.780713] [Gen loss: -2.990037]
# [Epoch 465/2200]  [Disc loss: -0.770980] [Gen loss: -3.427438]
# [Epoch 466/2200]  [Disc loss: -0.772053] [Gen loss: -3.308636]
# [Epoch 467/2200]  [Disc loss: -0.773242] [Gen loss: -3.255954]
# [Epoch 468/2200]  [Disc loss: -0.777857] [Gen loss: -3.246827]
# [Epoch 469/2200]  [Disc loss: -0.767700] [Gen loss: -3.252532]
# [Epoch 470/2200]  [Disc loss: -0.774262] [Gen loss: -3.176402]
# [Epoch 471/2200]  [Disc loss: -0.764808] [Gen loss: -3.232968]
# [Epoch 472/2200]  [Disc loss: -0.774002] [Gen loss: -3.512477]
# [Epoch 473/2200]  [Disc loss: -0.768488] [Gen loss: -3.416933]
# [Epoch 474/2200]  [Disc loss: -0.760710] [Gen loss: -3.238097]
# [Epoch 475/2200]  [Disc loss: -0.762529] [Gen loss: -3.102160]
# [Epoch 476/2200]  [Disc loss: -0.766641] [Gen loss: -3.335422]
# [Epoch 477/2200]  [Disc loss: -0.761514] [Gen loss: -2.999707]
# [Epoch 478/2200]  [Disc loss: -0.769695] [Gen loss: -3.234704]
# [Epoch 479/2200]  [Disc loss: -0.754632] [Gen loss: -3.072864]
# [Epoch 480/2200]  [Disc loss: -0.755899] [Gen loss: -3.110379]
# [Epoch 481/2200]  [Disc loss: -0.758785] [Gen loss: -3.028911]
# [Epoch 482/2200]  [Disc loss: -0.752071] [Gen loss: -2.970684]
# [Epoch 483/2200]  [Disc loss: -0.758161] [Gen loss: -3.175286]
# [Epoch 484/2200]  [Disc loss: -0.753015] [Gen loss: -2.928502]
# [Epoch 485/2200]  [Disc loss: -0.758248] [Gen loss: -2.763662]
# [Epoch 486/2200]  [Disc loss: -0.749322] [Gen loss: -2.859531]
# [Epoch 487/2200]  [Disc loss: -0.752485] [Gen loss: -2.764115]
# [Epoch 488/2200]  [Disc loss: -0.753482] [Gen loss: -2.620945]
# [Epoch 489/2200]  [Disc loss: -0.746496] [Gen loss: -2.722207]
# [Epoch 490/2200]  [Disc loss: -0.751580] [Gen loss: -2.459761]
# [Epoch 491/2200]  [Disc loss: -0.750744] [Gen loss: -2.594878]
# [Epoch 492/2200]  [Disc loss: -0.747698] [Gen loss: -2.563935]
# [Epoch 493/2200]  [Disc loss: -0.753580] [Gen loss: -2.682608]
# [Epoch 494/2200]  [Disc loss: -0.740468] [Gen loss: -2.670341]
# [Epoch 495/2200]  [Disc loss: -0.742978] [Gen loss: -2.488572]
# [Epoch 496/2200]  [Disc loss: -0.744940] [Gen loss: -2.751493]
# [Epoch 497/2200]  [Disc loss: -0.742492] [Gen loss: -2.683504]
# [Epoch 498/2200]  [Disc loss: -0.742804] [Gen loss: -2.641490]
# [Epoch 499/2200]  [Disc loss: -0.738249] [Gen loss: -2.632966]
# [Epoch 500/2200]  [Disc loss: -0.738834] [Gen loss: -2.839057]
# [Epoch 501/2200]  [Disc loss: -0.737140] [Gen loss: -2.603303]
# [Epoch 502/2200]  [Disc loss: -0.740699] [Gen loss: -2.750415]
# [Epoch 503/2200]  [Disc loss: -0.734849] [Gen loss: -2.379170]
# [Epoch 504/2200]  [Disc loss: -0.735173] [Gen loss: -2.468909]
# [Epoch 505/2200]  [Disc loss: -0.744258] [Gen loss: -2.541670]
# [Epoch 506/2200]  [Disc loss: -0.731248] [Gen loss: -2.308915]
# [Epoch 507/2200]  [Disc loss: -0.732239] [Gen loss: -2.471820]
# [Epoch 508/2200]  [Disc loss: -0.725875] [Gen loss: -2.463854]
# [Epoch 509/2200]  [Disc loss: -0.731652] [Gen loss: -2.265701]
# [Epoch 510/2200]  [Disc loss: -0.733042] [Gen loss: -2.394137]
# [Epoch 511/2200]  [Disc loss: -0.729350] [Gen loss: -2.220417]
# [Epoch 512/2200]  [Disc loss: -0.722706] [Gen loss: -2.303773]
# [Epoch 513/2200]  [Disc loss: -0.729229] [Gen loss: -2.371645]
# [Epoch 514/2200]  [Disc loss: -0.723440] [Gen loss: -2.304477]
# [Epoch 515/2200]  [Disc loss: -0.722295] [Gen loss: -2.363841]
# [Epoch 516/2200]  [Disc loss: -0.729264] [Gen loss: -2.416245]
# [Epoch 517/2200]  [Disc loss: -0.720975] [Gen loss: -2.113747]
# [Epoch 518/2200]  [Disc loss: -0.722118] [Gen loss: -2.074015]
# [Epoch 519/2200]  [Disc loss: -0.725744] [Gen loss: -2.349198]
# [Epoch 520/2200]  [Disc loss: -0.724541] [Gen loss: -2.402345]
# [Epoch 521/2200]  [Disc loss: -0.723777] [Gen loss: -2.358659]
# [Epoch 522/2200]  [Disc loss: -0.721374] [Gen loss: -2.358125]
# [Epoch 523/2200]  [Disc loss: -0.720434] [Gen loss: -2.190285]
# [Epoch 524/2200]  [Disc loss: -0.720748] [Gen loss: -2.256924]
# [Epoch 525/2200]  [Disc loss: -0.718873] [Gen loss: -2.190479]
# [Epoch 526/2200]  [Disc loss: -0.723128] [Gen loss: -2.091512]
# [Epoch 527/2200]  [Disc loss: -0.717333] [Gen loss: -2.135888]
# [Epoch 528/2200]  [Disc loss: -0.709330] [Gen loss: -1.972280]
# [Epoch 529/2200]  [Disc loss: -0.715314] [Gen loss: -2.201079]
# [Epoch 530/2200]  [Disc loss: -0.714262] [Gen loss: -2.222995]
# [Epoch 531/2200]  [Disc loss: -0.712844] [Gen loss: -2.193610]
# [Epoch 532/2200]  [Disc loss: -0.706643] [Gen loss: -2.279017]
# [Epoch 533/2200]  [Disc loss: -0.708522] [Gen loss: -2.183685]
# [Epoch 534/2200]  [Disc loss: -0.714109] [Gen loss: -1.869196]
# [Epoch 535/2200]  [Disc loss: -0.710391] [Gen loss: -2.306372]
# [Epoch 536/2200]  [Disc loss: -0.713912] [Gen loss: -2.149167]
# [Epoch 537/2200]  [Disc loss: -0.714487] [Gen loss: -2.018645]
# [Epoch 538/2200]  [Disc loss: -0.713041] [Gen loss: -2.034286]
# [Epoch 539/2200]  [Disc loss: -0.707220] [Gen loss: -2.096265]
# [Epoch 540/2200]  [Disc loss: -0.709358] [Gen loss: -2.218474]
# [Epoch 541/2200]  [Disc loss: -0.712615] [Gen loss: -1.994832]
# [Epoch 542/2200]  [Disc loss: -0.703108] [Gen loss: -2.078548]
# [Epoch 543/2200]  [Disc loss: -0.700975] [Gen loss: -1.856818]
# [Epoch 544/2200]  [Disc loss: -0.707451] [Gen loss: -2.202595]
# [Epoch 545/2200]  [Disc loss: -0.709432] [Gen loss: -1.990461]
# [Epoch 546/2200]  [Disc loss: -0.705495] [Gen loss: -1.959983]
# [Epoch 547/2200]  [Disc loss: -0.713789] [Gen loss: -1.992796]
# [Epoch 548/2200]  [Disc loss: -0.708575] [Gen loss: -1.841909]
# [Epoch 549/2200]  [Disc loss: -0.699273] [Gen loss: -1.918611]
# [Epoch 550/2200]  [Disc loss: -0.705473] [Gen loss: -1.797907]
# [Epoch 551/2200]  [Disc loss: -0.707886] [Gen loss: -1.976135]
# [Epoch 552/2200]  [Disc loss: -0.700833] [Gen loss: -1.914939]
# [Epoch 553/2200]  [Disc loss: -0.700793] [Gen loss: -1.798152]
# [Epoch 554/2200]  [Disc loss: -0.701741] [Gen loss: -1.906293]
# [Epoch 555/2200]  [Disc loss: -0.696499] [Gen loss: -1.814401]
# [Epoch 556/2200]  [Disc loss: -0.708481] [Gen loss: -1.890702]
# [Epoch 557/2200]  [Disc loss: -0.701367] [Gen loss: -1.596486]
# [Epoch 558/2200]  [Disc loss: -0.697218] [Gen loss: -1.558424]
# [Epoch 559/2200]  [Disc loss: -0.707571] [Gen loss: -1.565145]
# [Epoch 560/2200]  [Disc loss: -0.705591] [Gen loss: -1.730360]
# [Epoch 561/2200]  [Disc loss: -0.698612] [Gen loss: -1.469032]
# [Epoch 562/2200]  [Disc loss: -0.701332] [Gen loss: -1.529896]
# [Epoch 563/2200]  [Disc loss: -0.699924] [Gen loss: -1.647268]
# [Epoch 564/2200]  [Disc loss: -0.703812] [Gen loss: -1.688721]
# [Epoch 565/2200]  [Disc loss: -0.695407] [Gen loss: -1.571877]
# [Epoch 566/2200]  [Disc loss: -0.705834] [Gen loss: -1.554613]
# [Epoch 567/2200]  [Disc loss: -0.697884] [Gen loss: -1.423236]
# [Epoch 568/2200]  [Disc loss: -0.699245] [Gen loss: -1.621126]
# [Epoch 569/2200]  [Disc loss: -0.696349] [Gen loss: -1.346988]
# [Epoch 570/2200]  [Disc loss: -0.697451] [Gen loss: -1.482418]
# [Epoch 571/2200]  [Disc loss: -0.694317] [Gen loss: -1.492305]
# [Epoch 572/2200]  [Disc loss: -0.692324] [Gen loss: -1.438139]
# [Epoch 573/2200]  [Disc loss: -0.694506] [Gen loss: -1.444476]
# [Epoch 574/2200]  [Disc loss: -0.698113] [Gen loss: -1.492829]
# [Epoch 575/2200]  [Disc loss: -0.695654] [Gen loss: -1.236910]
# [Epoch 576/2200]  [Disc loss: -0.693579] [Gen loss: -1.289503]
# [Epoch 577/2200]  [Disc loss: -0.697712] [Gen loss: -1.447491]
# [Epoch 578/2200]  [Disc loss: -0.689351] [Gen loss: -1.307707]
# [Epoch 579/2200]  [Disc loss: -0.696831] [Gen loss: -1.086438]
# [Epoch 580/2200]  [Disc loss: -0.691934] [Gen loss: -1.136308]
# [Epoch 581/2200]  [Disc loss: -0.694895] [Gen loss: -1.189810]
# [Epoch 582/2200]  [Disc loss: -0.694545] [Gen loss: -1.083658]
# [Epoch 583/2200]  [Disc loss: -0.688646] [Gen loss: -1.138693]
# [Epoch 584/2200]  [Disc loss: -0.689106] [Gen loss: -1.034275]
# [Epoch 585/2200]  [Disc loss: -0.693726] [Gen loss: -0.913677]
# [Epoch 586/2200]  [Disc loss: -0.687930] [Gen loss: -1.048543]
# [Epoch 587/2200]  [Disc loss: -0.691724] [Gen loss: -1.153497]
# [Epoch 588/2200]  [Disc loss: -0.688641] [Gen loss: -0.833534]
# [Epoch 589/2200]  [Disc loss: -0.695497] [Gen loss: -0.889482]
# [Epoch 590/2200]  [Disc loss: -0.690524] [Gen loss: -0.958168]
# [Epoch 591/2200]  [Disc loss: -0.688773] [Gen loss: -0.832090]
# [Epoch 592/2200]  [Disc loss: -0.691756] [Gen loss: -1.017403]
# [Epoch 593/2200]  [Disc loss: -0.685953] [Gen loss: -0.841959]
# [Epoch 594/2200]  [Disc loss: -0.690068] [Gen loss: -0.974219]
# [Epoch 595/2200]  [Disc loss: -0.691993] [Gen loss: -0.703899]
# [Epoch 596/2200]  [Disc loss: -0.691057] [Gen loss: -0.748925]
# [Epoch 597/2200]  [Disc loss: -0.686594] [Gen loss: -0.896824]
# [Epoch 598/2200]  [Disc loss: -0.687710] [Gen loss: -0.698291]
# [Epoch 599/2200]  [Disc loss: -0.687949] [Gen loss: -0.837501]
# [Epoch 600/2200]  [Disc loss: -0.689391] [Gen loss: -0.702145]
# [Epoch 601/2200]  [Disc loss: -0.687164] [Gen loss: -0.530659]
# [Epoch 602/2200]  [Disc loss: -0.689005] [Gen loss: -0.604887]
# [Epoch 603/2200]  [Disc loss: -0.680266] [Gen loss: -0.677277]
# [Epoch 604/2200]  [Disc loss: -0.688294] [Gen loss: -0.673952]
# [Epoch 605/2200]  [Disc loss: -0.686727] [Gen loss: -0.644995]
# [Epoch 606/2200]  [Disc loss: -0.686837] [Gen loss: -0.527599]
# [Epoch 607/2200]  [Disc loss: -0.679400] [Gen loss: -0.478214]
# [Epoch 608/2200]  [Disc loss: -0.681709] [Gen loss: -0.693229]
# [Epoch 609/2200]  [Disc loss: -0.685850] [Gen loss: -0.478789]
# [Epoch 610/2200]  [Disc loss: -0.681019] [Gen loss: -0.389839]
# [Epoch 611/2200]  [Disc loss: -0.683618] [Gen loss: -0.621868]
# [Epoch 612/2200]  [Disc loss: -0.684111] [Gen loss: -0.596393]
# [Epoch 613/2200]  [Disc loss: -0.678771] [Gen loss: -0.559231]
# [Epoch 614/2200]  [Disc loss: -0.683244] [Gen loss: -0.529264]
# [Epoch 615/2200]  [Disc loss: -0.678528] [Gen loss: -0.598306]
# [Epoch 616/2200]  [Disc loss: -0.683192] [Gen loss: -0.575304]
# [Epoch 617/2200]  [Disc loss: -0.672112] [Gen loss: -0.481028]
# [Epoch 618/2200]  [Disc loss: -0.677267] [Gen loss: -0.397752]
# [Epoch 619/2200]  [Disc loss: -0.679947] [Gen loss: -0.405574]
# [Epoch 620/2200]  [Disc loss: -0.674197] [Gen loss: -0.498030]
# [Epoch 621/2200]  [Disc loss: -0.675388] [Gen loss: -0.343416]
# [Epoch 622/2200]  [Disc loss: -0.676533] [Gen loss: -0.319857]
# [Epoch 623/2200]  [Disc loss: -0.673341] [Gen loss: -0.191394]
# [Epoch 624/2200]  [Disc loss: -0.678374] [Gen loss: -0.322975]
# [Epoch 625/2200]  [Disc loss: -0.676377] [Gen loss: -0.121806]
# [Epoch 626/2200]  [Disc loss: -0.677829] [Gen loss: -0.174053]
# [Epoch 627/2200]  [Disc loss: -0.680538] [Gen loss: -0.184611]
# [Epoch 628/2200]  [Disc loss: -0.677547] [Gen loss: -0.120974]
# [Epoch 629/2200]  [Disc loss: -0.674771] [Gen loss: -0.173614]
# [Epoch 630/2200]  [Disc loss: -0.667002] [Gen loss: -0.236684]
# [Epoch 631/2200]  [Disc loss: -0.677196] [Gen loss: -0.264607]
# [Epoch 632/2200]  [Disc loss: -0.667126] [Gen loss: -0.157963]
# [Epoch 633/2200]  [Disc loss: -0.674982] [Gen loss: -0.273297]
# [Epoch 634/2200]  [Disc loss: -0.668482] [Gen loss: -0.218756]
# [Epoch 635/2200]  [Disc loss: -0.665340] [Gen loss: 0.002824]
# [Epoch 636/2200]  [Disc loss: -0.667071] [Gen loss: -0.086763]
# [Epoch 637/2200]  [Disc loss: -0.669127] [Gen loss: -0.086411]
# [Epoch 638/2200]  [Disc loss: -0.674599] [Gen loss: 0.048885]
# [Epoch 639/2200]  [Disc loss: -0.669945] [Gen loss: -0.129640]
# [Epoch 640/2200]  [Disc loss: -0.670170] [Gen loss: -0.010300]
# [Epoch 641/2200]  [Disc loss: -0.669310] [Gen loss: 0.063463]
# [Epoch 642/2200]  [Disc loss: -0.670859] [Gen loss: 0.373725]
# [Epoch 643/2200]  [Disc loss: -0.671823] [Gen loss: 0.186621]
# [Epoch 644/2200]  [Disc loss: -0.664657] [Gen loss: 0.022493]
# [Epoch 645/2200]  [Disc loss: -0.666993] [Gen loss: 0.052849]
# [Epoch 646/2200]  [Disc loss: -0.669697] [Gen loss: -0.008305]
# [Epoch 647/2200]  [Disc loss: -0.658271] [Gen loss: 0.095521]
# [Epoch 648/2200]  [Disc loss: -0.672533] [Gen loss: -0.041121]
# [Epoch 649/2200]  [Disc loss: -0.666035] [Gen loss: 0.166056]
# [Epoch 650/2200]  [Disc loss: -0.661599] [Gen loss: 0.197782]
# [Epoch 651/2200]  [Disc loss: -0.664311] [Gen loss: 0.259433]
# [Epoch 652/2200]  [Disc loss: -0.659229] [Gen loss: 0.068838]
# [Epoch 653/2200]  [Disc loss: -0.664982] [Gen loss: 0.097140]
# [Epoch 654/2200]  [Disc loss: -0.663410] [Gen loss: 0.245397]
# [Epoch 655/2200]  [Disc loss: -0.664517] [Gen loss: 0.237994]
# [Epoch 656/2200]  [Disc loss: -0.660651] [Gen loss: 0.354236]
# [Epoch 657/2200]  [Disc loss: -0.661613] [Gen loss: 0.265917]
# [Epoch 658/2200]  [Disc loss: -0.659917] [Gen loss: 0.534661]
# [Epoch 659/2200]  [Disc loss: -0.666995] [Gen loss: 0.310522]
# [Epoch 660/2200]  [Disc loss: -0.658942] [Gen loss: 0.423138]
# [Epoch 661/2200]  [Disc loss: -0.658986] [Gen loss: 0.455691]
# [Epoch 662/2200]  [Disc loss: -0.659007] [Gen loss: 0.458002]
# [Epoch 663/2200]  [Disc loss: -0.659727] [Gen loss: 0.244396]
# [Epoch 664/2200]  [Disc loss: -0.658057] [Gen loss: 0.522225]
# [Epoch 665/2200]  [Disc loss: -0.659350] [Gen loss: 0.474433]
# [Epoch 666/2200]  [Disc loss: -0.656844] [Gen loss: 0.427332]
# [Epoch 667/2200]  [Disc loss: -0.662051] [Gen loss: 0.419279]
# [Epoch 668/2200]  [Disc loss: -0.652734] [Gen loss: 0.516450]
# [Epoch 669/2200]  [Disc loss: -0.660972] [Gen loss: 0.739877]
# [Epoch 670/2200]  [Disc loss: -0.654785] [Gen loss: 0.534044]
# [Epoch 671/2200]  [Disc loss: -0.652965] [Gen loss: 0.525109]
# [Epoch 672/2200]  [Disc loss: -0.654899] [Gen loss: 0.700902]
# [Epoch 673/2200]  [Disc loss: -0.658073] [Gen loss: 0.789714]
# [Epoch 674/2200]  [Disc loss: -0.655511] [Gen loss: 0.809832]
# [Epoch 675/2200]  [Disc loss: -0.655993] [Gen loss: 0.690731]
# [Epoch 676/2200]  [Disc loss: -0.654543] [Gen loss: 0.519920]
# [Epoch 677/2200]  [Disc loss: -0.656691] [Gen loss: 0.875923]
# [Epoch 678/2200]  [Disc loss: -0.655539] [Gen loss: 0.786243]
# [Epoch 679/2200]  [Disc loss: -0.655169] [Gen loss: 0.758892]
# [Epoch 680/2200]  [Disc loss: -0.653682] [Gen loss: 0.603265]
# [Epoch 681/2200]  [Disc loss: -0.657598] [Gen loss: 0.684276]
# [Epoch 682/2200]  [Disc loss: -0.656917] [Gen loss: 0.804436]
# [Epoch 683/2200]  [Disc loss: -0.652225] [Gen loss: 0.550195]
# [Epoch 684/2200]  [Disc loss: -0.655360] [Gen loss: 0.761079]
# [Epoch 685/2200]  [Disc loss: -0.650471] [Gen loss: 0.750756]
# [Epoch 686/2200]  [Disc loss: -0.652779] [Gen loss: 0.763928]
# [Epoch 687/2200]  [Disc loss: -0.652653] [Gen loss: 0.566248]
# [Epoch 688/2200]  [Disc loss: -0.647163] [Gen loss: 0.899589]
# [Epoch 689/2200]  [Disc loss: -0.655404] [Gen loss: 0.830239]
# [Epoch 690/2200]  [Disc loss: -0.650118] [Gen loss: 0.805042]
# [Epoch 691/2200]  [Disc loss: -0.645644] [Gen loss: 0.776511]
# [Epoch 692/2200]  [Disc loss: -0.647101] [Gen loss: 0.742598]
# [Epoch 693/2200]  [Disc loss: -0.650197] [Gen loss: 0.895038]
# [Epoch 694/2200]  [Disc loss: -0.647940] [Gen loss: 0.876412]
# [Epoch 695/2200]  [Disc loss: -0.652177] [Gen loss: 0.889214]
# [Epoch 696/2200]  [Disc loss: -0.649823] [Gen loss: 0.664443]
# [Epoch 697/2200]  [Disc loss: -0.652283] [Gen loss: 0.832098]
# [Epoch 698/2200]  [Disc loss: -0.648896] [Gen loss: 0.804746]
# [Epoch 699/2200]  [Disc loss: -0.644845] [Gen loss: 0.754904]
# [Epoch 700/2200]  [Disc loss: -0.650299] [Gen loss: 1.048239]
# [Epoch 701/2200]  [Disc loss: -0.645526] [Gen loss: 0.949040]
# [Epoch 702/2200]  [Disc loss: -0.647627] [Gen loss: 0.821620]
# [Epoch 703/2200]  [Disc loss: -0.651338] [Gen loss: 0.817310]
# [Epoch 704/2200]  [Disc loss: -0.643398] [Gen loss: 1.080826]
# [Epoch 705/2200]  [Disc loss: -0.646929] [Gen loss: 1.000341]
# [Epoch 706/2200]  [Disc loss: -0.645579] [Gen loss: 0.971233]
# [Epoch 707/2200]  [Disc loss: -0.647635] [Gen loss: 0.674155]
# [Epoch 708/2200]  [Disc loss: -0.644296] [Gen loss: 0.916959]
# [Epoch 709/2200]  [Disc loss: -0.645089] [Gen loss: 1.098232]
# [Epoch 710/2200]  [Disc loss: -0.648722] [Gen loss: 0.763620]
# [Epoch 711/2200]  [Disc loss: -0.641873] [Gen loss: 0.779858]
# [Epoch 712/2200]  [Disc loss: -0.639414] [Gen loss: 0.791948]
# [Epoch 713/2200]  [Disc loss: -0.644337] [Gen loss: 0.909602]
# [Epoch 714/2200]  [Disc loss: -0.641190] [Gen loss: 0.795411]
# [Epoch 715/2200]  [Disc loss: -0.647812] [Gen loss: 0.920075]
# [Epoch 716/2200]  [Disc loss: -0.642885] [Gen loss: 0.960809]
# [Epoch 717/2200]  [Disc loss: -0.640778] [Gen loss: 0.830638]
# [Epoch 718/2200]  [Disc loss: -0.639525] [Gen loss: 1.052870]
# [Epoch 719/2200]  [Disc loss: -0.643588] [Gen loss: 1.045407]
# [Epoch 720/2200]  [Disc loss: -0.643117] [Gen loss: 0.905414]
# [Epoch 721/2200]  [Disc loss: -0.638008] [Gen loss: 0.855716]
# [Epoch 722/2200]  [Disc loss: -0.639401] [Gen loss: 0.987604]
# [Epoch 723/2200]  [Disc loss: -0.641213] [Gen loss: 0.751209]
# [Epoch 724/2200]  [Disc loss: -0.642058] [Gen loss: 0.829533]
# [Epoch 725/2200]  [Disc loss: -0.645902] [Gen loss: 1.177840]
# [Epoch 726/2200]  [Disc loss: -0.639074] [Gen loss: 1.143871]
# [Epoch 727/2200]  [Disc loss: -0.641958] [Gen loss: 0.952973]
# [Epoch 728/2200]  [Disc loss: -0.634321] [Gen loss: 0.947684]
# [Epoch 729/2200]  [Disc loss: -0.640240] [Gen loss: 1.082753]
# [Epoch 730/2200]  [Disc loss: -0.637465] [Gen loss: 1.015662]
# [Epoch 731/2200]  [Disc loss: -0.635985] [Gen loss: 1.038224]
# [Epoch 732/2200]  [Disc loss: -0.638906] [Gen loss: 1.050034]
# [Epoch 733/2200]  [Disc loss: -0.635056] [Gen loss: 1.014113]
# [Epoch 734/2200]  [Disc loss: -0.641173] [Gen loss: 0.926091]
# [Epoch 735/2200]  [Disc loss: -0.635789] [Gen loss: 0.848251]
# [Epoch 736/2200]  [Disc loss: -0.633620] [Gen loss: 0.973626]
# [Epoch 737/2200]  [Disc loss: -0.631924] [Gen loss: 1.064839]
# [Epoch 738/2200]  [Disc loss: -0.637243] [Gen loss: 1.043757]
# [Epoch 739/2200]  [Disc loss: -0.632138] [Gen loss: 0.984466]
# [Epoch 740/2200]  [Disc loss: -0.636395] [Gen loss: 0.891426]
# [Epoch 741/2200]  [Disc loss: -0.641033] [Gen loss: 1.044128]
# [Epoch 742/2200]  [Disc loss: -0.634995] [Gen loss: 0.979059]
# [Epoch 743/2200]  [Disc loss: -0.632479] [Gen loss: 0.844088]
# [Epoch 744/2200]  [Disc loss: -0.630141] [Gen loss: 1.197908]
# [Epoch 745/2200]  [Disc loss: -0.632320] [Gen loss: 0.890108]
# [Epoch 746/2200]  [Disc loss: -0.637175] [Gen loss: 0.985459]
# [Epoch 747/2200]  [Disc loss: -0.626549] [Gen loss: 1.122726]
# [Epoch 748/2200]  [Disc loss: -0.634942] [Gen loss: 1.072529]
# [Epoch 749/2200]  [Disc loss: -0.636887] [Gen loss: 1.034673]
# [Epoch 750/2200]  [Disc loss: -0.629971] [Gen loss: 1.161249]
# [Epoch 751/2200]  [Disc loss: -0.636032] [Gen loss: 1.312928]
# [Epoch 752/2200]  [Disc loss: -0.635323] [Gen loss: 1.171716]
# [Epoch 753/2200]  [Disc loss: -0.634413] [Gen loss: 1.275905]
# [Epoch 754/2200]  [Disc loss: -0.636678] [Gen loss: 1.102716]
# [Epoch 755/2200]  [Disc loss: -0.631713] [Gen loss: 1.204868]
# [Epoch 756/2200]  [Disc loss: -0.638702] [Gen loss: 1.267136]
# [Epoch 757/2200]  [Disc loss: -0.627905] [Gen loss: 1.355867]
# [Epoch 758/2200]  [Disc loss: -0.631889] [Gen loss: 1.189367]
# [Epoch 759/2200]  [Disc loss: -0.632859] [Gen loss: 1.255738]
# [Epoch 760/2200]  [Disc loss: -0.628630] [Gen loss: 1.218947]
# [Epoch 761/2200]  [Disc loss: -0.635194] [Gen loss: 1.411726]
# [Epoch 762/2200]  [Disc loss: -0.624085] [Gen loss: 1.272714]
# [Epoch 763/2200]  [Disc loss: -0.626664] [Gen loss: 1.588172]
# [Epoch 764/2200]  [Disc loss: -0.638377] [Gen loss: 1.143920]
# [Epoch 765/2200]  [Disc loss: -0.629893] [Gen loss: 1.303840]
# [Epoch 766/2200]  [Disc loss: -0.635145] [Gen loss: 0.919714]
# [Epoch 767/2200]  [Disc loss: -0.629924] [Gen loss: 1.307188]
# [Epoch 768/2200]  [Disc loss: -0.631512] [Gen loss: 1.351685]
# [Epoch 769/2200]  [Disc loss: -0.630757] [Gen loss: 1.242963]
# [Epoch 770/2200]  [Disc loss: -0.629830] [Gen loss: 1.110257]
# [Epoch 771/2200]  [Disc loss: -0.630555] [Gen loss: 1.387675]
# [Epoch 772/2200]  [Disc loss: -0.630639] [Gen loss: 1.320453]
# [Epoch 773/2200]  [Disc loss: -0.627925] [Gen loss: 1.289079]
# [Epoch 774/2200]  [Disc loss: -0.631305] [Gen loss: 1.382156]
# [Epoch 775/2200]  [Disc loss: -0.623826] [Gen loss: 1.595806]
# [Epoch 776/2200]  [Disc loss: -0.629259] [Gen loss: 1.225727]
# [Epoch 777/2200]  [Disc loss: -0.631698] [Gen loss: 1.466461]
# [Epoch 778/2200]  [Disc loss: -0.632937] [Gen loss: 1.142390]
# [Epoch 779/2200]  [Disc loss: -0.626567] [Gen loss: 1.409996]
# [Epoch 780/2200]  [Disc loss: -0.627132] [Gen loss: 1.329092]
# [Epoch 781/2200]  [Disc loss: -0.630652] [Gen loss: 1.376610]
# [Epoch 782/2200]  [Disc loss: -0.629105] [Gen loss: 1.432410]
# [Epoch 783/2200]  [Disc loss: -0.628199] [Gen loss: 1.188944]
# [Epoch 784/2200]  [Disc loss: -0.626757] [Gen loss: 1.438799]
# [Epoch 785/2200]  [Disc loss: -0.626292] [Gen loss: 1.292809]
# [Epoch 786/2200]  [Disc loss: -0.629246] [Gen loss: 1.316026]
# [Epoch 787/2200]  [Disc loss: -0.622546] [Gen loss: 1.399231]
# [Epoch 788/2200]  [Disc loss: -0.632336] [Gen loss: 1.373351]
# [Epoch 789/2200]  [Disc loss: -0.631728] [Gen loss: 1.281938]
# [Epoch 790/2200]  [Disc loss: -0.621091] [Gen loss: 1.309820]
# [Epoch 791/2200]  [Disc loss: -0.628113] [Gen loss: 1.340726]
# [Epoch 792/2200]  [Disc loss: -0.632150] [Gen loss: 1.388222]
# [Epoch 793/2200]  [Disc loss: -0.632719] [Gen loss: 1.490139]
# [Epoch 794/2200]  [Disc loss: -0.629212] [Gen loss: 1.341609]
# [Epoch 795/2200]  [Disc loss: -0.629187] [Gen loss: 1.346558]
# [Epoch 796/2200]  [Disc loss: -0.631750] [Gen loss: 1.454265]
# [Epoch 797/2200]  [Disc loss: -0.631253] [Gen loss: 1.480539]
# [Epoch 798/2200]  [Disc loss: -0.625136] [Gen loss: 1.591751]
# [Epoch 799/2200]  [Disc loss: -0.626565] [Gen loss: 1.299106]
# [Epoch 800/2200]  [Disc loss: -0.623548] [Gen loss: 1.336383]
# [Epoch 801/2200]  [Disc loss: -0.629742] [Gen loss: 1.411460]
# [Epoch 802/2200]  [Disc loss: -0.622469] [Gen loss: 1.372965]
# [Epoch 803/2200]  [Disc loss: -0.630091] [Gen loss: 1.446606]
# [Epoch 804/2200]  [Disc loss: -0.628727] [Gen loss: 1.221600]
# [Epoch 805/2200]  [Disc loss: -0.625053] [Gen loss: 1.170175]
# [Epoch 806/2200]  [Disc loss: -0.628496] [Gen loss: 1.605738]
# [Epoch 807/2200]  [Disc loss: -0.622046] [Gen loss: 1.354718]
# [Epoch 808/2200]  [Disc loss: -0.625534] [Gen loss: 1.354466]
# [Epoch 809/2200]  [Disc loss: -0.622814] [Gen loss: 1.250615]
# [Epoch 810/2200]  [Disc loss: -0.626235] [Gen loss: 1.269754]
# [Epoch 811/2200]  [Disc loss: -0.619263] [Gen loss: 1.404295]
# [Epoch 812/2200]  [Disc loss: -0.625702] [Gen loss: 1.263988]
# [Epoch 813/2200]  [Disc loss: -0.622462] [Gen loss: 1.517187]
# [Epoch 814/2200]  [Disc loss: -0.624016] [Gen loss: 1.356957]
# [Epoch 815/2200]  [Disc loss: -0.624672] [Gen loss: 1.479156]
# [Epoch 816/2200]  [Disc loss: -0.621056] [Gen loss: 1.391832]
# [Epoch 817/2200]  [Disc loss: -0.619699] [Gen loss: 1.481247]
# [Epoch 818/2200]  [Disc loss: -0.624883] [Gen loss: 1.417826]
# [Epoch 819/2200]  [Disc loss: -0.622370] [Gen loss: 1.566366]
# [Epoch 820/2200]  [Disc loss: -0.624512] [Gen loss: 1.274616]
# [Epoch 821/2200]  [Disc loss: -0.621246] [Gen loss: 1.481492]
# [Epoch 822/2200]  [Disc loss: -0.624927] [Gen loss: 1.480465]
# [Epoch 823/2200]  [Disc loss: -0.626230] [Gen loss: 1.522615]
# [Epoch 824/2200]  [Disc loss: -0.622997] [Gen loss: 1.525234]
# [Epoch 825/2200]  [Disc loss: -0.627486] [Gen loss: 1.451675]
# [Epoch 826/2200]  [Disc loss: -0.621358] [Gen loss: 1.420292]
# [Epoch 827/2200]  [Disc loss: -0.627203] [Gen loss: 1.471326]
# [Epoch 828/2200]  [Disc loss: -0.617704] [Gen loss: 1.436950]
# [Epoch 829/2200]  [Disc loss: -0.620661] [Gen loss: 1.297010]
# [Epoch 830/2200]  [Disc loss: -0.627147] [Gen loss: 1.634580]
# [Epoch 831/2200]  [Disc loss: -0.621796] [Gen loss: 1.422417]
# [Epoch 832/2200]  [Disc loss: -0.617179] [Gen loss: 1.545851]
# [Epoch 833/2200]  [Disc loss: -0.621706] [Gen loss: 1.545840]
# [Epoch 834/2200]  [Disc loss: -0.618265] [Gen loss: 1.462344]
# [Epoch 835/2200]  [Disc loss: -0.620099] [Gen loss: 1.504643]
# [Epoch 836/2200]  [Disc loss: -0.620251] [Gen loss: 1.432391]
# [Epoch 837/2200]  [Disc loss: -0.625598] [Gen loss: 1.790997]
# [Epoch 838/2200]  [Disc loss: -0.618315] [Gen loss: 1.508153]
# [Epoch 839/2200]  [Disc loss: -0.621283] [Gen loss: 1.707115]
# [Epoch 840/2200]  [Disc loss: -0.627074] [Gen loss: 1.819045]
# [Epoch 841/2200]  [Disc loss: -0.619156] [Gen loss: 1.467517]
# [Epoch 842/2200]  [Disc loss: -0.622502] [Gen loss: 1.762401]
# [Epoch 843/2200]  [Disc loss: -0.618376] [Gen loss: 1.512083]
# [Epoch 844/2200]  [Disc loss: -0.621318] [Gen loss: 1.757295]
# [Epoch 845/2200]  [Disc loss: -0.617343] [Gen loss: 1.601654]
# [Epoch 846/2200]  [Disc loss: -0.615509] [Gen loss: 1.517843]
# [Epoch 847/2200]  [Disc loss: -0.617491] [Gen loss: 1.583576]
# [Epoch 848/2200]  [Disc loss: -0.619281] [Gen loss: 1.667624]
# [Epoch 849/2200]  [Disc loss: -0.620360] [Gen loss: 1.489850]
# [Epoch 850/2200]  [Disc loss: -0.618617] [Gen loss: 1.560766]
# [Epoch 851/2200]  [Disc loss: -0.617571] [Gen loss: 1.526776]
# [Epoch 852/2200]  [Disc loss: -0.614308] [Gen loss: 1.330567]
# [Epoch 853/2200]  [Disc loss: -0.621134] [Gen loss: 1.612465]
# [Epoch 854/2200]  [Disc loss: -0.616503] [Gen loss: 1.404050]
# [Epoch 855/2200]  [Disc loss: -0.618583] [Gen loss: 1.549712]
# [Epoch 856/2200]  [Disc loss: -0.610414] [Gen loss: 1.727419]
# [Epoch 857/2200]  [Disc loss: -0.611096] [Gen loss: 1.329811]
# [Epoch 858/2200]  [Disc loss: -0.616979] [Gen loss: 1.494916]
# [Epoch 859/2200]  [Disc loss: -0.617373] [Gen loss: 1.561429]
# [Epoch 860/2200]  [Disc loss: -0.615638] [Gen loss: 1.781373]
# [Epoch 861/2200]  [Disc loss: -0.618388] [Gen loss: 1.809814]
# [Epoch 862/2200]  [Disc loss: -0.616851] [Gen loss: 1.693414]
# [Epoch 863/2200]  [Disc loss: -0.619305] [Gen loss: 1.821677]
# [Epoch 864/2200]  [Disc loss: -0.620551] [Gen loss: 1.729914]
# [Epoch 865/2200]  [Disc loss: -0.616045] [Gen loss: 1.648909]
# [Epoch 866/2200]  [Disc loss: -0.617404] [Gen loss: 1.717855]
# [Epoch 867/2200]  [Disc loss: -0.617051] [Gen loss: 1.857332]
# [Epoch 868/2200]  [Disc loss: -0.613002] [Gen loss: 1.764286]
# [Epoch 869/2200]  [Disc loss: -0.614441] [Gen loss: 1.788033]
# [Epoch 870/2200]  [Disc loss: -0.607514] [Gen loss: 1.924857]
# [Epoch 871/2200]  [Disc loss: -0.614631] [Gen loss: 1.728463]
# [Epoch 872/2200]  [Disc loss: -0.614290] [Gen loss: 1.762602]
# [Epoch 873/2200]  [Disc loss: -0.615876] [Gen loss: 1.858953]
# [Epoch 874/2200]  [Disc loss: -0.620058] [Gen loss: 2.056600]
# [Epoch 875/2200]  [Disc loss: -0.614019] [Gen loss: 1.652786]
# [Epoch 876/2200]  [Disc loss: -0.615347] [Gen loss: 1.736700]
# [Epoch 877/2200]  [Disc loss: -0.613475] [Gen loss: 1.819949]
# [Epoch 878/2200]  [Disc loss: -0.613390] [Gen loss: 1.718764]
# [Epoch 879/2200]  [Disc loss: -0.615668] [Gen loss: 1.898924]
# [Epoch 880/2200]  [Disc loss: -0.614989] [Gen loss: 1.849608]
# [Epoch 881/2200]  [Disc loss: -0.615581] [Gen loss: 1.847616]
# [Epoch 882/2200]  [Disc loss: -0.611742] [Gen loss: 1.745795]
# [Epoch 883/2200]  [Disc loss: -0.612677] [Gen loss: 1.784890]
# [Epoch 884/2200]  [Disc loss: -0.611290] [Gen loss: 1.798816]
# [Epoch 885/2200]  [Disc loss: -0.615313] [Gen loss: 1.918079]
# [Epoch 886/2200]  [Disc loss: -0.615397] [Gen loss: 1.973081]
# [Epoch 887/2200]  [Disc loss: -0.606604] [Gen loss: 1.825352]
# [Epoch 888/2200]  [Disc loss: -0.610568] [Gen loss: 1.956297]
# [Epoch 889/2200]  [Disc loss: -0.609784] [Gen loss: 1.755416]
# [Epoch 890/2200]  [Disc loss: -0.617369] [Gen loss: 1.856686]
# [Epoch 891/2200]  [Disc loss: -0.614822] [Gen loss: 1.975810]
# [Epoch 892/2200]  [Disc loss: -0.610013] [Gen loss: 1.803767]
# [Epoch 893/2200]  [Disc loss: -0.610257] [Gen loss: 1.802046]
# [Epoch 894/2200]  [Disc loss: -0.607974] [Gen loss: 1.886433]
# [Epoch 895/2200]  [Disc loss: -0.609365] [Gen loss: 1.992341]
# [Epoch 896/2200]  [Disc loss: -0.611707] [Gen loss: 1.821686]
# [Epoch 897/2200]  [Disc loss: -0.613799] [Gen loss: 1.912796]
# [Epoch 898/2200]  [Disc loss: -0.614619] [Gen loss: 2.021461]
# [Epoch 899/2200]  [Disc loss: -0.613634] [Gen loss: 1.936117]
# [Epoch 900/2200]  [Disc loss: -0.611992] [Gen loss: 1.773583]
# [Epoch 901/2200]  [Disc loss: -0.609962] [Gen loss: 1.984116]
# [Epoch 902/2200]  [Disc loss: -0.614777] [Gen loss: 2.045480]
# [Epoch 903/2200]  [Disc loss: -0.605030] [Gen loss: 1.944915]
# [Epoch 904/2200]  [Disc loss: -0.612059] [Gen loss: 1.910339]
# [Epoch 905/2200]  [Disc loss: -0.608505] [Gen loss: 1.864094]
# [Epoch 906/2200]  [Disc loss: -0.609591] [Gen loss: 2.051998]
# [Epoch 907/2200]  [Disc loss: -0.610434] [Gen loss: 2.165968]
# [Epoch 908/2200]  [Disc loss: -0.608793] [Gen loss: 1.967927]
# [Epoch 909/2200]  [Disc loss: -0.614310] [Gen loss: 2.066818]
# [Epoch 910/2200]  [Disc loss: -0.604394] [Gen loss: 2.202197]
# [Epoch 911/2200]  [Disc loss: -0.603390] [Gen loss: 1.786431]
# [Epoch 912/2200]  [Disc loss: -0.599597] [Gen loss: 1.974839]
# [Epoch 913/2200]  [Disc loss: -0.608625] [Gen loss: 2.036685]
# [Epoch 914/2200]  [Disc loss: -0.608605] [Gen loss: 1.986090]
# [Epoch 915/2200]  [Disc loss: -0.608273] [Gen loss: 2.217847]
# [Epoch 916/2200]  [Disc loss: -0.606153] [Gen loss: 1.930043]
# [Epoch 917/2200]  [Disc loss: -0.606857] [Gen loss: 2.004503]
# [Epoch 918/2200]  [Disc loss: -0.608026] [Gen loss: 1.957272]
# [Epoch 919/2200]  [Disc loss: -0.607168] [Gen loss: 2.163776]
# [Epoch 920/2200]  [Disc loss: -0.607799] [Gen loss: 1.999980]
# [Epoch 921/2200]  [Disc loss: -0.610379] [Gen loss: 2.309634]
# [Epoch 922/2200]  [Disc loss: -0.606278] [Gen loss: 1.812010]
# [Epoch 923/2200]  [Disc loss: -0.610350] [Gen loss: 2.217948]
# [Epoch 924/2200]  [Disc loss: -0.609663] [Gen loss: 2.055733]
# [Epoch 925/2200]  [Disc loss: -0.605061] [Gen loss: 2.198600]
# [Epoch 926/2200]  [Disc loss: -0.607764] [Gen loss: 1.916063]
# [Epoch 927/2200]  [Disc loss: -0.602054] [Gen loss: 2.175638]
# [Epoch 928/2200]  [Disc loss: -0.600567] [Gen loss: 2.037556]
# [Epoch 929/2200]  [Disc loss: -0.606336] [Gen loss: 2.149224]
# [Epoch 930/2200]  [Disc loss: -0.606725] [Gen loss: 2.141750]
# [Epoch 931/2200]  [Disc loss: -0.604341] [Gen loss: 2.122795]
# [Epoch 932/2200]  [Disc loss: -0.607380] [Gen loss: 2.086634]
# [Epoch 933/2200]  [Disc loss: -0.605645] [Gen loss: 2.185703]
# [Epoch 934/2200]  [Disc loss: -0.602074] [Gen loss: 2.013517]
# [Epoch 935/2200]  [Disc loss: -0.604133] [Gen loss: 2.119055]
# [Epoch 936/2200]  [Disc loss: -0.607091] [Gen loss: 2.169888]
# [Epoch 937/2200]  [Disc loss: -0.599183] [Gen loss: 2.118285]
# [Epoch 938/2200]  [Disc loss: -0.607883] [Gen loss: 2.009252]
# [Epoch 939/2200]  [Disc loss: -0.598856] [Gen loss: 2.282627]
# [Epoch 940/2200]  [Disc loss: -0.593085] [Gen loss: 2.039356]
# [Epoch 941/2200]  [Disc loss: -0.597318] [Gen loss: 2.076183]
# [Epoch 942/2200]  [Disc loss: -0.602246] [Gen loss: 2.084994]
# [Epoch 943/2200]  [Disc loss: -0.602314] [Gen loss: 2.096519]
# [Epoch 944/2200]  [Disc loss: -0.603165] [Gen loss: 2.052703]
# [Epoch 945/2200]  [Disc loss: -0.598295] [Gen loss: 2.124562]
# [Epoch 946/2200]  [Disc loss: -0.599167] [Gen loss: 2.101857]
# [Epoch 947/2200]  [Disc loss: -0.601289] [Gen loss: 2.167565]
# [Epoch 948/2200]  [Disc loss: -0.599034] [Gen loss: 2.142200]
# [Epoch 949/2200]  [Disc loss: -0.602412] [Gen loss: 2.238535]
# [Epoch 950/2200]  [Disc loss: -0.603040] [Gen loss: 2.001495]
# [Epoch 951/2200]  [Disc loss: -0.603178] [Gen loss: 2.178704]
# [Epoch 952/2200]  [Disc loss: -0.597983] [Gen loss: 2.096158]
# [Epoch 953/2200]  [Disc loss: -0.599415] [Gen loss: 2.004916]
# ...
# [Epoch 1955/2200]  [Disc loss: -0.476315] [Gen loss: -0.004602]
# [Epoch 1956/2200]  [Disc loss: -0.472033] [Gen loss: -0.179810]
# [Epoch 1957/2200]  [Disc loss: -0.473986] [Gen loss: -0.026876]
# [Epoch 1958/2200]  [Disc loss: -0.469704] [Gen loss: -0.128441]
# [Epoch 1959/2200]  [Disc loss: -0.474762] [Gen loss: -0.098828]
# [Epoch 1960/2200]  [Disc loss: -0.478853] [Gen loss: -0.096343]
# [Epoch 1961/2200]  [Disc loss: -0.478211] [Gen loss: -0.039173]
# [Epoch 1962/2200]  [Disc loss: -0.482435] [Gen loss: -0.037629]
# [Epoch 1963/2200]  [Disc loss: -0.480018] [Gen loss: 0.026552]
# [Epoch 1964/2200]  [Disc loss: -0.472452] [Gen loss: 0.042881]
# [Epoch 1965/2200]  [Disc loss: -0.469977] [Gen loss: -0.069124]
# [Epoch 1966/2200]  [Disc loss: -0.469292] [Gen loss: -0.072403]
# [Epoch 1967/2200]  [Disc loss: -0.473167] [Gen loss: -0.247855]
# [Epoch 1968/2200]  [Disc loss: -0.471525] [Gen loss: -0.006713]
# [Epoch 1969/2200]  [Disc loss: -0.476185] [Gen loss: -0.066675]
# [Epoch 1970/2200]  [Disc loss: -0.472897] [Gen loss: -0.121705]
# [Epoch 1971/2200]  [Disc loss: -0.476109] [Gen loss: -0.096882]
# [Epoch 1972/2200]  [Disc loss: -0.472228] [Gen loss: -0.009865]
# [Epoch 1973/2200]  [Disc loss: -0.473054] [Gen loss: -0.058165]
# [Epoch 1974/2200]  [Disc loss: -0.474985] [Gen loss: -0.118240]
# [Epoch 1975/2200]  [Disc loss: -0.472781] [Gen loss: -0.123382]
# [Epoch 1976/2200]  [Disc loss: -0.475676] [Gen loss: -0.172397]
# [Epoch 1977/2200]  [Disc loss: -0.471707] [Gen loss: -0.014312]
# [Epoch 1978/2200]  [Disc loss: -0.470635] [Gen loss: -0.104463]
# [Epoch 1979/2200]  [Disc loss: -0.466131] [Gen loss: -0.028813]
# [Epoch 1980/2200]  [Disc loss: -0.475146] [Gen loss: -0.163049]
# [Epoch 1981/2200]  [Disc loss: -0.472269] [Gen loss: -0.107931]
# [Epoch 1982/2200]  [Disc loss: -0.467966] [Gen loss: -0.105670]
# [Epoch 1983/2200]  [Disc loss: -0.477093] [Gen loss: -0.133224]
# [Epoch 1984/2200]  [Disc loss: -0.474967] [Gen loss: 0.067534]
# [Epoch 1985/2200]  [Disc loss: -0.474752] [Gen loss: 0.021901]
# [Epoch 1986/2200]  [Disc loss: -0.473402] [Gen loss: -0.067749]
# [Epoch 1987/2200]  [Disc loss: -0.474659] [Gen loss: -0.133472]
# [Epoch 1988/2200]  [Disc loss: -0.475663] [Gen loss: -0.002332]
# [Epoch 1989/2200]  [Disc loss: -0.471043] [Gen loss: -0.191256]
# [Epoch 1990/2200]  [Disc loss: -0.474502] [Gen loss: 0.013749]
# [Epoch 1991/2200]  [Disc loss: -0.467154] [Gen loss: -0.142643]
# [Epoch 1992/2200]  [Disc loss: -0.475193] [Gen loss: -0.090707]
# [Epoch 1993/2200]  [Disc loss: -0.469670] [Gen loss: -0.053709]
# [Epoch 1994/2200]  [Disc loss: -0.472667] [Gen loss: -0.117850]
# [Epoch 1995/2200]  [Disc loss: -0.471760] [Gen loss: -0.234191]
# [Epoch 1996/2200]  [Disc loss: -0.471373] [Gen loss: -0.183915]
# [Epoch 1997/2200]  [Disc loss: -0.473253] [Gen loss: -0.177528]
# [Epoch 1998/2200]  [Disc loss: -0.473687] [Gen loss: -0.110633]
# [Epoch 1999/2200]  [Disc loss: -0.471067] [Gen loss: -0.150603]
# [Epoch 2000/2200]  [Disc loss: -0.473876] [Gen loss: -0.052556]
# [Epoch 2001/2200]  [Disc loss: -0.469340] [Gen loss: -0.163573]
# [Epoch 2002/2200]  [Disc loss: -0.475433] [Gen loss: -0.112141]
# [Epoch 2003/2200]  [Disc loss: -0.466966] [Gen loss: -0.258881]
# [Epoch 2004/2200]  [Disc loss: -0.467234] [Gen loss: -0.214320]
# [Epoch 2005/2200]  [Disc loss: -0.476285] [Gen loss: -0.319739]
# [Epoch 2006/2200]  [Disc loss: -0.475955] [Gen loss: -0.143327]
# [Epoch 2007/2200]  [Disc loss: -0.473213] [Gen loss: -0.191554]
# [Epoch 2008/2200]  [Disc loss: -0.468742] [Gen loss: -0.154763]
# [Epoch 2009/2200]  [Disc loss: -0.473543] [Gen loss: -0.345868]
# [Epoch 2010/2200]  [Disc loss: -0.466858] [Gen loss: -0.266002]
# [Epoch 2011/2200]  [Disc loss: -0.474304] [Gen loss: -0.301676]
# [Epoch 2012/2200]  [Disc loss: -0.468107] [Gen loss: -0.138687]
# [Epoch 2013/2200]  [Disc loss: -0.464117] [Gen loss: -0.273323]
# [Epoch 2014/2200]  [Disc loss: -0.470337] [Gen loss: -0.164706]
# [Epoch 2015/2200]  [Disc loss: -0.472717] [Gen loss: -0.239640]
# [Epoch 2016/2200]  [Disc loss: -0.471186] [Gen loss: -0.231240]
# [Epoch 2017/2200]  [Disc loss: -0.472537] [Gen loss: -0.236952]
# [Epoch 2018/2200]  [Disc loss: -0.472019] [Gen loss: -0.133975]
# [Epoch 2019/2200]  [Disc loss: -0.470743] [Gen loss: -0.094701]
# [Epoch 2020/2200]  [Disc loss: -0.469578] [Gen loss: -0.297731]
# [Epoch 2021/2200]  [Disc loss: -0.471877] [Gen loss: -0.132202]
# [Epoch 2022/2200]  [Disc loss: -0.470170] [Gen loss: -0.224023]
# [Epoch 2023/2200]  [Disc loss: -0.471857] [Gen loss: -0.148062]
# [Epoch 2024/2200]  [Disc loss: -0.475547] [Gen loss: -0.180340]
# [Epoch 2025/2200]  [Disc loss: -0.471346] [Gen loss: -0.256238]
# [Epoch 2026/2200]  [Disc loss: -0.467652] [Gen loss: -0.178044]
# [Epoch 2027/2200]  [Disc loss: -0.467257] [Gen loss: -0.327280]
# [Epoch 2028/2200]  [Disc loss: -0.467516] [Gen loss: -0.289770]
# [Epoch 2029/2200]  [Disc loss: -0.468551] [Gen loss: -0.298253]
# [Epoch 2030/2200]  [Disc loss: -0.473706] [Gen loss: -0.209518]
# [Epoch 2031/2200]  [Disc loss: -0.469322] [Gen loss: -0.224911]
# [Epoch 2032/2200]  [Disc loss: -0.469678] [Gen loss: -0.376537]
# [Epoch 2033/2200]  [Disc loss: -0.466124] [Gen loss: -0.347587]
# [Epoch 2034/2200]  [Disc loss: -0.468056] [Gen loss: -0.452269]
# [Epoch 2035/2200]  [Disc loss: -0.470062] [Gen loss: -0.286539]
# [Epoch 2036/2200]  [Disc loss: -0.465992] [Gen loss: -0.369574]
# [Epoch 2037/2200]  [Disc loss: -0.468652] [Gen loss: -0.238716]
# [Epoch 2038/2200]  [Disc loss: -0.466267] [Gen loss: -0.392381]
# [Epoch 2039/2200]  [Disc loss: -0.462920] [Gen loss: -0.223185]
# [Epoch 2040/2200]  [Disc loss: -0.470785] [Gen loss: -0.320540]
# [Epoch 2041/2200]  [Disc loss: -0.474702] [Gen loss: -0.234149]
# [Epoch 2042/2200]  [Disc loss: -0.463549] [Gen loss: -0.231470]
# [Epoch 2043/2200]  [Disc loss: -0.469092] [Gen loss: -0.281141]
# [Epoch 2044/2200]  [Disc loss: -0.467029] [Gen loss: -0.377752]
# [Epoch 2045/2200]  [Disc loss: -0.469572] [Gen loss: -0.298358]
# [Epoch 2046/2200]  [Disc loss: -0.467050] [Gen loss: -0.283019]
# [Epoch 2047/2200]  [Disc loss: -0.470541] [Gen loss: -0.341920]
# [Epoch 2048/2200]  [Disc loss: -0.469288] [Gen loss: -0.386785]
# [Epoch 2049/2200]  [Disc loss: -0.469880] [Gen loss: -0.313797]
# [Epoch 2050/2200]  [Disc loss: -0.469744] [Gen loss: -0.252304]
# [Epoch 2051/2200]  [Disc loss: -0.467168] [Gen loss: -0.327312]
# [Epoch 2052/2200]  [Disc loss: -0.469828] [Gen loss: -0.247087]
# [Epoch 2053/2200]  [Disc loss: -0.470697] [Gen loss: -0.249402]
# [Epoch 2054/2200]  [Disc loss: -0.466819] [Gen loss: -0.290717]
# [Epoch 2055/2200]  [Disc loss: -0.468175] [Gen loss: -0.357631]
# [Epoch 2056/2200]  [Disc loss: -0.468669] [Gen loss: -0.428801]
# [Epoch 2057/2200]  [Disc loss: -0.467439] [Gen loss: -0.238465]
# [Epoch 2058/2200]  [Disc loss: -0.470834] [Gen loss: -0.328898]
# [Epoch 2059/2200]  [Disc loss: -0.465875] [Gen loss: -0.359776]
# [Epoch 2060/2200]  [Disc loss: -0.469885] [Gen loss: -0.323967]
# [Epoch 2061/2200]  [Disc loss: -0.466580] [Gen loss: -0.279019]
# [Epoch 2062/2200]  [Disc loss: -0.463629] [Gen loss: -0.241453]
# [Epoch 2063/2200]  [Disc loss: -0.470351] [Gen loss: -0.307488]
# [Epoch 2064/2200]  [Disc loss: -0.467287] [Gen loss: -0.364989]
# [Epoch 2065/2200]  [Disc loss: -0.463624] [Gen loss: -0.293971]
# [Epoch 2066/2200]  [Disc loss: -0.468054] [Gen loss: -0.255965]
# [Epoch 2067/2200]  [Disc loss: -0.467648] [Gen loss: -0.312870]
# [Epoch 2068/2200]  [Disc loss: -0.474178] [Gen loss: -0.365267]
# [Epoch 2069/2200]  [Disc loss: -0.470756] [Gen loss: -0.364796]
# [Epoch 2070/2200]  [Disc loss: -0.464878] [Gen loss: -0.314774]
# [Epoch 2071/2200]  [Disc loss: -0.469400] [Gen loss: -0.312494]
# [Epoch 2072/2200]  [Disc loss: -0.466509] [Gen loss: -0.381338]
# [Epoch 2073/2200]  [Disc loss: -0.459339] [Gen loss: -0.284094]
# [Epoch 2074/2200]  [Disc loss: -0.467778] [Gen loss: -0.322770]
# [Epoch 2075/2200]  [Disc loss: -0.465709] [Gen loss: -0.301345]
# [Epoch 2076/2200]  [Disc loss: -0.467372] [Gen loss: -0.366402]
# [Epoch 2077/2200]  [Disc loss: -0.468585] [Gen loss: -0.281610]
# [Epoch 2078/2200]  [Disc loss: -0.461840] [Gen loss: -0.273220]
# [Epoch 2079/2200]  [Disc loss: -0.464410] [Gen loss: -0.353245]
# [Epoch 2080/2200]  [Disc loss: -0.463494] [Gen loss: -0.085412]
# [Epoch 2081/2200]  [Disc loss: -0.466935] [Gen loss: -0.466296]
# [Epoch 2082/2200]  [Disc loss: -0.466286] [Gen loss: -0.194261]
# [Epoch 2083/2200]  [Disc loss: -0.464854] [Gen loss: -0.383072]
# [Epoch 2084/2200]  [Disc loss: -0.457465] [Gen loss: -0.380925]
# [Epoch 2085/2200]  [Disc loss: -0.467336] [Gen loss: -0.332509]
# [Epoch 2086/2200]  [Disc loss: -0.469277] [Gen loss: -0.399152]
# [Epoch 2087/2200]  [Disc loss: -0.462661] [Gen loss: -0.402345]
# [Epoch 2088/2200]  [Disc loss: -0.458603] [Gen loss: -0.390139]
# [Epoch 2089/2200]  [Disc loss: -0.469295] [Gen loss: -0.526878]
# [Epoch 2090/2200]  [Disc loss: -0.461397] [Gen loss: -0.366707]
# [Epoch 2091/2200]  [Disc loss: -0.457177] [Gen loss: -0.406570]
# [Epoch 2092/2200]  [Disc loss: -0.467011] [Gen loss: -0.422034]
# [Epoch 2093/2200]  [Disc loss: -0.461689] [Gen loss: -0.366730]
# [Epoch 2094/2200]  [Disc loss: -0.466850] [Gen loss: -0.406940]
# [Epoch 2095/2200]  [Disc loss: -0.466581] [Gen loss: -0.266808]
# [Epoch 2096/2200]  [Disc loss: -0.461228] [Gen loss: -0.360291]
# [Epoch 2097/2200]  [Disc loss: -0.461058] [Gen loss: -0.527678]
# [Epoch 2098/2200]  [Disc loss: -0.465701] [Gen loss: -0.378085]
# [Epoch 2099/2200]  [Disc loss: -0.463053] [Gen loss: -0.528189]
# [Epoch 2100/2200]  [Disc loss: -0.467262] [Gen loss: -0.192997]
# [Epoch 2101/2200]  [Disc loss: -0.462998] [Gen loss: -0.339665]
# [Epoch 2102/2200]  [Disc loss: -0.464998] [Gen loss: -0.217198]
# [Epoch 2103/2200]  [Disc loss: -0.466250] [Gen loss: -0.425381]
# [Epoch 2104/2200]  [Disc loss: -0.464252] [Gen loss: -0.329729]
# [Epoch 2105/2200]  [Disc loss: -0.462131] [Gen loss: -0.252439]
# [Epoch 2106/2200]  [Disc loss: -0.461055] [Gen loss: -0.511463]
# [Epoch 2107/2200]  [Disc loss: -0.467878] [Gen loss: -0.283987]
# [Epoch 2108/2200]  [Disc loss: -0.465044] [Gen loss: -0.315950]
# [Epoch 2109/2200]  [Disc loss: -0.464988] [Gen loss: -0.484263]
# [Epoch 2110/2200]  [Disc loss: -0.465449] [Gen loss: -0.273146]
# [Epoch 2111/2200]  [Disc loss: -0.457832] [Gen loss: -0.432503]
# [Epoch 2112/2200]  [Disc loss: -0.466542] [Gen loss: -0.476422]
# [Epoch 2113/2200]  [Disc loss: -0.460003] [Gen loss: -0.338933]
# [Epoch 2114/2200]  [Disc loss: -0.461208] [Gen loss: -0.307578]
# [Epoch 2115/2200]  [Disc loss: -0.467892] [Gen loss: -0.409011]
# [Epoch 2116/2200]  [Disc loss: -0.461680] [Gen loss: -0.368617]
# [Epoch 2117/2200]  [Disc loss: -0.454729] [Gen loss: -0.241617]
# [Epoch 2118/2200]  [Disc loss: -0.463568] [Gen loss: -0.382490]
# [Epoch 2119/2200]  [Disc loss: -0.459065] [Gen loss: -0.345377]
# [Epoch 2120/2200]  [Disc loss: -0.461410] [Gen loss: -0.382411]
# [Epoch 2121/2200]  [Disc loss: -0.460945] [Gen loss: -0.533411]
# [Epoch 2122/2200]  [Disc loss: -0.460781] [Gen loss: -0.520973]
# [Epoch 2123/2200]  [Disc loss: -0.462213] [Gen loss: -0.416836]
# [Epoch 2124/2200]  [Disc loss: -0.463714] [Gen loss: -0.311853]
# [Epoch 2125/2200]  [Disc loss: -0.457230] [Gen loss: -0.342913]
# [Epoch 2126/2200]  [Disc loss: -0.462341] [Gen loss: -0.275645]
# [Epoch 2127/2200]  [Disc loss: -0.461621] [Gen loss: -0.247991]
# [Epoch 2128/2200]  [Disc loss: -0.462279] [Gen loss: -0.408742]
# [Epoch 2129/2200]  [Disc loss: -0.461246] [Gen loss: -0.567119]
# [Epoch 2130/2200]  [Disc loss: -0.462706] [Gen loss: -0.208663]
# [Epoch 2131/2200]  [Disc loss: -0.460493] [Gen loss: -0.257696]
# [Epoch 2132/2200]  [Disc loss: -0.459891] [Gen loss: -0.432044]
# [Epoch 2133/2200]  [Disc loss: -0.463775] [Gen loss: -0.401406]
# [Epoch 2134/2200]  [Disc loss: -0.462264] [Gen loss: -0.371302]
# [Epoch 2135/2200]  [Disc loss: -0.459274] [Gen loss: -0.408114]
# [Epoch 2136/2200]  [Disc loss: -0.457129] [Gen loss: -0.433429]
# [Epoch 2137/2200]  [Disc loss: -0.462765] [Gen loss: -0.309905]
# [Epoch 2138/2200]  [Disc loss: -0.456847] [Gen loss: -0.432304]
# [Epoch 2139/2200]  [Disc loss: -0.454169] [Gen loss: -0.445157]
# [Epoch 2140/2200]  [Disc loss: -0.459749] [Gen loss: -0.333598]
# [Epoch 2141/2200]  [Disc loss: -0.464590] [Gen loss: -0.306111]
# [Epoch 2142/2200]  [Disc loss: -0.459354] [Gen loss: -0.300973]
# [Epoch 2143/2200]  [Disc loss: -0.461584] [Gen loss: -0.389575]
# [Epoch 2144/2200]  [Disc loss: -0.459464] [Gen loss: -0.500998]
# [Epoch 2145/2200]  [Disc loss: -0.455955] [Gen loss: -0.214146]
# [Epoch 2146/2200]  [Disc loss: -0.455141] [Gen loss: -0.503499]
# [Epoch 2147/2200]  [Disc loss: -0.458986] [Gen loss: -0.448674]
# [Epoch 2148/2200]  [Disc loss: -0.459475] [Gen loss: -0.385142]
# [Epoch 2149/2200]  [Disc loss: -0.455268] [Gen loss: -0.529032]
# [Epoch 2150/2200]  [Disc loss: -0.459101] [Gen loss: -0.236768]
# [Epoch 2151/2200]  [Disc loss: -0.459353] [Gen loss: -0.381057]
# [Epoch 2152/2200]  [Disc loss: -0.458996] [Gen loss: -0.396752]
# [Epoch 2153/2200]  [Disc loss: -0.459297] [Gen loss: -0.521955]
# [Epoch 2154/2200]  [Disc loss: -0.452307] [Gen loss: -0.487718]
# [Epoch 2155/2200]  [Disc loss: -0.453792] [Gen loss: -0.531453]
# [Epoch 2156/2200]  [Disc loss: -0.454963] [Gen loss: -0.489343]
# [Epoch 2157/2200]  [Disc loss: -0.460259] [Gen loss: -0.423559]
# [Epoch 2158/2200]  [Disc loss: -0.455367] [Gen loss: -0.397746]
# [Epoch 2159/2200]  [Disc loss: -0.460574] [Gen loss: -0.523044]
# [Epoch 2160/2200]  [Disc loss: -0.454582] [Gen loss: -0.293193]
# [Epoch 2161/2200]  [Disc loss: -0.457505] [Gen loss: -0.541489]
# [Epoch 2162/2200]  [Disc loss: -0.458453] [Gen loss: -0.536156]
# [Epoch 2163/2200]  [Disc loss: -0.452756] [Gen loss: -0.451074]
# [Epoch 2164/2200]  [Disc loss: -0.459880] [Gen loss: -0.311770]
# [Epoch 2165/2200]  [Disc loss: -0.455655] [Gen loss: -0.420891]
# [Epoch 2166/2200]  [Disc loss: -0.459477] [Gen loss: -0.399450]
# [Epoch 2167/2200]  [Disc loss: -0.458675] [Gen loss: -0.475852]
# [Epoch 2168/2200]  [Disc loss: -0.458518] [Gen loss: -0.371510]
# [Epoch 2169/2200]  [Disc loss: -0.457618] [Gen loss: -0.355152]
# [Epoch 2170/2200]  [Disc loss: -0.463017] [Gen loss: -0.372911]
# [Epoch 2171/2200]  [Disc loss: -0.457199] [Gen loss: -0.456958]
# [Epoch 2172/2200]  [Disc loss: -0.455007] [Gen loss: -0.341207]
# [Epoch 2173/2200]  [Disc loss: -0.456586] [Gen loss: -0.568717]
# [Epoch 2174/2200]  [Disc loss: -0.456083] [Gen loss: -0.546704]
# [Epoch 2175/2200]  [Disc loss: -0.453837] [Gen loss: -0.582501]
# [Epoch 2176/2200]  [Disc loss: -0.456943] [Gen loss: -0.609415]
# [Epoch 2177/2200]  [Disc loss: -0.453315] [Gen loss: -0.422650]
# [Epoch 2178/2200]  [Disc loss: -0.457324] [Gen loss: -0.406308]
# [Epoch 2179/2200]  [Disc loss: -0.457730] [Gen loss: -0.531773]
# [Epoch 2180/2200]  [Disc loss: -0.456876] [Gen loss: -0.290558]
# [Epoch 2181/2200]  [Disc loss: -0.457348] [Gen loss: -0.590556]
# [Epoch 2182/2200]  [Disc loss: -0.458267] [Gen loss: -0.487106]
# [Epoch 2183/2200]  [Disc loss: -0.454811] [Gen loss: -0.357506]
# [Epoch 2184/2200]  [Disc loss: -0.457569] [Gen loss: -0.471327]
# [Epoch 2185/2200]  [Disc loss: -0.454493] [Gen loss: -0.432099]
# [Epoch 2186/2200]  [Disc loss: -0.451854] [Gen loss: -0.466427]
# [Epoch 2187/2200]  [Disc loss: -0.452691] [Gen loss: -0.553947]
# [Epoch 2188/2200]  [Disc loss: -0.451301] [Gen loss: -0.328477]
# [Epoch 2189/2200]  [Disc loss: -0.456316] [Gen loss: -0.595037]
# [Epoch 2190/2200]  [Disc loss: -0.459293] [Gen loss: -0.356871]
# [Epoch 2191/2200]  [Disc loss: -0.459142] [Gen loss: -0.612390]
# [Epoch 2192/2200]  [Disc loss: -0.451715] [Gen loss: -0.345107]
# [Epoch 2193/2200]  [Disc loss: -0.453705] [Gen loss: -0.458328]
# [Epoch 2194/2200]  [Disc loss: -0.455966] [Gen loss: -0.334112]
# [Epoch 2195/2200]  [Disc loss: -0.462018] [Gen loss: -0.448131]
# [Epoch 2196/2200]  [Disc loss: -0.453451] [Gen loss: -0.385506]
# [Epoch 2197/2200]  [Disc loss: -0.453732] [Gen loss: -0.420608]
# [Epoch 2198/2200]  [Disc loss: -0.458105] [Gen loss: -0.359221]
# [Epoch 2199/2200]  [Disc loss: -0.449751] [Gen loss: -0.574550]
# Training finished. Generating sample of latent vectors
# 0

# %%
torch.no_grad()
trainer.G.eval()

S = Sampler(generator=trainer.G)
latent = S.sample(10) #10 samples
latent = latent.detach().cpu().numpy().tolist()

sampled_mols_save_path = os.path.join(trainer.output_model_folder, 'sampled')
np.save(sampled_mols_save_path+f'_epoch{200}', latent)

# %%
x = np.load('content/sampled_epoch200.npy')
pd.DataFrame(x).head(10)
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.638836 -0.616414 -3.202151  0.009196 -2.119055  1.406643 -0.288569
# 1  2.098586 -2.920185 -0.921610 -0.210710  1.939441 -0.419797 -1.819821
# 2  1.603340  0.779736  3.524892  1.078962 -0.617806  0.202965 -0.816952
# 3  0.573565  0.641949  0.788232  0.773578  0.278844  1.286416 -0.480327
# 4 -1.461080 -1.294397  2.549797 -2.771791 -1.449190  1.575721  1.540542
# 5  1.243765  1.393844 -0.937783 -2.016922  0.530487  0.798823  1.923109
# 6 -0.280874 -2.460422  2.250018  0.652199 -0.840923  0.464562 -3.036115
# 7  3.511398 -0.091787 -0.219192  0.313985 -1.573894  2.981424  0.247866
# 8 -1.808075 -1.455871  0.118823 -1.008678 -1.252403 -0.634293 -2.631734
# 9  1.108043 -0.107384 -0.916500  0.421288 -1.178407  1.392352 -3.051135
#
#          7         8         9   ...        46        47        48        49  \
# 0  0.728176  1.062475 -0.720555  ...  0.309986 -0.232794 -0.393898 -0.498157
# 1 -2.933575  2.609533  2.776092  ...  0.222477 -0.429017  0.079016  0.308999
# 2 -1.342952  0.513388 -3.130149  ...  0.373169 -0.384275 -0.360362  0.876034
# 3  2.061178 -0.784136  1.422693  ...  0.472464  0.298562 -0.242873  0.185650
# 4  0.649556 -2.976316 -2.892350  ... -0.106666 -0.218720 -0.108841  0.194058
# 5  2.612517 -0.685000  0.355754  ...  0.629894 -0.736601 -0.451012  0.281935
# 6 -0.623445  2.949517  1.943163  ...  0.436232 -0.294117  0.231873  0.306376
# 7 -2.049631 -2.851445 -0.444110  ...  0.414965 -0.255028 -0.118179  0.311007
# 8 -0.015655  1.059319  1.270841  ...  0.583149 -0.622613 -0.294913  0.030339
# 9 -1.335910 -2.592261  1.934546  ...  0.386187 -0.259708 -0.347451  0.462199
#
#          50        51        52        53        54        55
# 0  0.453065 -1.587266 -0.212633 -0.147607 -0.112923  0.268307
# 1 -0.155979  0.617917 -0.542015  0.161656  0.061596 -0.098435
# 2  0.296635 -1.419499 -0.048151  0.438009  0.773474  0.320471
# 3 -0.327381  0.075236  0.261322 -0.225767  0.385955  0.086198
# 4 -0.343664  1.299873 -1.034401 -0.085661 -0.572886 -0.183947
# 5 -0.005658  0.625740 -0.567256  0.354323  0.635459  0.208598
# 6 -0.140524  0.187396  0.055132 -0.087789 -0.119752  0.412944
# 7 -0.055165  1.258763 -0.117244  0.088544  0.053068  0.374792
# 8 -0.802155 -1.120866  0.112123  0.166610 -0.054769 -0.881775
# 9 -0.020424  0.163021  0.191441 -0.275179 -0.007054  0.155120
#
# [10 rows x 56 columns]
